# %%
import numpy as np
import torch

torch.cuda.is_available()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(torch.cuda.get_device_name(0))

import MLPLoRA
# Out:
# NVIDIA GeForce RTX 3090

# %% [markdown]
# # Generate Random Gaussian Data and Fixed Target Function (Two-Layer)

# %%
def relu(x):
    return np.maximum(x, 0)


def generate_target_func(input_dim, hidden_dim, output_dim, rank_W1, rank_W2):
    fixed_W1 = np.random.normal(size=(input_dim, hidden_dim)) / np.sqrt(input_dim)
    fixed_W2 = np.random.normal(size=(hidden_dim, output_dim)) / np.sqrt(output_dim + hidden_dim)

    print('Operator Norm of fixed W1: ', np.linalg.norm(fixed_W1, ord=2))
    print('Operator Norm of fixed W2: ', np.linalg.norm(fixed_W2, ord=2))

    A1 = np.random.normal(size=(input_dim, rank_W1)) / np.sqrt(input_dim)
    B1 = np.random.normal(size=(rank_W1, hidden_dim)) / np.sqrt(hidden_dim)
    A2 = np.random.normal(size=(hidden_dim, rank_W2)) / np.sqrt(hidden_dim)
    B2 = np.random.normal(size=(rank_W2, output_dim)) / np.sqrt(output_dim)

    W1 = fixed_W1 + 3 * A1 @ B1
    W2 = fixed_W2 + 3 * A2 @ B2

    print('Operator Norm of W1: ', np.linalg.norm(W1, ord=2))
    print('Operator Norm of W2: ', np.linalg.norm(W2, ord=2))
    
    return lambda X: relu(X @ W1) @ W2, fixed_W1, fixed_W2


def generate_data(input_dim, num_train, num_test, target_func):
    X = np.random.normal(size=(num_train + num_test, input_dim))
    X /= np.linalg.norm(X, axis=1, keepdims=True)
    Y = target_func(X)
    return (X[:num_train], Y[:num_train]), (X[num_train:], Y[num_train:])

def data_to_tensor(data_pair):
    return torch.from_numpy(data_pair[0].astype(np.float32)), torch.from_numpy(data_pair[1].astype(np.float32))

# %%
input_dim = 500
hidden_dim = 100
output_dim = 20
num_train_samples = 10000
num_test_samples = 2000
rank_W1 = 10
rank_W2 = 10

target_func, fixed_W1, fixed_W2 = generate_target_func(input_dim, hidden_dim, output_dim, rank_W1, rank_W2)
train_data, test_data = generate_data(input_dim, num_train_samples, num_test_samples, target_func)
# Out:
# Operator Norm of fixed W1:  1.4243566211839866
# Operator Norm of fixed W2:  1.2191197458343974
# Operator Norm of W1:  4.100107873890544
# Operator Norm of W2:  4.640019773511152

# %%
import measurements
lr = 10
batch_size = 200
phys_bs = 5000
num_epochs = 300

msrs = measurements.Measurement(verbose=True)
msrs.add_train_recorder('MSE', phys_bs, verbose=True)
msrs.add_test_recorder('MSE', phys_bs, verbose=True)

mlp = MLPLoRA.fully_connected_net(input_dim, output_dim, [hidden_dim], 'relu').cuda()
optimizer = torch.optim.SGD(mlp.parameters(), lr=lr)
loss_fn = torch.nn.MSELoss()

MLPLoRA.train(data_to_tensor(train_data), data_to_tensor(test_data), mlp, loss_fn, optimizer, batch_size, num_epochs, msrs)
# Out:
# Epoch #0
#   Metrics on training data:
#     MSE: 0.05905507504940033.
#   Metrics on testing data:
#     MSE: 0.0583227276802063.
# Epoch #1
#   Metrics on training data:
#     MSE: 0.05726661905646324.
#   Metrics on testing data:
#     MSE: 0.05664518103003502.
# Epoch #2
#   Metrics on training data:
#     MSE: 0.05499308183789253.
#   Metrics on testing data:
#     MSE: 0.05453081801533699.
# Epoch #3
#   Metrics on training data:
#     MSE: 0.05192647501826286.
#   Metrics on testing data:
#     MSE: 0.051678940653800964.
# Epoch #4
#   Metrics on training data:
#     MSE: 0.04791194200515747.
#   Metrics on testing data:
#     MSE: 0.047939784824848175.
# Epoch #5
#   Metrics on training data:
#     MSE: 0.04321407526731491.
#   Metrics on testing data:
#     MSE: 0.04352974146604538.
# Epoch #6
#   Metrics on training data:
#     MSE: 0.03867059946060181.
#   Metrics on testing data:
#     MSE: 0.039262909442186356.
# Epoch #7
#   Metrics on training data:
#     MSE: 0.038721006363630295.
#   Metrics on testing data:
#     MSE: 0.03953607380390167.
# Epoch #8
#   Metrics on training data:
#     MSE: 0.032004453241825104.
#   Metrics on testing data:
#     MSE: 0.03306853026151657.
# Epoch #9
#   Metrics on training data:
#     MSE: 0.033284999430179596.
#   Metrics on testing data:
#     MSE: 0.0343807153403759.
# Epoch #10
#   Metrics on training data:
#     MSE: 0.03025120124220848.
#   Metrics on testing data:
#     MSE: 0.03151936084032059.
# Epoch #11
#   Metrics on training data:
#     MSE: 0.02973247691988945.
#   Metrics on testing data:
#     MSE: 0.031135274097323418.
# Epoch #12
#   Metrics on training data:
#     MSE: 0.024916741997003555.
#   Metrics on testing data:
#     MSE: 0.02638641558587551.
# Epoch #13
#   Metrics on training data:
#     MSE: 0.02548716589808464.
#   Metrics on testing data:
#     MSE: 0.026847105473279953.
# Epoch #14
#   Metrics on training data:
#     MSE: 0.02346162311732769.
#   Metrics on testing data:
#     MSE: 0.02501276694238186.
# Epoch #15
#   Metrics on training data:
#     MSE: 0.02335287444293499.
#   Metrics on testing data:
#     MSE: 0.024998152628540993.
# Epoch #16
#   Metrics on training data:
#     MSE: 0.022325735539197922.
#   Metrics on testing data:
#     MSE: 0.02395821548998356.
# Epoch #17
#   Metrics on training data:
#     MSE: 0.02236258238554001.
#   Metrics on testing data:
#     MSE: 0.023988991975784302.
# Epoch #18
#   Metrics on training data:
#     MSE: 0.02046538144350052.
#   Metrics on testing data:
#     MSE: 0.02218126691877842.
# Epoch #19
#   Metrics on training data:
#     MSE: 0.019615191966295242.
#   Metrics on testing data:
#     MSE: 0.021241536363959312.
# Epoch #20
#   Metrics on training data:
#     MSE: 0.019340110942721367.
#   Metrics on testing data:
#     MSE: 0.020967602729797363.
# Epoch #21
#   Metrics on training data:
#     MSE: 0.018524963408708572.
#   Metrics on testing data:
#     MSE: 0.020207148045301437.
# Epoch #22
#   Metrics on training data:
#     MSE: 0.01931673288345337.
#   Metrics on testing data:
#     MSE: 0.021043973043560982.
# Epoch #23
#   Metrics on training data:
#     MSE: 0.018352847546339035.
#   Metrics on testing data:
#     MSE: 0.02017906680703163.
# Epoch #24
#   Metrics on training data:
#     MSE: 0.017696313560009003.
#   Metrics on testing data:
#     MSE: 0.01947491616010666.
# Epoch #25
#   Metrics on training data:
#     MSE: 0.017842255532741547.
#   Metrics on testing data:
#     MSE: 0.019613560289144516.
# Epoch #26
#   Metrics on training data:
#     MSE: 0.017807146534323692.
#   Metrics on testing data:
#     MSE: 0.01961148902773857.
# Epoch #27
#   Metrics on training data:
#     MSE: 0.017225680872797966.
#   Metrics on testing data:
#     MSE: 0.01909278891980648.
# Epoch #28
#   Metrics on training data:
#     MSE: 0.01706979237496853.
#   Metrics on testing data:
#     MSE: 0.01896362006664276.
# Epoch #29
#   Metrics on training data:
#     MSE: 0.01702038012444973.
#   Metrics on testing data:
#     MSE: 0.01890268363058567.
# Epoch #30
#   Metrics on training data:
#     MSE: 0.017424974590539932.
#   Metrics on testing data:
#     MSE: 0.019305935129523277.
# Epoch #31
#   Metrics on training data:
#     MSE: 0.017018117010593414.
#   Metrics on testing data:
#     MSE: 0.018956633284687996.
# Epoch #32
#   Metrics on training data:
#     MSE: 0.0166853629052639.
#   Metrics on testing data:
#     MSE: 0.018651941791176796.
# Epoch #33
#   Metrics on training data:
#     MSE: 0.016535988077521324.
#   Metrics on testing data:
#     MSE: 0.018508637323975563.
# Epoch #34
#   Metrics on training data:
#     MSE: 0.01661583222448826.
#   Metrics on testing data:
#     MSE: 0.01859232783317566.
# Epoch #35
#   Metrics on training data:
#     MSE: 0.016588538885116577.
#   Metrics on testing data:
#     MSE: 0.01859353668987751.
# Epoch #36
#   Metrics on training data:
#     MSE: 0.016453353688120842.
#   Metrics on testing data:
#     MSE: 0.01849200390279293.
# Epoch #37
#   Metrics on training data:
#     MSE: 0.01624332182109356.
#   Metrics on testing data:
#     MSE: 0.018305117264389992.
# Epoch #38
#   Metrics on training data:
#     MSE: 0.01613248512148857.
#   Metrics on testing data:
#     MSE: 0.018202774226665497.
# Epoch #39
#   Metrics on training data:
#     MSE: 0.016204645857214928.
#   Metrics on testing data:
#     MSE: 0.018276158720254898.
# Epoch #40
#   Metrics on training data:
#     MSE: 0.01630254089832306.
#   Metrics on testing data:
#     MSE: 0.018393857404589653.
# Epoch #41
#   Metrics on training data:
#     MSE: 0.016109468415379524.
#   Metrics on testing data:
#     MSE: 0.018234925344586372.
# Epoch #42
#   Metrics on training data:
#     MSE: 0.015938475728034973.
#   Metrics on testing data:
#     MSE: 0.01808631606400013.
# Epoch #43
#   Metrics on training data:
#     MSE: 0.015859106555581093.
#   Metrics on testing data:
#     MSE: 0.01800929754972458.
# Epoch #44
#   Metrics on training data:
#     MSE: 0.015886321663856506.
#   Metrics on testing data:
#     MSE: 0.018039589747786522.
# Epoch #45
#   Metrics on training data:
#     MSE: 0.015844857320189476.
#   Metrics on testing data:
#     MSE: 0.018030155450105667.
# Epoch #46
#   Metrics on training data:
#     MSE: 0.015838833525776863.
#   Metrics on testing data:
#     MSE: 0.01804986596107483.
# Epoch #47
#   Metrics on training data:
#     MSE: 0.015703771263360977.
#   Metrics on testing data:
#     MSE: 0.01793067716062069.
# Epoch #48
#   Metrics on training data:
#     MSE: 0.015611106529831886.
#   Metrics on testing data:
#     MSE: 0.017840052023530006.
# Epoch #49
#   Metrics on training data:
#     MSE: 0.015619032084941864.
#   Metrics on testing data:
#     MSE: 0.017855411395430565.
# Epoch #50
#   Metrics on training data:
#     MSE: 0.01556042768061161.
#   Metrics on testing data:
#     MSE: 0.017821643501520157.
# Epoch #51
#   Metrics on training data:
#     MSE: 0.015542829409241676.
#   Metrics on testing data:
#     MSE: 0.01783289946615696.
# Epoch #52
#   Metrics on training data:
#     MSE: 0.015484324656426907.
#   Metrics on testing data:
#     MSE: 0.01779089868068695.
# Epoch #53
#   Metrics on training data:
#     MSE: 0.015407118946313858.
#   Metrics on testing data:
#     MSE: 0.017716355621814728.
# Epoch #54
#   Metrics on training data:
#     MSE: 0.015394854359328747.
#   Metrics on testing data:
#     MSE: 0.017714589834213257.
# Epoch #55
#   Metrics on training data:
#     MSE: 0.015321663580834866.
#   Metrics on testing data:
#     MSE: 0.017664048820734024.
# Epoch #56
#   Metrics on training data:
#     MSE: 0.01531053613871336.
#   Metrics on testing data:
#     MSE: 0.01767454296350479.
# Epoch #57
#   Metrics on training data:
#     MSE: 0.015290526673197746.
#   Metrics on testing data:
#     MSE: 0.01766568422317505.
# Epoch #58
#   Metrics on training data:
#     MSE: 0.015220255590975285.
#   Metrics on testing data:
#     MSE: 0.01760437898337841.
# Epoch #59
#   Metrics on training data:
#     MSE: 0.015184014104306698.
#   Metrics on testing data:
#     MSE: 0.01757689006626606.
# Epoch #60
#   Metrics on training data:
#     MSE: 0.01511471252888441.
#   Metrics on testing data:
#     MSE: 0.017534464597702026.
# Epoch #61
#   Metrics on training data:
#     MSE: 0.015117987990379333.
#   Metrics on testing data:
#     MSE: 0.017562173306941986.
# Epoch #62
#   Metrics on training data:
#     MSE: 0.015096588060259819.
#   Metrics on testing data:
#     MSE: 0.017555247992277145.
# Epoch #63
#   Metrics on training data:
#     MSE: 0.015022901818156242.
#   Metrics on testing data:
#     MSE: 0.017489148303866386.
# Epoch #64
#   Metrics on training data:
#     MSE: 0.015004890039563179.
#   Metrics on testing data:
#     MSE: 0.017482861876487732.
# Epoch #65
#   Metrics on training data:
#     MSE: 0.014951338991522789.
#   Metrics on testing data:
#     MSE: 0.017457349225878716.
# Epoch #66
#   Metrics on training data:
#     MSE: 0.014972185716032982.
#   Metrics on testing data:
#     MSE: 0.01750289648771286.
# Epoch #67
#   Metrics on training data:
#     MSE: 0.01492446567863226.
#   Metrics on testing data:
#     MSE: 0.017468607053160667.
# Epoch #68
#   Metrics on training data:
#     MSE: 0.014848470687866211.
#   Metrics on testing data:
#     MSE: 0.01739986054599285.
# Epoch #69
#   Metrics on training data:
#     MSE: 0.014831366017460823.
#   Metrics on testing data:
#     MSE: 0.017393646761775017.
# Epoch #70
#   Metrics on training data:
#     MSE: 0.014777373522520065.
#   Metrics on testing data:
#     MSE: 0.017370009794831276.
# Epoch #71
#   Metrics on training data:
#     MSE: 0.014781555160880089.
#   Metrics on testing data:
#     MSE: 0.017400147393345833.
# Epoch #72
#   Metrics on training data:
#     MSE: 0.014717819169163704.
#   Metrics on testing data:
#     MSE: 0.017351916059851646.
# Epoch #73
#   Metrics on training data:
#     MSE: 0.014686309732496738.
#   Metrics on testing data:
#     MSE: 0.0173238106071949.
# Epoch #74
#   Metrics on training data:
#     MSE: 0.014633769169449806.
#   Metrics on testing data:
#     MSE: 0.01729322224855423.
# Epoch #75
#   Metrics on training data:
#     MSE: 0.01464066468179226.
#   Metrics on testing data:
#     MSE: 0.017330270260572433.
# Epoch #76
#   Metrics on training data:
#     MSE: 0.014702352695167065.
#   Metrics on testing data:
#     MSE: 0.017408860847353935.
# Epoch #77
#   Metrics on training data:
#     MSE: 0.014547315426170826.
#   Metrics on testing data:
#     MSE: 0.017266858369112015.
# Epoch #78
#   Metrics on training data:
#     MSE: 0.01454341970384121.
#   Metrics on testing data:
#     MSE: 0.017265381291508675.
# Epoch #79
#   Metrics on training data:
#     MSE: 0.01448771171271801.
#   Metrics on testing data:
#     MSE: 0.017232730984687805.
# Epoch #80
#   Metrics on training data:
#     MSE: 0.014480436220765114.
#   Metrics on testing data:
#     MSE: 0.0172547847032547.
# Epoch #81
#   Metrics on training data:
#     MSE: 0.014499523676931858.
#   Metrics on testing data:
#     MSE: 0.017295369878411293.
# Epoch #82
#   Metrics on training data:
#     MSE: 0.014365572482347488.
#   Metrics on testing data:
#     MSE: 0.01717352867126465.
# Epoch #83
#   Metrics on training data:
#     MSE: 0.014383337460458279.
#   Metrics on testing data:
#     MSE: 0.017199629917740822.
# Epoch #84
#   Metrics on training data:
#     MSE: 0.014298592694103718.
#   Metrics on testing data:
#     MSE: 0.017138535156846046.
# Epoch #85
#   Metrics on training data:
#     MSE: 0.014368172734975815.
#   Metrics on testing data:
#     MSE: 0.017238212749361992.
# Epoch #86
#   Metrics on training data:
#     MSE: 0.01438738964498043.
#   Metrics on testing data:
#     MSE: 0.017273807898163795.
# Epoch #87
#   Metrics on training data:
#     MSE: 0.014188303612172604.
#   Metrics on testing data:
#     MSE: 0.017087047919631004.
# Epoch #88
#   Metrics on training data:
#     MSE: 0.014224196784198284.
#   Metrics on testing data:
#     MSE: 0.017130808904767036.
# Epoch #89
#   Metrics on training data:
#     MSE: 0.014152037911117077.
#   Metrics on testing data:
#     MSE: 0.017082761973142624.
# Epoch #90
#   Metrics on training data:
#     MSE: 0.014200667850673199.
#   Metrics on testing data:
#     MSE: 0.017160015180706978.
# Epoch #91
#   Metrics on training data:
#     MSE: 0.014337518252432346.
#   Metrics on testing data:
#     MSE: 0.01731027476489544.
# Epoch #92
#   Metrics on training data:
#     MSE: 0.014012777246534824.
#   Metrics on testing data:
#     MSE: 0.017015626654028893.
# Epoch #93
#   Metrics on training data:
#     MSE: 0.014100966975092888.
#   Metrics on testing data:
#     MSE: 0.017107227817177773.
# Epoch #94
#   Metrics on training data:
#     MSE: 0.013974430039525032.
#   Metrics on testing data:
#     MSE: 0.01700579561293125.
# Epoch #95
#   Metrics on training data:
#     MSE: 0.014000955037772655.
#   Metrics on testing data:
#     MSE: 0.017056670039892197.
# Epoch #96
#   Metrics on training data:
#     MSE: 0.014201879501342773.
#   Metrics on testing data:
#     MSE: 0.01726672053337097.
# Epoch #97
#   Metrics on training data:
#     MSE: 0.013845855370163918.
#   Metrics on testing data:
#     MSE: 0.0169510580599308.
# Epoch #98
#   Metrics on training data:
#     MSE: 0.013955009169876575.
#   Metrics on testing data:
#     MSE: 0.017058255150914192.
# Epoch #99
#   Metrics on training data:
#     MSE: 0.013831112533807755.
#   Metrics on testing data:
#     MSE: 0.016960076987743378.
# Epoch #100
#   Metrics on training data:
#     MSE: 0.013760555535554886.
#   Metrics on testing data:
#     MSE: 0.016916219145059586.
# Epoch #101
#   Metrics on training data:
#     MSE: 0.014120304957032204.
#   Metrics on testing data:
#     MSE: 0.017282405868172646.
# Epoch #102
#   Metrics on training data:
#     MSE: 0.013904107734560966.
#   Metrics on testing data:
#     MSE: 0.017088228836655617.
# Epoch #103
#   Metrics on training data:
#     MSE: 0.013861410319805145.
#   Metrics on testing data:
#     MSE: 0.017071247100830078.
# Epoch #104
#   Metrics on training data:
#     MSE: 0.013694924302399158.
#   Metrics on testing data:
#     MSE: 0.01692132279276848.
# Epoch #105
#   Metrics on training data:
#     MSE: 0.013626232743263245.
#   Metrics on testing data:
#     MSE: 0.01687767170369625.
# Epoch #106
#   Metrics on training data:
#     MSE: 0.013730539940297604.
#   Metrics on testing data:
#     MSE: 0.016992725431919098.
# Epoch #107
#   Metrics on training data:
#     MSE: 0.013841338455677032.
#   Metrics on testing data:
#     MSE: 0.01711929403245449.
# Epoch #108
#   Metrics on training data:
#     MSE: 0.013463488779962063.
#   Metrics on testing data:
#     MSE: 0.01678166165947914.
# Epoch #109
#   Metrics on training data:
#     MSE: 0.013718980364501476.
#   Metrics on testing data:
#     MSE: 0.01703576371073723.
# Epoch #110
#   Metrics on training data:
#     MSE: 0.01348953228443861.
#   Metrics on testing data:
#     MSE: 0.01683896966278553.
# Epoch #111
#   Metrics on training data:
#     MSE: 0.013401116244494915.
#   Metrics on testing data:
#     MSE: 0.016780437901616096.
# Epoch #112
#   Metrics on training data:
#     MSE: 0.013751489110291004.
#   Metrics on testing data:
#     MSE: 0.017124531790614128.
# Epoch #113
#   Metrics on training data:
#     MSE: 0.013574345037341118.
#   Metrics on testing data:
#     MSE: 0.016969159245491028.
# Epoch #114
#   Metrics on training data:
#     MSE: 0.01371468510478735.
#   Metrics on testing data:
#     MSE: 0.01714007928967476.
# Epoch #115
#   Metrics on training data:
#     MSE: 0.013486138544976711.
#   Metrics on testing data:
#     MSE: 0.016928810626268387.
# Epoch #116
#   Metrics on training data:
#     MSE: 0.013311324641108513.
#   Metrics on testing data:
#     MSE: 0.01679193414747715.
# Epoch #117
#   Metrics on training data:
#     MSE: 0.0132802315056324.
#   Metrics on testing data:
#     MSE: 0.016767198219895363.
# Epoch #118
#   Metrics on training data:
#     MSE: 0.013524993322789669.
#   Metrics on testing data:
#     MSE: 0.01701367273926735.
# Epoch #119
#   Metrics on training data:
#     MSE: 0.013299082405865192.
#   Metrics on testing data:
#     MSE: 0.016822347417473793.
# Epoch #120
#   Metrics on training data:
#     MSE: 0.013487727381289005.
#   Metrics on testing data:
#     MSE: 0.017041493207216263.
# Epoch #121
#   Metrics on training data:
#     MSE: 0.013367196545004845.
#   Metrics on testing data:
#     MSE: 0.016920434311032295.
# Epoch #122
#   Metrics on training data:
#     MSE: 0.01315317489206791.
#   Metrics on testing data:
#     MSE: 0.01673523150384426.
# Epoch #123
#   Metrics on training data:
#     MSE: 0.013108216226100922.
#   Metrics on testing data:
#     MSE: 0.016715554520487785.
# Epoch #124
#   Metrics on training data:
#     MSE: 0.013411471620202065.
#   Metrics on testing data:
#     MSE: 0.017012707889080048.
# Epoch #125
#   Metrics on training data:
#     MSE: 0.013152333907783031.
#   Metrics on testing data:
#     MSE: 0.01679232157766819.
# Epoch #126
#   Metrics on training data:
#     MSE: 0.013150869868695736.
#   Metrics on testing data:
#     MSE: 0.016840245574712753.
# Epoch #127
#   Metrics on training data:
#     MSE: 0.013495470397174358.
#   Metrics on testing data:
#     MSE: 0.0171539094299078.
# Epoch #128
#   Metrics on training data:
#     MSE: 0.013111581094563007.
#   Metrics on testing data:
#     MSE: 0.01679547131061554.
# Epoch #129
#   Metrics on training data:
#     MSE: 0.013222132809460163.
#   Metrics on testing data:
#     MSE: 0.01691238209605217.
# Epoch #130
#   Metrics on training data:
#     MSE: 0.013221700675785542.
#   Metrics on testing data:
#     MSE: 0.016945648938417435.
# Epoch #131
#   Metrics on training data:
#     MSE: 0.012866479344666004.
#   Metrics on testing data:
#     MSE: 0.016654884442687035.
# Epoch #132
#   Metrics on training data:
#     MSE: 0.013461828231811523.
#   Metrics on testing data:
#     MSE: 0.017241811379790306.
# Epoch #133
#   Metrics on training data:
#     MSE: 0.013048775494098663.
#   Metrics on testing data:
#     MSE: 0.01683064177632332.
# Epoch #134
#   Metrics on training data:
#     MSE: 0.012996014207601547.
#   Metrics on testing data:
#     MSE: 0.01677047461271286.
# Epoch #135
#   Metrics on training data:
#     MSE: 0.013069882057607174.
#   Metrics on testing data:
#     MSE: 0.016895638778805733.
# Epoch #136
#   Metrics on training data:
#     MSE: 0.012944430112838745.
#   Metrics on testing data:
#     MSE: 0.016814038157463074.
# Epoch #137
#   Metrics on training data:
#     MSE: 0.013503787107765675.
#   Metrics on testing data:
#     MSE: 0.017408400774002075.
# Epoch #138
#   Metrics on training data:
#     MSE: 0.013061825186014175.
#   Metrics on testing data:
#     MSE: 0.01693565584719181.
# Epoch #139
#   Metrics on training data:
#     MSE: 0.012730718590319157.
#   Metrics on testing data:
#     MSE: 0.01661917380988598.
# Epoch #140
#   Metrics on training data:
#     MSE: 0.013148687779903412.
#   Metrics on testing data:
#     MSE: 0.017038902267813683.
# Epoch #141
#   Metrics on training data:
#     MSE: 0.01278839260339737.
#   Metrics on testing data:
#     MSE: 0.016750317066907883.
# Epoch #142
#   Metrics on training data:
#     MSE: 0.012853411957621574.
#   Metrics on testing data:
#     MSE: 0.016887951642274857.
# Epoch #143
#   Metrics on training data:
#     MSE: 0.01329093612730503.
#   Metrics on testing data:
#     MSE: 0.017262376844882965.
# Epoch #144
#   Metrics on training data:
#     MSE: 0.01260462962090969.
#   Metrics on testing data:
#     MSE: 0.01660793274641037.
# Epoch #145
#   Metrics on training data:
#     MSE: 0.012499239295721054.
#   Metrics on testing data:
#     MSE: 0.01652657426893711.
# Epoch #146
#   Metrics on training data:
#     MSE: 0.012979894876480103.
#   Metrics on testing data:
#     MSE: 0.016996070742607117.
# Epoch #147
#   Metrics on training data:
#     MSE: 0.012600199319422245.
#   Metrics on testing data:
#     MSE: 0.016668496653437614.
# Epoch #148
#   Metrics on training data:
#     MSE: 0.012323635630309582.
#   Metrics on testing data:
#     MSE: 0.01642148196697235.
# Epoch #149
#   Metrics on training data:
#     MSE: 0.013404786586761475.
#   Metrics on testing data:
#     MSE: 0.01749933697283268.
# Epoch #150
#   Metrics on training data:
#     MSE: 0.012827209196984768.
#   Metrics on testing data:
#     MSE: 0.017007241025567055.
# Epoch #151
#   Metrics on training data:
#     MSE: 0.012779583223164082.
#   Metrics on testing data:
#     MSE: 0.01690366491675377.
# Epoch #152
#   Metrics on training data:
#     MSE: 0.012676852755248547.
#   Metrics on testing data:
#     MSE: 0.016782963648438454.
# Epoch #153
#   Metrics on training data:
#     MSE: 0.01295290607959032.
#   Metrics on testing data:
#     MSE: 0.01711246185004711.
# Epoch #154
#   Metrics on training data:
#     MSE: 0.012807470746338367.
#   Metrics on testing data:
#     MSE: 0.017020264640450478.
# Epoch #155
#   Metrics on training data:
#     MSE: 0.012434754520654678.
#   Metrics on testing data:
#     MSE: 0.01673313044011593.
# Epoch #156
#   Metrics on training data:
#     MSE: 0.012917552143335342.
#   Metrics on testing data:
#     MSE: 0.01713065430521965.
# Epoch #157
#   Metrics on training data:
#     MSE: 0.012415940873324871.
#   Metrics on testing data:
#     MSE: 0.01664712093770504.
# Epoch #158
#   Metrics on training data:
#     MSE: 0.012441826052963734.
#   Metrics on testing data:
#     MSE: 0.01668197102844715.
# Epoch #159
#   Metrics on training data:
#     MSE: 0.013032360933721066.
#   Metrics on testing data:
#     MSE: 0.017323346808552742.
# Epoch #160
#   Metrics on training data:
#     MSE: 0.012239639647305012.
#   Metrics on testing data:
#     MSE: 0.016604047268629074.
# Epoch #161
#   Metrics on training data:
#     MSE: 0.012198766693472862.
#   Metrics on testing data:
#     MSE: 0.016575001180171967.
# Epoch #162
#   Metrics on training data:
#     MSE: 0.012568247504532337.
#   Metrics on testing data:
#     MSE: 0.016892243176698685.
# Epoch #163
#   Metrics on training data:
#     MSE: 0.01238731388002634.
#   Metrics on testing data:
#     MSE: 0.016722332686185837.
# Epoch #164
#   Metrics on training data:
#     MSE: 0.013018207624554634.
#   Metrics on testing data:
#     MSE: 0.017406880855560303.
# Epoch #165
#   Metrics on training data:
#     MSE: 0.012118435464799404.
#   Metrics on testing data:
#     MSE: 0.016574066132307053.
# Epoch #166
#   Metrics on training data:
#     MSE: 0.012261373922228813.
#   Metrics on testing data:
#     MSE: 0.016671834513545036.
# Epoch #167
#   Metrics on training data:
#     MSE: 0.012689459137618542.
#   Metrics on testing data:
#     MSE: 0.017130611464381218.
# Epoch #168
#   Metrics on training data:
#     MSE: 0.012565857730805874.
#   Metrics on testing data:
#     MSE: 0.017075445502996445.
# Epoch #169
#   Metrics on training data:
#     MSE: 0.012924897484481335.
#   Metrics on testing data:
#     MSE: 0.017361370846629143.
# Epoch #170
#   Metrics on training data:
#     MSE: 0.011930546723306179.
#   Metrics on testing data:
#     MSE: 0.016438541933894157.
# Epoch #171
#   Metrics on training data:
#     MSE: 0.012425999157130718.
#   Metrics on testing data:
#     MSE: 0.016899656504392624.
# Epoch #172
#   Metrics on training data:
#     MSE: 0.011899790726602077.
#   Metrics on testing data:
#     MSE: 0.01649550348520279.
# Epoch #173
#   Metrics on training data:
#     MSE: 0.012872567400336266.
#   Metrics on testing data:
#     MSE: 0.017499232664704323.
# Epoch #174
#   Metrics on training data:
#     MSE: 0.012647295370697975.
#   Metrics on testing data:
#     MSE: 0.01720118708908558.
# Epoch #175
#   Metrics on training data:
#     MSE: 0.012008805759251118.
#   Metrics on testing data:
#     MSE: 0.01661159284412861.
# Epoch #176
#   Metrics on training data:
#     MSE: 0.012503490783274174.
#   Metrics on testing data:
#     MSE: 0.017078105360269547.
# Epoch #177
#   Metrics on training data:
#     MSE: 0.011978860013186932.
#   Metrics on testing data:
#     MSE: 0.01663856953382492.
# Epoch #178
#   Metrics on training data:
#     MSE: 0.011555281467735767.
#   Metrics on testing data:
#     MSE: 0.016252385452389717.
# Epoch #179
#   Metrics on training data:
#     MSE: 0.012687128968536854.
#   Metrics on testing data:
#     MSE: 0.0173623226583004.
# Epoch #180
#   Metrics on training data:
#     MSE: 0.012447808869183064.
#   Metrics on testing data:
#     MSE: 0.017191346734762192.
# Epoch #181
#   Metrics on training data:
#     MSE: 0.01201327983289957.
#   Metrics on testing data:
#     MSE: 0.016690701246261597.
# Epoch #182
#   Metrics on training data:
#     MSE: 0.011876281350851059.
#   Metrics on testing data:
#     MSE: 0.016584480181336403.
# Epoch #183
#   Metrics on training data:
#     MSE: 0.011599372141063213.
#   Metrics on testing data:
#     MSE: 0.016425715759396553.
# Epoch #184
#   Metrics on training data:
#     MSE: 0.012542378157377243.
#   Metrics on testing data:
#     MSE: 0.01725764200091362.
# Epoch #185
#   Metrics on training data:
#     MSE: 0.012098933570086956.
#   Metrics on testing data:
#     MSE: 0.016892770305275917.
# Epoch #186
#   Metrics on training data:
#     MSE: 0.012261910364031792.
#   Metrics on testing data:
#     MSE: 0.017113259062170982.
# Epoch #187
#   Metrics on training data:
#     MSE: 0.012087988667190075.
#   Metrics on testing data:
#     MSE: 0.0169060118496418.
# Epoch #188
#   Metrics on training data:
#     MSE: 0.011724768206477165.
#   Metrics on testing data:
#     MSE: 0.016540762037038803.
# Epoch #189
#   Metrics on training data:
#     MSE: 0.012217878364026546.
#   Metrics on testing data:
#     MSE: 0.017073223367333412.
# Epoch #190
#   Metrics on training data:
#     MSE: 0.011913109570741653.
#   Metrics on testing data:
#     MSE: 0.016851766034960747.
# Epoch #191
#   Metrics on training data:
#     MSE: 0.011651033535599709.
#   Metrics on testing data:
#     MSE: 0.01665632426738739.
# Epoch #192
#   Metrics on training data:
#     MSE: 0.012038808315992355.
#   Metrics on testing data:
#     MSE: 0.016940144822001457.
# Epoch #193
#   Metrics on training data:
#     MSE: 0.011503040790557861.
#   Metrics on testing data:
#     MSE: 0.016474414616823196.
# Epoch #194
#   Metrics on training data:
#     MSE: 0.012245817109942436.
#   Metrics on testing data:
#     MSE: 0.017155930399894714.
# Epoch #195
#   Metrics on training data:
#     MSE: 0.01194704044610262.
#   Metrics on testing data:
#     MSE: 0.016925718635320663.
# Epoch #196
#   Metrics on training data:
#     MSE: 0.01187918335199356.
#   Metrics on testing data:
#     MSE: 0.016934191808104515.
# Epoch #197
#   Metrics on training data:
#     MSE: 0.01188182458281517.
#   Metrics on testing data:
#     MSE: 0.01688815839588642.
# Epoch #198
#   Metrics on training data:
#     MSE: 0.011677771806716919.
#   Metrics on testing data:
#     MSE: 0.01665501855313778.
# Epoch #199
#   Metrics on training data:
#     MSE: 0.0119758490473032.
#   Metrics on testing data:
#     MSE: 0.017010454088449478.
# Epoch #200
#   Metrics on training data:
#     MSE: 0.011471958830952644.
#   Metrics on testing data:
#     MSE: 0.016647160053253174.
# Epoch #201
#   Metrics on training data:
#     MSE: 0.011402335949242115.
#   Metrics on testing data:
#     MSE: 0.016552060842514038.
# Epoch #202
#   Metrics on training data:
#     MSE: 0.011820375919342041.
#   Metrics on testing data:
#     MSE: 0.016896989196538925.
# Epoch #203
#   Metrics on training data:
#     MSE: 0.0112290158867836.
#   Metrics on testing data:
#     MSE: 0.0163981094956398.
# Epoch #204
#   Metrics on training data:
#     MSE: 0.012059350498020649.
#   Metrics on testing data:
#     MSE: 0.01713424362242222.
# Epoch #205
#   Metrics on training data:
#     MSE: 0.011594091542065144.
#   Metrics on testing data:
#     MSE: 0.016747470945119858.
# Epoch #206
#   Metrics on training data:
#     MSE: 0.011731425300240517.
#   Metrics on testing data:
#     MSE: 0.01693541184067726.
# Epoch #207
#   Metrics on training data:
#     MSE: 0.011636110953986645.
#   Metrics on testing data:
#     MSE: 0.01681983657181263.
# Epoch #208
#   Metrics on training data:
#     MSE: 0.011238789185881615.
#   Metrics on testing data:
#     MSE: 0.016423454508185387.
# Epoch #209
#   Metrics on training data:
#     MSE: 0.011675593443214893.
#   Metrics on testing data:
#     MSE: 0.01691109500825405.
# Epoch #210
#   Metrics on training data:
#     MSE: 0.011333746835589409.
#   Metrics on testing data:
#     MSE: 0.016691220924258232.
# Epoch #211
#   Metrics on training data:
#     MSE: 0.011740455403923988.
#   Metrics on testing data:
#     MSE: 0.01704287715256214.
# Epoch #212
#   Metrics on training data:
#     MSE: 0.011352771893143654.
#   Metrics on testing data:
#     MSE: 0.01666748896241188.
# Epoch #213
#   Metrics on training data:
#     MSE: 0.011041390709578991.
#   Metrics on testing data:
#     MSE: 0.016346948221325874.
# Epoch #214
#   Metrics on training data:
#     MSE: 0.01166797336190939.
#   Metrics on testing data:
#     MSE: 0.01696252077817917.
# Epoch #215
#   Metrics on training data:
#     MSE: 0.011367648839950562.
#   Metrics on testing data:
#     MSE: 0.01670737937092781.
# Epoch #216
#   Metrics on training data:
#     MSE: 0.011386832222342491.
#   Metrics on testing data:
#     MSE: 0.016712484881281853.
# Epoch #217
#   Metrics on training data:
#     MSE: 0.01088922843337059.
#   Metrics on testing data:
#     MSE: 0.016274621710181236.
# Epoch #218
#   Metrics on training data:
#     MSE: 0.011382263153791428.
#   Metrics on testing data:
#     MSE: 0.01680370420217514.
# Epoch #219
#   Metrics on training data:
#     MSE: 0.011147241108119488.
#   Metrics on testing data:
#     MSE: 0.01665593311190605.
# Epoch #220
#   Metrics on training data:
#     MSE: 0.011320498771965504.
#   Metrics on testing data:
#     MSE: 0.016759024932980537.
# Epoch #221
#   Metrics on training data:
#     MSE: 0.01152851339429617.
#   Metrics on testing data:
#     MSE: 0.016935253515839577.
# Epoch #222
#   Metrics on training data:
#     MSE: 0.011116055771708488.
#   Metrics on testing data:
#     MSE: 0.016597596928477287.
# Epoch #223
#   Metrics on training data:
#     MSE: 0.010991517454385757.
#   Metrics on testing data:
#     MSE: 0.016593636944890022.
# Epoch #224
#   Metrics on training data:
#     MSE: 0.011291200295090675.
#   Metrics on testing data:
#     MSE: 0.016823049634695053.
# Epoch #225
#   Metrics on training data:
#     MSE: 0.011150537058711052.
#   Metrics on testing data:
#     MSE: 0.016652699559926987.
# Epoch #226
#   Metrics on training data:
#     MSE: 0.0111885080114007.
#   Metrics on testing data:
#     MSE: 0.016695423051714897.
# Epoch #227
#   Metrics on training data:
#     MSE: 0.011094584129750729.
#   Metrics on testing data:
#     MSE: 0.016635073348879814.
# Epoch #228
#   Metrics on training data:
#     MSE: 0.011429878883063793.
#   Metrics on testing data:
#     MSE: 0.017018772661685944.
# Epoch #229
#   Metrics on training data:
#     MSE: 0.010809434577822685.
#   Metrics on testing data:
#     MSE: 0.016447335481643677.
# Epoch #230
#   Metrics on training data:
#     MSE: 0.010641471482813358.
#   Metrics on testing data:
#     MSE: 0.016265390440821648.
# Epoch #231
#   Metrics on training data:
#     MSE: 0.011290651746094227.
#   Metrics on testing data:
#     MSE: 0.017003536224365234.
# Epoch #232
#   Metrics on training data:
#     MSE: 0.011263556778430939.
#   Metrics on testing data:
#     MSE: 0.016919396817684174.
# Epoch #233
#   Metrics on training data:
#     MSE: 0.011063956655561924.
#   Metrics on testing data:
#     MSE: 0.01666652224957943.
# Epoch #234
#   Metrics on training data:
#     MSE: 0.010762923397123814.
#   Metrics on testing data:
#     MSE: 0.01641727052628994.
# Epoch #235
#   Metrics on training data:
#     MSE: 0.011143296957015991.
#   Metrics on testing data:
#     MSE: 0.01681068167090416.
# Epoch #236
#   Metrics on training data:
#     MSE: 0.01102529652416706.
#   Metrics on testing data:
#     MSE: 0.01680983230471611.
# Epoch #237
#   Metrics on training data:
#     MSE: 0.010726547800004482.
#   Metrics on testing data:
#     MSE: 0.016480956226587296.
# Epoch #238
#   Metrics on training data:
#     MSE: 0.01081605814397335.
#   Metrics on testing data:
#     MSE: 0.01656905747950077.
# Epoch #239
#   Metrics on training data:
#     MSE: 0.01080045010894537.
#   Metrics on testing data:
#     MSE: 0.016654599457979202.
# Epoch #240
#   Metrics on training data:
#     MSE: 0.01115204393863678.
#   Metrics on testing data:
#     MSE: 0.01689058169722557.
# Epoch #241
#   Metrics on training data:
#     MSE: 0.010801021941006184.
#   Metrics on testing data:
#     MSE: 0.016555247828364372.
# Epoch #242
#   Metrics on training data:
#     MSE: 0.010956109501421452.
#   Metrics on testing data:
#     MSE: 0.01671455055475235.
# Epoch #243
#   Metrics on training data:
#     MSE: 0.010691520757973194.
#   Metrics on testing data:
#     MSE: 0.016518352553248405.
# Epoch #244
#   Metrics on training data:
#     MSE: 0.010977517813444138.
#   Metrics on testing data:
#     MSE: 0.01687849871814251.
# Epoch #245
#   Metrics on training data:
#     MSE: 0.010936897248029709.
#   Metrics on testing data:
#     MSE: 0.016826603561639786.
# Epoch #246
#   Metrics on training data:
#     MSE: 0.01116642914712429.
#   Metrics on testing data:
#     MSE: 0.01706952042877674.
# Epoch #247
#   Metrics on training data:
#     MSE: 0.010515252128243446.
#   Metrics on testing data:
#     MSE: 0.016408264636993408.
# Epoch #248
#   Metrics on training data:
#     MSE: 0.010867105796933174.
#   Metrics on testing data:
#     MSE: 0.016740471124649048.
# Epoch #249
#   Metrics on training data:
#     MSE: 0.010873754508793354.
#   Metrics on testing data:
#     MSE: 0.01679023914039135.
# Epoch #250
#   Metrics on training data:
#     MSE: 0.01048409566283226.
#   Metrics on testing data:
#     MSE: 0.016527952626347542.
# Epoch #251
#   Metrics on training data:
#     MSE: 0.01078860554844141.
#   Metrics on testing data:
#     MSE: 0.016751466318964958.
# Epoch #252
#   Metrics on training data:
#     MSE: 0.0108450036495924.
#   Metrics on testing data:
#     MSE: 0.016805998980998993.
# Epoch #253
#   Metrics on training data:
#     MSE: 0.01072003599256277.
#   Metrics on testing data:
#     MSE: 0.01677621528506279.
# Epoch #254
#   Metrics on training data:
#     MSE: 0.010522755794227123.
#   Metrics on testing data:
#     MSE: 0.016509776934981346.
# Epoch #255
#   Metrics on training data:
#     MSE: 0.010205271653831005.
#   Metrics on testing data:
#     MSE: 0.01621716469526291.
# Epoch #256
#   Metrics on training data:
#     MSE: 0.010533050633966923.
#   Metrics on testing data:
#     MSE: 0.016632145270705223.
# Epoch #257
#   Metrics on training data:
#     MSE: 0.010229992680251598.
#   Metrics on testing data:
#     MSE: 0.016404274851083755.
# Epoch #258
#   Metrics on training data:
#     MSE: 0.010777287185192108.
#   Metrics on testing data:
#     MSE: 0.01683240756392479.
# Epoch #259
#   Metrics on training data:
#     MSE: 0.010347138158977032.
#   Metrics on testing data:
#     MSE: 0.01641635224223137.
# Epoch #260
#   Metrics on training data:
#     MSE: 0.01073746383190155.
#   Metrics on testing data:
#     MSE: 0.016925930976867676.
# Epoch #261
#   Metrics on training data:
#     MSE: 0.010211377404630184.
#   Metrics on testing data:
#     MSE: 0.016447467729449272.
# Epoch #262
#   Metrics on training data:
#     MSE: 0.010462374426424503.
#   Metrics on testing data:
#     MSE: 0.016573065891861916.
# Epoch #263
#   Metrics on training data:
#     MSE: 0.010507417842745781.
#   Metrics on testing data:
#     MSE: 0.016659287735819817.
# Epoch #264
#   Metrics on training data:
#     MSE: 0.010101011954247952.
#   Metrics on testing data:
#     MSE: 0.016329355537891388.
# Epoch #265
#   Metrics on training data:
#     MSE: 0.010487181134521961.
#   Metrics on testing data:
#     MSE: 0.016781285405158997.
# Epoch #266
#   Metrics on training data:
#     MSE: 0.01044634822756052.
#   Metrics on testing data:
#     MSE: 0.01662288047373295.
# Epoch #267
#   Metrics on training data:
#     MSE: 0.01009021420031786.
#   Metrics on testing data:
#     MSE: 0.016304505988955498.
# Epoch #268
#   Metrics on training data:
#     MSE: 0.009951578453183174.
#   Metrics on testing data:
#     MSE: 0.01627219282090664.
# Epoch #269
#   Metrics on training data:
#     MSE: 0.01079690083861351.
#   Metrics on testing data:
#     MSE: 0.017036564648151398.
# Epoch #270
#   Metrics on training data:
#     MSE: 0.01010918989777565.
#   Metrics on testing data:
#     MSE: 0.016366582363843918.
# Epoch #271
#   Metrics on training data:
#     MSE: 0.010071857832372189.
#   Metrics on testing data:
#     MSE: 0.01638125814497471.
# Epoch #272
#   Metrics on training data:
#     MSE: 0.010983407497406006.
#   Metrics on testing data:
#     MSE: 0.017327001318335533.
# Epoch #273
#   Metrics on training data:
#     MSE: 0.010210339911282063.
#   Metrics on testing data:
#     MSE: 0.016539350152015686.
# Epoch #274
#   Metrics on training data:
#     MSE: 0.010145113803446293.
#   Metrics on testing data:
#     MSE: 0.01647443138062954.
# Epoch #275
#   Metrics on training data:
#     MSE: 0.01031295582652092.
#   Metrics on testing data:
#     MSE: 0.016709184274077415.
# Epoch #276
#   Metrics on training data:
#     MSE: 0.010317436419427395.
#   Metrics on testing data:
#     MSE: 0.016737377271056175.
# Epoch #277
#   Metrics on training data:
#     MSE: 0.010454343631863594.
#   Metrics on testing data:
#     MSE: 0.016884610056877136.
# Epoch #278
#   Metrics on training data:
#     MSE: 0.009983585216104984.
#   Metrics on testing data:
#     MSE: 0.016476521268486977.
# Epoch #279
#   Metrics on training data:
#     MSE: 0.010330700315535069.
#   Metrics on testing data:
#     MSE: 0.016743287444114685.
# Epoch #280
#   Metrics on training data:
#     MSE: 0.009870748966932297.
#   Metrics on testing data:
#     MSE: 0.016299987211823463.
# Epoch #281
#   Metrics on training data:
#     MSE: 0.010261695832014084.
#   Metrics on testing data:
#     MSE: 0.016713520511984825.
# Epoch #282
#   Metrics on training data:
#     MSE: 0.00996389426290989.
#   Metrics on testing data:
#     MSE: 0.01653972454369068.
# Epoch #283
#   Metrics on training data:
#     MSE: 0.010283851064741611.
#   Metrics on testing data:
#     MSE: 0.016838034614920616.
# Epoch #284
#   Metrics on training data:
#     MSE: 0.009960361756384373.
#   Metrics on testing data:
#     MSE: 0.016485225409269333.
# Epoch #285
#   Metrics on training data:
#     MSE: 0.00969504565000534.
#   Metrics on testing data:
#     MSE: 0.016198618337512016.
# Epoch #286
#   Metrics on training data:
#     MSE: 0.010211506858468056.
#   Metrics on testing data:
#     MSE: 0.016790008172392845.
# Epoch #287
#   Metrics on training data:
#     MSE: 0.00981091894209385.
#   Metrics on testing data:
#     MSE: 0.016479454934597015.
# Epoch #288
#   Metrics on training data:
#     MSE: 0.010223501361906528.
#   Metrics on testing data:
#     MSE: 0.01683223433792591.
# Epoch #289
#   Metrics on training data:
#     MSE: 0.010134664364159107.
#   Metrics on testing data:
#     MSE: 0.016710640862584114.
# Epoch #290
#   Metrics on training data:
#     MSE: 0.01013171672821045.
#   Metrics on testing data:
#     MSE: 0.016738230362534523.
# Epoch #291
#   Metrics on training data:
#     MSE: 0.009668196551501751.
#   Metrics on testing data:
#     MSE: 0.016334757208824158.
# Epoch #292
#   Metrics on training data:
#     MSE: 0.010095697827637196.
#   Metrics on testing data:
#     MSE: 0.016805382445454597.
# Epoch #293
#   Metrics on training data:
#     MSE: 0.009899437427520752.
#   Metrics on testing data:
#     MSE: 0.016603834927082062.
# Epoch #294
#   Metrics on training data:
#     MSE: 0.009942945092916489.
#   Metrics on testing data:
#     MSE: 0.01664549857378006.
# Epoch #295
#   Metrics on training data:
#     MSE: 0.009669937193393707.
#   Metrics on testing data:
#     MSE: 0.016323929652571678.
# Epoch #296
#   Metrics on training data:
#     MSE: 0.010006224736571312.
#   Metrics on testing data:
#     MSE: 0.016689961776137352.
# Epoch #297
#   Metrics on training data:
#     MSE: 0.00961784366518259.
#   Metrics on testing data:
#     MSE: 0.01634986139833927.
# Epoch #298
#   Metrics on training data:
#     MSE: 0.01003445778042078.
#   Metrics on testing data:
#     MSE: 0.016840877011418343.
# Epoch #299
#   Metrics on training data:
#     MSE: 0.009665055200457573.
#   Metrics on testing data:
#     MSE: 0.01648060977458954.

# %%
msrs = measurements.Measurement(verbose=True)
msrs.add_train_recorder('MSE', phys_bs, verbose=True)
msrs.add_test_recorder('MSE', phys_bs, verbose=True)

lora, lora_layers = MLPLoRA.get_mlp_lora([fixed_W1, fixed_W2], [rank_W1, rank_W2], 'relu')
lora = lora.cuda()
optimizer = torch.optim.SGD(lora.parameters(), lr=50)
loss_fn = torch.nn.MSELoss()

MLPLoRA.train(data_to_tensor(train_data), data_to_tensor(test_data), lora, loss_fn, optimizer, batch_size, num_epochs, msrs)
# Out:
# Epoch #0
#   Metrics on training data:
#     MSE: 0.04993470758199692.
#   Metrics on testing data:
#     MSE: 0.04920484498143196.
# Epoch #1
#   Metrics on training data:
#     MSE: 0.038984403014183044.
#   Metrics on testing data:
#     MSE: 0.03899824619293213.
# Epoch #2
#   Metrics on training data:
#     MSE: 0.03008093126118183.
#   Metrics on testing data:
#     MSE: 0.0308341383934021.
# Epoch #3
#   Metrics on training data:
#     MSE: 0.02412392571568489.
#   Metrics on testing data:
#     MSE: 0.02529069595038891.
# Epoch #4
#   Metrics on training data:
#     MSE: 0.019846230745315552.
#   Metrics on testing data:
#     MSE: 0.021218284964561462.
# Epoch #5
#   Metrics on training data:
#     MSE: 0.01710786484181881.
#   Metrics on testing data:
#     MSE: 0.01851341314613819.
# Epoch #6
#   Metrics on training data:
#     MSE: 0.015144884586334229.
#   Metrics on testing data:
#     MSE: 0.01652984321117401.
# Epoch #7
#   Metrics on training data:
#     MSE: 0.013562090694904327.
#   Metrics on testing data:
#     MSE: 0.014909537509083748.
# Epoch #8
#   Metrics on training data:
#     MSE: 0.01218927651643753.
#   Metrics on testing data:
#     MSE: 0.013499277643859386.
# Epoch #9
#   Metrics on training data:
#     MSE: 0.010982745327055454.
#   Metrics on testing data:
#     MSE: 0.012244561687111855.
# Epoch #10
#   Metrics on training data:
#     MSE: 0.009925320744514465.
#   Metrics on testing data:
#     MSE: 0.011133299209177494.
# Epoch #11
#   Metrics on training data:
#     MSE: 0.008989865891635418.
#   Metrics on testing data:
#     MSE: 0.010136757045984268.
# Epoch #12
#   Metrics on training data:
#     MSE: 0.008155244402587414.
#   Metrics on testing data:
#     MSE: 0.009231981821358204.
# Epoch #13
#   Metrics on training data:
#     MSE: 0.007389326114207506.
#   Metrics on testing data:
#     MSE: 0.008396830409765244.
# Epoch #14
#   Metrics on training data:
#     MSE: 0.00667465478181839.
#   Metrics on testing data:
#     MSE: 0.007622081786394119.
# Epoch #15
#   Metrics on training data:
#     MSE: 0.00600119074806571.
#   Metrics on testing data:
#     MSE: 0.006889958865940571.
# Epoch #16
#   Metrics on training data:
#     MSE: 0.005365691147744656.
#   Metrics on testing data:
#     MSE: 0.006190622691065073.
# Epoch #17
#   Metrics on training data:
#     MSE: 0.004771532490849495.
#   Metrics on testing data:
#     MSE: 0.005531611852347851.
# Epoch #18
#   Metrics on training data:
#     MSE: 0.004224765580147505.
#   Metrics on testing data:
#     MSE: 0.004917478654533625.
# Epoch #19
#   Metrics on training data:
#     MSE: 0.0037267939187586308.
#   Metrics on testing data:
#     MSE: 0.004353453870862722.
# Epoch #20
#   Metrics on training data:
#     MSE: 0.003280090633779764.
#   Metrics on testing data:
#     MSE: 0.003840038552880287.
# Epoch #21
#   Metrics on training data:
#     MSE: 0.002882429864257574.
#   Metrics on testing data:
#     MSE: 0.0033771672751754522.
# Epoch #22
#   Metrics on training data:
#     MSE: 0.0025307813193649054.
#   Metrics on testing data:
#     MSE: 0.002963798586279154.
# Epoch #23
#   Metrics on training data:
#     MSE: 0.0022234702482819557.
#   Metrics on testing data:
#     MSE: 0.0026006605476140976.
# Epoch #24
#   Metrics on training data:
#     MSE: 0.0019595420453697443.
#   Metrics on testing data:
#     MSE: 0.0022892109118402004.
# Epoch #25
#   Metrics on training data:
#     MSE: 0.0017373696900904179.
#   Metrics on testing data:
#     MSE: 0.002026872942224145.
# Epoch #26
#   Metrics on training data:
#     MSE: 0.0015511466190218925.
#   Metrics on testing data:
#     MSE: 0.0018072559032589197.
# Epoch #27
#   Metrics on training data:
#     MSE: 0.001394436345435679.
#   Metrics on testing data:
#     MSE: 0.0016225052531808615.
# Epoch #28
#   Metrics on training data:
#     MSE: 0.0012605206575244665.
#   Metrics on testing data:
#     MSE: 0.0014654226833954453.
# Epoch #29
#   Metrics on training data:
#     MSE: 0.0011424139374867082.
#   Metrics on testing data:
#     MSE: 0.0013277757680043578.
# Epoch #30
#   Metrics on training data:
#     MSE: 0.0010340369772166014.
#   Metrics on testing data:
#     MSE: 0.0012017927365377545.
# Epoch #31
#   Metrics on training data:
#     MSE: 0.0009304720442742109.
#   Metrics on testing data:
#     MSE: 0.0010825835634022951.
# Epoch #32
#   Metrics on training data:
#     MSE: 0.0008283961797133088.
#   Metrics on testing data:
#     MSE: 0.0009655887261033058.
# Epoch #33
#   Metrics on training data:
#     MSE: 0.0007270065834745765.
#   Metrics on testing data:
#     MSE: 0.0008501741103827953.
# Epoch #34
#   Metrics on training data:
#     MSE: 0.0006276250933296978.
#   Metrics on testing data:
#     MSE: 0.0007369201630353928.
# Epoch #35
#   Metrics on training data:
#     MSE: 0.0005330016138032079.
#   Metrics on testing data:
#     MSE: 0.0006285518757067621.
# Epoch #36
#   Metrics on training data:
#     MSE: 0.00044636725215241313.
#   Metrics on testing data:
#     MSE: 0.0005283409846015275.
# Epoch #37
#   Metrics on training data:
#     MSE: 0.0003700295346789062.
#   Metrics on testing data:
#     MSE: 0.000439227296737954.
# Epoch #38
#   Metrics on training data:
#     MSE: 0.00030426570447161794.
#   Metrics on testing data:
#     MSE: 0.0003617853799369186.
# Epoch #39
#   Metrics on training data:
#     MSE: 0.00024849825422279537.
#   Metrics on testing data:
#     MSE: 0.000295852601993829.
# Epoch #40
#   Metrics on training data:
#     MSE: 0.00020205463806632906.
#   Metrics on testing data:
#     MSE: 0.0002406727144261822.
# Epoch #41
#   Metrics on training data:
#     MSE: 0.00016377631982322782.
#   Metrics on testing data:
#     MSE: 0.00019491164130158722.
# Epoch #42
#   Metrics on training data:
#     MSE: 0.00013254355872049928.
#   Metrics on testing data:
#     MSE: 0.00015748849546071142.
# Epoch #43
#   Metrics on training data:
#     MSE: 0.00010727391054388136.
#   Metrics on testing data:
#     MSE: 0.000127148610772565.
# Epoch #44
#   Metrics on training data:
#     MSE: 8.689548849361017e-05.
#   Metrics on testing data:
#     MSE: 0.00010277226829202846.
# Epoch #45
#   Metrics on training data:
#     MSE: 7.049627311062068e-05.
#   Metrics on testing data:
#     MSE: 8.320406777784228e-05.
# Epoch #46
#   Metrics on training data:
#     MSE: 5.735435843234882e-05.
#   Metrics on testing data:
#     MSE: 6.755799404345453e-05.
# Epoch #47
#   Metrics on training data:
#     MSE: 4.682103099185042e-05.
#   Metrics on testing data:
#     MSE: 5.504791624844074e-05.
# Epoch #48
#   Metrics on training data:
#     MSE: 3.835244206129573e-05.
#   Metrics on testing data:
#     MSE: 4.501346847973764e-05.
# Epoch #49
#   Metrics on training data:
#     MSE: 3.153102079522796e-05.
#   Metrics on testing data:
#     MSE: 3.6935518437530845e-05.
# Epoch #50
#   Metrics on training data:
#     MSE: 2.6034975235234015e-05.
#   Metrics on testing data:
#     MSE: 3.043777178390883e-05.
# Epoch #51
#   Metrics on training data:
#     MSE: 2.157700691896025e-05.
#   Metrics on testing data:
#     MSE: 2.5193308829329908e-05.
# Epoch #52
#   Metrics on training data:
#     MSE: 1.7950736946659163e-05.
#   Metrics on testing data:
#     MSE: 2.0930014215991832e-05.
# Epoch #53
#   Metrics on training data:
#     MSE: 1.4993992408562917e-05.
#   Metrics on testing data:
#     MSE: 1.7451060557505116e-05.
# Epoch #54
#   Metrics on training data:
#     MSE: 1.2572447303682566e-05.
#   Metrics on testing data:
#     MSE: 1.4601998373109382e-05.
# Epoch #55
#   Metrics on training data:
#     MSE: 1.0579363333818037e-05.
#   Metrics on testing data:
#     MSE: 1.226095173478825e-05.
# Epoch #56
#   Metrics on training data:
#     MSE: 8.933779099606909e-06.
#   Metrics on testing data:
#     MSE: 1.0328708412998822e-05.
# Epoch #57
#   Metrics on training data:
#     MSE: 7.571193236799445e-06.
#   Metrics on testing data:
#     MSE: 8.733331924304366e-06.
# Epoch #58
#   Metrics on training data:
#     MSE: 6.439867320295889e-06.
#   Metrics on testing data:
#     MSE: 7.409498266497394e-06.
# Epoch #59
#   Metrics on training data:
#     MSE: 5.495378445630195e-06.
#   Metrics on testing data:
#     MSE: 6.308647243713494e-06.
# Epoch #60
#   Metrics on training data:
#     MSE: 4.705338596977526e-06.
#   Metrics on testing data:
#     MSE: 5.389624675444793e-06.
# Epoch #61
#   Metrics on training data:
#     MSE: 4.043215540150413e-06.
#   Metrics on testing data:
#     MSE: 4.620163053914439e-06.
# Epoch #62
#   Metrics on training data:
#     MSE: 3.4854333534894977e-06.
#   Metrics on testing data:
#     MSE: 3.972625563619658e-06.
# Epoch #63
#   Metrics on training data:
#     MSE: 3.013179366462282e-06.
#   Metrics on testing data:
#     MSE: 3.4257438983331667e-06.
# Epoch #64
#   Metrics on training data:
#     MSE: 2.6122993403987493e-06.
#   Metrics on testing data:
#     MSE: 2.9630573408212513e-06.
# Epoch #65
#   Metrics on training data:
#     MSE: 2.271329549330403e-06.
#   Metrics on testing data:
#     MSE: 2.570464403106598e-06.
# Epoch #66
#   Metrics on training data:
#     MSE: 1.9803546820185147e-06.
#   Metrics on testing data:
#     MSE: 2.2358560727298027e-06.
# Epoch #67
#   Metrics on training data:
#     MSE: 1.7312233921984443e-06.
#   Metrics on testing data:
#     MSE: 1.9498515939631034e-06.
# Epoch #68
#   Metrics on training data:
#     MSE: 1.517231680736586e-06.
#   Metrics on testing data:
#     MSE: 1.704708552097145e-06.
# Epoch #69
#   Metrics on training data:
#     MSE: 1.3328746035767836e-06.
#   Metrics on testing data:
#     MSE: 1.4940039818611694e-06.
# Epoch #70
#   Metrics on training data:
#     MSE: 1.1735303360183025e-06.
#   Metrics on testing data:
#     MSE: 1.31224544475117e-06.
# Epoch #71
#   Metrics on training data:
#     MSE: 1.035328523357748e-06.
#   Metrics on testing data:
#     MSE: 1.1550952194738784e-06.
# Epoch #72
#   Metrics on training data:
#     MSE: 9.150818414127571e-07.
#   Metrics on testing data:
#     MSE: 1.0186815870838473e-06.
# Epoch #73
#   Metrics on training data:
#     MSE: 8.104175890366605e-07.
#   Metrics on testing data:
#     MSE: 9.00219220056897e-07.
# Epoch #74
#   Metrics on training data:
#     MSE: 7.190106998677948e-07.
#   Metrics on testing data:
#     MSE: 7.970715500960068e-07.
# Epoch #75
#   Metrics on training data:
#     MSE: 6.390031330738566e-07.
#   Metrics on testing data:
#     MSE: 7.06987862031383e-07.
# Epoch #76
#   Metrics on training data:
#     MSE: 5.687786597263766e-07.
#   Metrics on testing data:
#     MSE: 6.280328648244904e-07.
# Epoch #77
#   Metrics on training data:
#     MSE: 5.071026407676982e-07.
#   Metrics on testing data:
#     MSE: 5.588099725173379e-07.
# Epoch #78
#   Metrics on training data:
#     MSE: 4.528147030669061e-07.
#   Metrics on testing data:
#     MSE: 4.980630592399393e-07.
# Epoch #79
#   Metrics on training data:
#     MSE: 4.049140045481181e-07.
#   Metrics on testing data:
#     MSE: 4.4465534188020683e-07.
# Epoch #80
#   Metrics on training data:
#     MSE: 3.6260428259993205e-07.
#   Metrics on testing data:
#     MSE: 3.9758378989063203e-07.
# Epoch #81
#   Metrics on training data:
#     MSE: 3.2518462944608473e-07.
#   Metrics on testing data:
#     MSE: 3.5601149761532724e-07.
# Epoch #82
#   Metrics on training data:
#     MSE: 2.9201274287515844e-07.
#   Metrics on testing data:
#     MSE: 3.191501889432402e-07.
# Epoch #83
#   Metrics on training data:
#     MSE: 2.6252911311530625e-07.
#   Metrics on testing data:
#     MSE: 2.864769044208515e-07.
# Epoch #84
#   Metrics on training data:
#     MSE: 2.363152731277296e-07.
#   Metrics on testing data:
#     MSE: 2.5747229415173933e-07.
# Epoch #85
#   Metrics on training data:
#     MSE: 2.1297050523116923e-07.
#   Metrics on testing data:
#     MSE: 2.316869824880996e-07.
# Epoch #86
#   Metrics on training data:
#     MSE: 1.921619912081951e-07.
#   Metrics on testing data:
#     MSE: 2.0870341188583552e-07.
# Epoch #87
#   Metrics on training data:
#     MSE: 1.7358171078285523e-07.
#   Metrics on testing data:
#     MSE: 1.8821474156993645e-07.
# Epoch #88
#   Metrics on training data:
#     MSE: 1.569687810842879e-07.
#   Metrics on testing data:
#     MSE: 1.699086737971811e-07.
# Epoch #89
#   Metrics on training data:
#     MSE: 1.42085795573621e-07.
#   Metrics on testing data:
#     MSE: 1.5352455307038326e-07.
# Epoch #90
#   Metrics on training data:
#     MSE: 1.2873273647073802e-07.
#   Metrics on testing data:
#     MSE: 1.3885131977531273e-07.
# Epoch #91
#   Metrics on training data:
#     MSE: 1.1673341049345254e-07.
#   Metrics on testing data:
#     MSE: 1.2569562102271448e-07.
# Epoch #92
#   Metrics on training data:
#     MSE: 1.0594201427238659e-07.
#   Metrics on testing data:
#     MSE: 1.1388785026156256e-07.
# Epoch #93
#   Metrics on training data:
#     MSE: 9.623036589800904e-08.
#   Metrics on testing data:
#     MSE: 1.0328329835829209e-07.
# Epoch #94
#   Metrics on training data:
#     MSE: 8.747807100917271e-08.
#   Metrics on testing data:
#     MSE: 9.374456055866176e-08.
# Epoch #95
#   Metrics on training data:
#     MSE: 7.958323777756959e-08.
#   Metrics on testing data:
#     MSE: 8.515399940733914e-08.
# Epoch #96
#   Metrics on training data:
#     MSE: 7.245328248473015e-08.
#   Metrics on testing data:
#     MSE: 7.741238050584798e-08.
# Epoch #97
#   Metrics on training data:
#     MSE: 6.601126045779893e-08.
#   Metrics on testing data:
#     MSE: 7.042983440896933e-08.
# Epoch #98
#   Metrics on training data:
#     MSE: 6.017975806571485e-08.
#   Metrics on testing data:
#     MSE: 6.411930542071786e-08.
# Epoch #99
#   Metrics on training data:
#     MSE: 5.489834009608785e-08.
#   Metrics on testing data:
#     MSE: 5.841175010345978e-08.
# Epoch #100
#   Metrics on training data:
#     MSE: 5.011160908452439e-08.
#   Metrics on testing data:
#     MSE: 5.3247699582925634e-08.
# Epoch #101
#   Metrics on training data:
#     MSE: 4.576864043315254e-08.
#   Metrics on testing data:
#     MSE: 4.857006885572446e-08.
# Epoch #102
#   Metrics on training data:
#     MSE: 4.182538049235518e-08.
#   Metrics on testing data:
#     MSE: 4.433034561657223e-08.
# Epoch #103
#   Metrics on training data:
#     MSE: 3.824372640792717e-08.
#   Metrics on testing data:
#     MSE: 4.0486082042434646e-08.
# Epoch #104
#   Metrics on training data:
#     MSE: 3.4987508001904644e-08.
#   Metrics on testing data:
#     MSE: 3.699647876942436e-08.
# Epoch #105
#   Metrics on training data:
#     MSE: 3.202541520863633e-08.
#   Metrics on testing data:
#     MSE: 3.382650604066839e-08.
# Epoch #106
#   Metrics on training data:
#     MSE: 2.93279924790113e-08.
#   Metrics on testing data:
#     MSE: 3.094464773312211e-08.
# Epoch #107
#   Metrics on training data:
#     MSE: 2.6868562486015435e-08.
#   Metrics on testing data:
#     MSE: 2.831726497731779e-08.
# Epoch #108
#   Metrics on training data:
#     MSE: 2.4626436001540242e-08.
#   Metrics on testing data:
#     MSE: 2.5925405822135872e-08.
# Epoch #109
#   Metrics on training data:
#     MSE: 2.258105524788334e-08.
#   Metrics on testing data:
#     MSE: 2.3746398625235088e-08.
# Epoch #110
#   Metrics on training data:
#     MSE: 2.0714324477921764e-08.
#   Metrics on testing data:
#     MSE: 2.1759975155077882e-08.
# Epoch #111
#   Metrics on training data:
#     MSE: 1.900968449319862e-08.
#   Metrics on testing data:
#     MSE: 1.9946549301153027e-08.
# Epoch #112
#   Metrics on training data:
#     MSE: 1.7452418177299478e-08.
#   Metrics on testing data:
#     MSE: 1.829220508398066e-08.
# Epoch #113
#   Metrics on training data:
#     MSE: 1.6028856464345154e-08.
#   Metrics on testing data:
#     MSE: 1.6781902090201584e-08.
# Epoch #114
#   Metrics on training data:
#     MSE: 1.472604704844116e-08.
#   Metrics on testing data:
#     MSE: 1.5401395714320643e-08.
# Epoch #115
#   Metrics on training data:
#     MSE: 1.3533605347504363e-08.
#   Metrics on testing data:
#     MSE: 1.4139625470477313e-08.
# Epoch #116
#   Metrics on training data:
#     MSE: 1.2441731200851791e-08.
#   Metrics on testing data:
#     MSE: 1.2985666764109283e-08.
# Epoch #117
#   Metrics on training data:
#     MSE: 1.144158101595849e-08.
#   Metrics on testing data:
#     MSE: 1.1929875753935448e-08.
# Epoch #118
#   Metrics on training data:
#     MSE: 1.052528286749066e-08.
#   Metrics on testing data:
#     MSE: 1.0963815633147078e-08.
# Epoch #119
#   Metrics on training data:
#     MSE: 9.685059865205403e-09.
#   Metrics on testing data:
#     MSE: 1.0078929690848781e-08.
# Epoch #120
#   Metrics on training data:
#     MSE: 8.914529558978757e-09.
#   Metrics on testing data:
#     MSE: 9.268201317524927e-09.
# Epoch #121
#   Metrics on training data:
#     MSE: 8.207687862693547e-09.
#   Metrics on testing data:
#     MSE: 8.52515658067432e-09.
# Epoch #122
#   Metrics on training data:
#     MSE: 7.559027181969213e-09.
#   Metrics on testing data:
#     MSE: 7.844184857219716e-09.
# Epoch #123
#   Metrics on training data:
#     MSE: 6.963302823237427e-09.
#   Metrics on testing data:
#     MSE: 7.219271846992115e-09.
# Epoch #124
#   Metrics on training data:
#     MSE: 6.416092102057291e-09.
#   Metrics on testing data:
#     MSE: 6.646221351047643e-09.
# Epoch #125
#   Metrics on training data:
#     MSE: 5.913151301939479e-09.
#   Metrics on testing data:
#     MSE: 6.119696305262323e-09.
# Epoch #126
#   Metrics on training data:
#     MSE: 5.450978335375112e-09.
#   Metrics on testing data:
#     MSE: 5.636590749702464e-09.
# Epoch #127
#   Metrics on training data:
#     MSE: 5.026088878423707e-09.
#   Metrics on testing data:
#     MSE: 5.192684948696069e-09.
# Epoch #128
#   Metrics on training data:
#     MSE: 4.6352583993325425e-09.
#   Metrics on testing data:
#     MSE: 4.784819207515056e-09.
# Epoch #129
#   Metrics on training data:
#     MSE: 4.275855225444047e-09.
#   Metrics on testing data:
#     MSE: 4.410143805699818e-09.
# Epoch #130
#   Metrics on training data:
#     MSE: 3.94444876761213e-09.
#   Metrics on testing data:
#     MSE: 4.06534894636934e-09.
# Epoch #131
#   Metrics on training data:
#     MSE: 3.6392178159871946e-09.
#   Metrics on testing data:
#     MSE: 3.747995247493918e-09.
# Epoch #132
#   Metrics on training data:
#     MSE: 3.3583360536937334e-09.
#   Metrics on testing data:
#     MSE: 3.4563694129019495e-09.
# Epoch #133
#   Metrics on training data:
#     MSE: 3.099692502672724e-09.
#   Metrics on testing data:
#     MSE: 3.1877971373717173e-09.
# Epoch #134
#   Metrics on training data:
#     MSE: 2.861362258244071e-09.
#   Metrics on testing data:
#     MSE: 2.9407210000442774e-09.
# Epoch #135
#   Metrics on training data:
#     MSE: 2.6417823484337077e-09.
#   Metrics on testing data:
#     MSE: 2.7132405211460764e-09.
# Epoch #136
#   Metrics on training data:
#     MSE: 2.4394135600402933e-09.
#   Metrics on testing data:
#     MSE: 2.5038422446499453e-09.
# Epoch #137
#   Metrics on training data:
#     MSE: 2.2528616749895036e-09.
#   Metrics on testing data:
#     MSE: 2.3108497337887e-09.
# Epoch #138
#   Metrics on training data:
#     MSE: 2.0808337275468602e-09.
#   Metrics on testing data:
#     MSE: 2.133057286357598e-09.
# Epoch #139
#   Metrics on training data:
#     MSE: 1.9222359259885025e-09.
#   Metrics on testing data:
#     MSE: 1.9692139030524913e-09.
# Epoch #140
#   Metrics on training data:
#     MSE: 1.7758294834635535e-09.
#   Metrics on testing data:
#     MSE: 1.8180849048476944e-09.
# Epoch #141
#   Metrics on training data:
#     MSE: 1.6408447933713433e-09.
#   Metrics on testing data:
#     MSE: 1.6789329926325536e-09.
# Epoch #142
#   Metrics on training data:
#     MSE: 1.5163335032042369e-09.
#   Metrics on testing data:
#     MSE: 1.550671036021356e-09.
# Epoch #143
#   Metrics on training data:
#     MSE: 1.401286642277455e-09.
#   Metrics on testing data:
#     MSE: 1.4321520636073615e-09.
# Epoch #144
#   Metrics on training data:
#     MSE: 1.2952291461587606e-09.
#   Metrics on testing data:
#     MSE: 1.3230623263638108e-09.
# Epoch #145
#   Metrics on training data:
#     MSE: 1.1973342317617153e-09.
#   Metrics on testing data:
#     MSE: 1.2223891898699435e-09.
# Epoch #146
#   Metrics on training data:
#     MSE: 1.106965297203999e-09.
#   Metrics on testing data:
#     MSE: 1.1295427926327761e-09.
# Epoch #147
#   Metrics on training data:
#     MSE: 1.0234667557895705e-09.
#   Metrics on testing data:
#     MSE: 1.0438171438309496e-09.
# Epoch #148
#   Metrics on training data:
#     MSE: 9.463733130488095e-10.
#   Metrics on testing data:
#     MSE: 9.646744514313355e-10.
# Epoch #149
#   Metrics on training data:
#     MSE: 8.75140349076986e-10.
#   Metrics on testing data:
#     MSE: 8.916256621915863e-10.
# Epoch #150
#   Metrics on training data:
#     MSE: 8.093533065967051e-10.
#   Metrics on testing data:
#     MSE: 8.242137528036153e-10.
# Epoch #151
#   Metrics on training data:
#     MSE: 7.48620720969484e-10.
#   Metrics on testing data:
#     MSE: 7.619853081841654e-10.
# Epoch #152
#   Metrics on training data:
#     MSE: 6.92459978246518e-10.
#   Metrics on testing data:
#     MSE: 7.044868022276773e-10.
# Epoch #153
#   Metrics on training data:
#     MSE: 6.405812547072287e-10.
#   Metrics on testing data:
#     MSE: 6.514327965945199e-10.
# Epoch #154
#   Metrics on training data:
#     MSE: 5.926140689282988e-10.
#   Metrics on testing data:
#     MSE: 6.023561094359309e-10.
# Epoch #155
#   Metrics on training data:
#     MSE: 5.483188902921654e-10.
#   Metrics on testing data:
#     MSE: 5.571591521480457e-10.
# Epoch #156
#   Metrics on training data:
#     MSE: 5.073382269848992e-10.
#   Metrics on testing data:
#     MSE: 5.152303583777496e-10.
# Epoch #157
#   Metrics on training data:
#     MSE: 4.694283295414436e-10.
#   Metrics on testing data:
#     MSE: 4.765278727170141e-10.
# Epoch #158
#   Metrics on training data:
#     MSE: 4.3442532904336417e-10.
#   Metrics on testing data:
#     MSE: 4.407925413563163e-10.
# Epoch #159
#   Metrics on training data:
#     MSE: 4.020471178201035e-10.
#   Metrics on testing data:
#     MSE: 4.077720938688856e-10.
# Epoch #160
#   Metrics on training data:
#     MSE: 3.721368491138577e-10.
#   Metrics on testing data:
#     MSE: 3.772660239764747e-10.
# Epoch #161
#   Metrics on training data:
#     MSE: 3.4444724850146713e-10.
#   Metrics on testing data:
#     MSE: 3.49065110150093e-10.
# Epoch #162
#   Metrics on training data:
#     MSE: 3.1883309881131083e-10.
#   Metrics on testing data:
#     MSE: 3.229849443453503e-10.
# Epoch #163
#   Metrics on training data:
#     MSE: 2.95142743578225e-10.
#   Metrics on testing data:
#     MSE: 2.9889604680199966e-10.
# Epoch #164
#   Metrics on training data:
#     MSE: 2.732369885904973e-10.
#   Metrics on testing data:
#     MSE: 2.766013529331701e-10.
# Epoch #165
#   Metrics on training data:
#     MSE: 2.529667586514961e-10.
#   Metrics on testing data:
#     MSE: 2.559858158779349e-10.
# Epoch #166
#   Metrics on training data:
#     MSE: 2.341899174584938e-10.
#   Metrics on testing data:
#     MSE: 2.368965856813787e-10.
# Epoch #167
#   Metrics on training data:
#     MSE: 2.168489693366027e-10.
#   Metrics on testing data:
#     MSE: 2.192553638646899e-10.
# Epoch #168
#   Metrics on training data:
#     MSE: 2.0078969042991446e-10.
#   Metrics on testing data:
#     MSE: 2.0295293223782096e-10.
# Epoch #169
#   Metrics on training data:
#     MSE: 1.8592438699727154e-10.
#   Metrics on testing data:
#     MSE: 1.8785956124034442e-10.
# Epoch #170
#   Metrics on training data:
#     MSE: 1.7218759751358448e-10.
#   Metrics on testing data:
#     MSE: 1.7392295936780044e-10.
# Epoch #171
#   Metrics on training data:
#     MSE: 1.5945691989038835e-10.
#   Metrics on testing data:
#     MSE: 1.6100439037547432e-10.
# Epoch #172
#   Metrics on training data:
#     MSE: 1.4766025902002156e-10.
#   Metrics on testing data:
#     MSE: 1.4906374745660145e-10.
# Epoch #173
#   Metrics on training data:
#     MSE: 1.3674957000109345e-10.
#   Metrics on testing data:
#     MSE: 1.3800884046677453e-10.
# Epoch #174
#   Metrics on training data:
#     MSE: 1.2665030135750044e-10.
#   Metrics on testing data:
#     MSE: 1.2779023672582213e-10.
# Epoch #175
#   Metrics on training data:
#     MSE: 1.1731488003263735e-10.
#   Metrics on testing data:
#     MSE: 1.183423220529889e-10.
# Epoch #176
#   Metrics on training data:
#     MSE: 1.0866268301823467e-10.
#   Metrics on testing data:
#     MSE: 1.0956054813382465e-10.
# Epoch #177
#   Metrics on training data:
#     MSE: 1.0064168942669482e-10.
#   Metrics on testing data:
#     MSE: 1.0145655149340627e-10.
# Epoch #178
#   Metrics on training data:
#     MSE: 9.322673882872223e-11.
#   Metrics on testing data:
#     MSE: 9.395251243660141e-11.
# Epoch #179
#   Metrics on training data:
#     MSE: 8.634672143958966e-11.
#   Metrics on testing data:
#     MSE: 8.699787418242622e-11.
# Epoch #180
#   Metrics on training data:
#     MSE: 7.999938905767223e-11.
#   Metrics on testing data:
#     MSE: 8.057608746891987e-11.
# Epoch #181
#   Metrics on training data:
#     MSE: 7.4108268133255e-11.
#   Metrics on testing data:
#     MSE: 7.462175322103803e-11.
# Epoch #182
#   Metrics on training data:
#     MSE: 6.866603813326932e-11.
#   Metrics on testing data:
#     MSE: 6.912510147616402e-11.
# Epoch #183
#   Metrics on training data:
#     MSE: 6.360684895456714e-11.
#   Metrics on testing data:
#     MSE: 6.401894986352019e-11.
# Epoch #184
#   Metrics on training data:
#     MSE: 5.893217858154998e-11.
#   Metrics on testing data:
#     MSE: 5.928708218805312e-11.
# Epoch #185
#   Metrics on training data:
#     MSE: 5.4605913540894946e-11.
#   Metrics on testing data:
#     MSE: 5.4924530201727606e-11.
# Epoch #186
#   Metrics on training data:
#     MSE: 5.059277302654763e-11.
#   Metrics on testing data:
#     MSE: 5.08876100979716e-11.
# Epoch #187
#   Metrics on training data:
#     MSE: 4.6878084747348225e-11.
#   Metrics on testing data:
#     MSE: 4.714425030916125e-11.
# Epoch #188
#   Metrics on training data:
#     MSE: 4.3431661045367775e-11.
#   Metrics on testing data:
#     MSE: 4.3658836962334746e-11.
# Epoch #189
#   Metrics on training data:
#     MSE: 4.024449176687206e-11.
#   Metrics on testing data:
#     MSE: 4.0450989780005386e-11.
# Epoch #190
#   Metrics on training data:
#     MSE: 3.730114828126574e-11.
#   Metrics on testing data:
#     MSE: 3.748815147197604e-11.
# Epoch #191
#   Metrics on training data:
#     MSE: 3.4565027923205704e-11.
#   Metrics on testing data:
#     MSE: 3.471832890622473e-11.
# Epoch #192
#   Metrics on training data:
#     MSE: 3.203290757647359e-11.
#   Metrics on testing data:
#     MSE: 3.217186933524019e-11.
# Epoch #193
#   Metrics on training data:
#     MSE: 2.9682818702969627e-11.
#   Metrics on testing data:
#     MSE: 2.981288826919837e-11.
# Epoch #194
#   Metrics on training data:
#     MSE: 2.7512450651023812e-11.
#   Metrics on testing data:
#     MSE: 2.7624598789022237e-11.
# Epoch #195
#   Metrics on training data:
#     MSE: 2.549306772625659e-11.
#   Metrics on testing data:
#     MSE: 2.559044642858055e-11.
# Epoch #196
#   Metrics on training data:
#     MSE: 2.3622531014622083e-11.
#   Metrics on testing data:
#     MSE: 2.371262734779389e-11.
# Epoch #197
#   Metrics on training data:
#     MSE: 2.1887592432934255e-11.
#   Metrics on testing data:
#     MSE: 2.196685888744554e-11.
# Epoch #198
#   Metrics on training data:
#     MSE: 2.0277907825105856e-11.
#   Metrics on testing data:
#     MSE: 2.0349472107383804e-11.
# Epoch #199
#   Metrics on training data:
#     MSE: 1.8794892725493284e-11.
#   Metrics on testing data:
#     MSE: 1.885390628342254e-11.
# Epoch #200
#   Metrics on training data:
#     MSE: 1.7420086206865193e-11.
#   Metrics on testing data:
#     MSE: 1.7472944965901682e-11.
# Epoch #201
#   Metrics on training data:
#     MSE: 1.6147361225904433e-11.
#   Metrics on testing data:
#     MSE: 1.618982031770244e-11.
# Epoch #202
#   Metrics on training data:
#     MSE: 1.4963500924447537e-11.
#   Metrics on testing data:
#     MSE: 1.499874009713853e-11.
# Epoch #203
#   Metrics on training data:
#     MSE: 1.3867210331419688e-11.
#   Metrics on testing data:
#     MSE: 1.3900942896771795e-11.
# Epoch #204
#   Metrics on training data:
#     MSE: 1.2858270871662913e-11.
#   Metrics on testing data:
#     MSE: 1.2887155752261403e-11.
# Epoch #205
#   Metrics on training data:
#     MSE: 1.1918692595369595e-11.
#   Metrics on testing data:
#     MSE: 1.1943236330469453e-11.
# Epoch #206
#   Metrics on training data:
#     MSE: 1.1050459158834514e-11.
#   Metrics on testing data:
#     MSE: 1.1070951447256228e-11.
# Epoch #207
#   Metrics on training data:
#     MSE: 1.024184122927485e-11.
#   Metrics on testing data:
#     MSE: 1.0259315098848365e-11.
# Epoch #208
#   Metrics on training data:
#     MSE: 9.496300447386918e-12.
#   Metrics on testing data:
#     MSE: 9.507800796670907e-12.
# Epoch #209
#   Metrics on training data:
#     MSE: 8.805129368683051e-12.
#   Metrics on testing data:
#     MSE: 8.813544512265015e-12.
# Epoch #210
#   Metrics on training data:
#     MSE: 8.165255797887294e-12.
#   Metrics on testing data:
#     MSE: 8.171366361331422e-12.
# Epoch #211
#   Metrics on training data:
#     MSE: 7.573395903459623e-12.
#   Metrics on testing data:
#     MSE: 7.577867153218953e-12.
# Epoch #212
#   Metrics on training data:
#     MSE: 7.0239977029151746e-12.
#   Metrics on testing data:
#     MSE: 7.030127781998408e-12.
# Epoch #213
#   Metrics on training data:
#     MSE: 6.514065328810936e-12.
#   Metrics on testing data:
#     MSE: 6.517210816153751e-12.
# Epoch #214
#   Metrics on training data:
#     MSE: 6.042147684959254e-12.
#   Metrics on testing data:
#     MSE: 6.0463569914737114e-12.
# Epoch #215
#   Metrics on training data:
#     MSE: 5.604192457320245e-12.
#   Metrics on testing data:
#     MSE: 5.607291974490947e-12.
# Epoch #216
#   Metrics on training data:
#     MSE: 5.201227035872558e-12.
#   Metrics on testing data:
#     MSE: 5.2031820692299835e-12.
# Epoch #217
#   Metrics on training data:
#     MSE: 4.82914706487203e-12.
#   Metrics on testing data:
#     MSE: 4.830044350589979e-12.
# Epoch #218
#   Metrics on training data:
#     MSE: 4.482211910655787e-12.
#   Metrics on testing data:
#     MSE: 4.482337678107795e-12.
# Epoch #219
#   Metrics on training data:
#     MSE: 4.163421777475529e-12.
#   Metrics on testing data:
#     MSE: 4.164368069131674e-12.
# Epoch #220
#   Metrics on training data:
#     MSE: 3.865007272563226e-12.
#   Metrics on testing data:
#     MSE: 3.86645836875088e-12.
# Epoch #221
#   Metrics on training data:
#     MSE: 3.5888265016020826e-12.
#   Metrics on testing data:
#     MSE: 3.5902693578532263e-12.
# Epoch #222
#   Metrics on training data:
#     MSE: 3.3345045474808543e-12.
#   Metrics on testing data:
#     MSE: 3.3359703888180547e-12.
# Epoch #223
#   Metrics on training data:
#     MSE: 3.0982781444588436e-12.
#   Metrics on testing data:
#     MSE: 3.1004357067820898e-12.
# Epoch #224
#   Metrics on training data:
#     MSE: 2.8776642527206242e-12.
#   Metrics on testing data:
#     MSE: 2.879339561917549e-12.
# Epoch #225
#   Metrics on training data:
#     MSE: 2.6725622583045894e-12.
#   Metrics on testing data:
#     MSE: 2.675209012648061e-12.
# Epoch #226
#   Metrics on training data:
#     MSE: 2.485374319544098e-12.
#   Metrics on testing data:
#     MSE: 2.488360646007992e-12.
# Epoch #227
#   Metrics on training data:
#     MSE: 2.3092734321994435e-12.
#   Metrics on testing data:
#     MSE: 2.313671173051479e-12.
# Epoch #228
#   Metrics on training data:
#     MSE: 2.146633131666631e-12.
#   Metrics on testing data:
#     MSE: 2.150709514994742e-12.
# Epoch #229
#   Metrics on training data:
#     MSE: 1.9957330059383604e-12.
#   Metrics on testing data:
#     MSE: 1.9991001042052314e-12.
# Epoch #230
#   Metrics on training data:
#     MSE: 1.8564080394439797e-12.
#   Metrics on testing data:
#     MSE: 1.859875101151154e-12.
# Epoch #231
#   Metrics on training data:
#     MSE: 1.7273790904603903e-12.
#   Metrics on testing data:
#     MSE: 1.7314006131585735e-12.
# Epoch #232
#   Metrics on training data:
#     MSE: 1.609467008452381e-12.
#   Metrics on testing data:
#     MSE: 1.6113598086051062e-12.
# Epoch #233
#   Metrics on training data:
#     MSE: 1.4997948629552615e-12.
#   Metrics on testing data:
#     MSE: 1.5022590376528866e-12.
# Epoch #234
#   Metrics on training data:
#     MSE: 1.3996745385977394e-12.
#   Metrics on testing data:
#     MSE: 1.4013941916635186e-12.
# Epoch #235
#   Metrics on training data:
#     MSE: 1.304999294390874e-12.
#   Metrics on testing data:
#     MSE: 1.3062362606494626e-12.
# Epoch #236
#   Metrics on training data:
#     MSE: 1.2183153791367474e-12.
#   Metrics on testing data:
#     MSE: 1.2201326103980503e-12.
# Epoch #237
#   Metrics on training data:
#     MSE: 1.1381679019401014e-12.
#   Metrics on testing data:
#     MSE: 1.1406960445659031e-12.
# Epoch #238
#   Metrics on training data:
#     MSE: 1.0648797382079023e-12.
#   Metrics on testing data:
#     MSE: 1.0665204613555246e-12.
# Epoch #239
#   Metrics on training data:
#     MSE: 9.958013146710298e-13.
#   Metrics on testing data:
#     MSE: 9.983092911364233e-13.
# Epoch #240
#   Metrics on training data:
#     MSE: 9.317194368460568e-13.
#   Metrics on testing data:
#     MSE: 9.343776837325568e-13.
# Epoch #241
#   Metrics on training data:
#     MSE: 8.730667556099136e-13.
#   Metrics on testing data:
#     MSE: 8.760580694038012e-13.
# Epoch #242
#   Metrics on training data:
#     MSE: 8.185756759926388e-13.
#   Metrics on testing data:
#     MSE: 8.222010854271045e-13.
# Epoch #243
#   Metrics on training data:
#     MSE: 7.685318852666823e-13.
#   Metrics on testing data:
#     MSE: 7.720822137007033e-13.
# Epoch #244
#   Metrics on training data:
#     MSE: 7.219695761367939e-13.
#   Metrics on testing data:
#     MSE: 7.262981991003337e-13.
# Epoch #245
#   Metrics on training data:
#     MSE: 6.790476384313515e-13.
#   Metrics on testing data:
#     MSE: 6.838041417822627e-13.
# Epoch #246
#   Metrics on training data:
#     MSE: 6.393529369125295e-13.
#   Metrics on testing data:
#     MSE: 6.436974434378961e-13.
# Epoch #247
#   Metrics on training data:
#     MSE: 6.02289702486547e-13.
#   Metrics on testing data:
#     MSE: 6.087055230523386e-13.
# Epoch #248
#   Metrics on training data:
#     MSE: 5.683219194731193e-13.
#   Metrics on testing data:
#     MSE: 5.752598918051799e-13.
# Epoch #249
#   Metrics on training data:
#     MSE: 5.372586598696716e-13.
#   Metrics on testing data:
#     MSE: 5.443320490530756e-13.
# Epoch #250
#   Metrics on training data:
#     MSE: 5.07733720518655e-13.
#   Metrics on testing data:
#     MSE: 5.150765881520303e-13.
# Epoch #251
#   Metrics on training data:
#     MSE: 4.808466450532956e-13.
#   Metrics on testing data:
#     MSE: 4.881871274418914e-13.
# Epoch #252
#   Metrics on training data:
#     MSE: 4.558561102381564e-13.
#   Metrics on testing data:
#     MSE: 4.641042324754485e-13.
# Epoch #253
#   Metrics on training data:
#     MSE: 4.3317454657965104e-13.
#   Metrics on testing data:
#     MSE: 4.410951855507439e-13.
# Epoch #254
#   Metrics on training data:
#     MSE: 4.122152651771932e-13.
#   Metrics on testing data:
#     MSE: 4.207804352347744e-13.
# Epoch #255
#   Metrics on training data:
#     MSE: 3.9309563091595445e-13.
#   Metrics on testing data:
#     MSE: 4.012946930049416e-13.
# Epoch #256
#   Metrics on training data:
#     MSE: 3.754965902016266e-13.
#   Metrics on testing data:
#     MSE: 3.8422607109844797e-13.
# Epoch #257
#   Metrics on training data:
#     MSE: 3.593093162411465e-13.
#   Metrics on testing data:
#     MSE: 3.680996750899529e-13.
# Epoch #258
#   Metrics on training data:
#     MSE: 3.4448453204577456e-13.
#   Metrics on testing data:
#     MSE: 3.5308634813678574e-13.
# Epoch #259
#   Metrics on training data:
#     MSE: 3.307916278134232e-13.
#   Metrics on testing data:
#     MSE: 3.394682538543359e-13.
# Epoch #260
#   Metrics on training data:
#     MSE: 3.1806233536692263e-13.
#   Metrics on testing data:
#     MSE: 3.273776378025922e-13.
# Epoch #261
#   Metrics on training data:
#     MSE: 3.064947655482403e-13.
#   Metrics on testing data:
#     MSE: 3.1550386218534565e-13.
# Epoch #262
#   Metrics on training data:
#     MSE: 2.956435009998648e-13.
#   Metrics on testing data:
#     MSE: 3.0470458513114085e-13.
# Epoch #263
#   Metrics on training data:
#     MSE: 2.851671806677891e-13.
#   Metrics on testing data:
#     MSE: 2.9440485422790874e-13.
# Epoch #264
#   Metrics on training data:
#     MSE: 2.753874873365897e-13.
#   Metrics on testing data:
#     MSE: 2.851124555631329e-13.
# Epoch #265
#   Metrics on training data:
#     MSE: 2.6670758158410524e-13.
#   Metrics on testing data:
#     MSE: 2.763859020121773e-13.
# Epoch #266
#   Metrics on training data:
#     MSE: 2.588819187233221e-13.
#   Metrics on testing data:
#     MSE: 2.689571926717954e-13.
# Epoch #267
#   Metrics on training data:
#     MSE: 2.514203038470053e-13.
#   Metrics on testing data:
#     MSE: 2.615410871816687e-13.
# Epoch #268
#   Metrics on training data:
#     MSE: 2.446348787606134e-13.
#   Metrics on testing data:
#     MSE: 2.551228813710976e-13.
# Epoch #269
#   Metrics on training data:
#     MSE: 2.380895502453184e-13.
#   Metrics on testing data:
#     MSE: 2.483845648691002e-13.
# Epoch #270
#   Metrics on training data:
#     MSE: 2.324562254924639e-13.
#   Metrics on testing data:
#     MSE: 2.427527308942329e-13.
# Epoch #271
#   Metrics on training data:
#     MSE: 2.2721024551825703e-13.
#   Metrics on testing data:
#     MSE: 2.374001331888892e-13.
# Epoch #272
#   Metrics on training data:
#     MSE: 2.2234933349813552e-13.
#   Metrics on testing data:
#     MSE: 2.3234533871527296e-13.
# Epoch #273
#   Metrics on training data:
#     MSE: 2.1768910730014107e-13.
#   Metrics on testing data:
#     MSE: 2.2772202960125165e-13.
# Epoch #274
#   Metrics on training data:
#     MSE: 2.1383484989211804e-13.
#   Metrics on testing data:
#     MSE: 2.2376935374102125e-13.
# Epoch #275
#   Metrics on training data:
#     MSE: 2.0989195895649432e-13.
#   Metrics on testing data:
#     MSE: 2.202699963616342e-13.
# Epoch #276
#   Metrics on training data:
#     MSE: 2.0664909670606302e-13.
#   Metrics on testing data:
#     MSE: 2.1709599450168288e-13.
# Epoch #277
#   Metrics on training data:
#     MSE: 2.037733453112353e-13.
#   Metrics on testing data:
#     MSE: 2.1423200670042664e-13.
# Epoch #278
#   Metrics on training data:
#     MSE: 2.0071912068628933e-13.
#   Metrics on testing data:
#     MSE: 2.1075777570638693e-13.
# Epoch #279
#   Metrics on training data:
#     MSE: 1.9812622408573594e-13.
#   Metrics on testing data:
#     MSE: 2.0854855114962184e-13.
# Epoch #280
#   Metrics on training data:
#     MSE: 1.957844558133845e-13.
#   Metrics on testing data:
#     MSE: 2.0590197298900326e-13.
# Epoch #281
#   Metrics on training data:
#     MSE: 1.934094160868649e-13.
#   Metrics on testing data:
#     MSE: 2.0336790790883436e-13.
# Epoch #282
#   Metrics on training data:
#     MSE: 1.916073501034496e-13.
#   Metrics on testing data:
#     MSE: 2.0181226752669784e-13.
# Epoch #283
#   Metrics on training data:
#     MSE: 1.8962282644693212e-13.
#   Metrics on testing data:
#     MSE: 2.0007515880594157e-13.
# Epoch #284
#   Metrics on training data:
#     MSE: 1.8794712422672e-13.
#   Metrics on testing data:
#     MSE: 1.9854913069564106e-13.
# Epoch #285
#   Metrics on training data:
#     MSE: 1.8609049576897435e-13.
#   Metrics on testing data:
#     MSE: 1.9623456234529185e-13.
# Epoch #286
#   Metrics on training data:
#     MSE: 1.8454361031938066e-13.
#   Metrics on testing data:
#     MSE: 1.9467161715101822e-13.
# Epoch #287
#   Metrics on training data:
#     MSE: 1.8325176987833702e-13.
#   Metrics on testing data:
#     MSE: 1.9369319245298583e-13.
# Epoch #288
#   Metrics on training data:
#     MSE: 1.818948366493628e-13.
#   Metrics on testing data:
#     MSE: 1.9197802527369523e-13.
# Epoch #289
#   Metrics on training data:
#     MSE: 1.8066062155378676e-13.
#   Metrics on testing data:
#     MSE: 1.910103206246433e-13.
# Epoch #290
#   Metrics on training data:
#     MSE: 1.7948793493149928e-13.
#   Metrics on testing data:
#     MSE: 1.8976870584924005e-13.
# Epoch #291
#   Metrics on training data:
#     MSE: 1.7831035584690846e-13.
#   Metrics on testing data:
#     MSE: 1.8877720296250206e-13.
# Epoch #292
#   Metrics on training data:
#     MSE: 1.7709625270163204e-13.
#   Metrics on testing data:
#     MSE: 1.8741104046253454e-13.
# Epoch #293
#   Metrics on training data:
#     MSE: 1.7605772254566249e-13.
#   Metrics on testing data:
#     MSE: 1.8607831204706105e-13.
# Epoch #294
#   Metrics on training data:
#     MSE: 1.7515124821430167e-13.
#   Metrics on testing data:
#     MSE: 1.8509387002697136e-13.
# Epoch #295
#   Metrics on training data:
#     MSE: 1.7402481636719785e-13.
#   Metrics on testing data:
#     MSE: 1.8421963715771483e-13.
# Epoch #296
#   Metrics on training data:
#     MSE: 1.7309808100773871e-13.
#   Metrics on testing data:
#     MSE: 1.8322177813574064e-13.
# Epoch #297
#   Metrics on training data:
#     MSE: 1.7232431302229012e-13.
#   Metrics on testing data:
#     MSE: 1.8264201457653118e-13.
# Epoch #298
#   Metrics on training data:
#     MSE: 1.7142614639007597e-13.
#   Metrics on testing data:
#     MSE: 1.8182337417366884e-13.
# Epoch #299
#   Metrics on training data:
#     MSE: 1.7051724615635422e-13.
#   Metrics on testing data:
#     MSE: 1.809664478815906e-13.

# %%
import measurements
lr = 50
batch_size = 200
phys_bs = 5000
num_epochs = 300


msrs = measurements.Measurement(verbose=True)
msrs.add_train_recorder('MSE', phys_bs, verbose=True)
msrs.add_test_recorder('MSE', phys_bs, verbose=True)

lora_t = MLPLoRA.get_mlp_lora([fixed_W1, fixed_W2], [10, 10], 'relu')
lora_t = (lora_t[0].cuda(), lora_t[1])
loss_fn = torch.nn.MSELoss()
opt_constr = lambda params: torch.optim.SGD(params, lr=10)

num_com_rounds = 10
num_epoch_per_round = 60

MLPLoRA.train_block_sub_lora(data_to_tensor(train_data), data_to_tensor(test_data), lora_t, [[5, 5], [5, 5]], 'relu',
                             loss_fn, opt_constr, batch_size, num_com_rounds, num_epoch_per_round, msrs)
# Out:
# Epoch #60
#   Metrics on training data:
#     MSE: 0.015292063355445862.
#   Metrics on testing data:
#     MSE: 0.016333363950252533.
# Epoch #120
#   Metrics on training data:
#     MSE: 0.012728547677397728.
#   Metrics on testing data:
#     MSE: 0.013928985223174095.
# Epoch #180
#   Metrics on training data:
#     MSE: 0.012270603328943253.
#   Metrics on testing data:
#     MSE: 0.013374208472669125.
# Epoch #240
#   Metrics on training data:
#     MSE: 0.01231649611145258.
#   Metrics on testing data:
#     MSE: 0.013440415263175964.
# Epoch #300
#   Metrics on training data:
#     MSE: 0.012253068387508392.
#   Metrics on testing data:
#     MSE: 0.013366270810365677.
# Epoch #360
#   Metrics on training data:
#     MSE: 0.012224958278238773.
#   Metrics on testing data:
#     MSE: 0.013400171883404255.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [8], in <cell line: 20>()
#      17 num_com_rounds = 10
#      18 num_epoch_per_round = 60
# ---> 20 MLPLoRA.train_block_sub_lora(data_to_tensor(train_data), data_to_tensor(test_data), lora_t, [[5, 5], [5, 5]], 'relu',
#      21                              loss_fn, opt_constr, batch_size, num_com_rounds, num_epoch_per_round, msrs)
#
# File ~\Desktop\COMP529\MLPLoRA.py:150, in train_block_sub_lora(train_data, test_data, model_t, all_ranks, activation, loss_fn, opt_constr, batch_size, num_com_rounds, num_epoch_per_round, measurement)
#     147 sub_model_params = [[] for _ in range(num_lora_layers)]
#     149 for sub_model_t in sub_models:
# --> 150     train(train_data, test_data, sub_model_t[0], loss_fn, opt_constr(sub_model_t[0].parameters()), batch_size,
#     151           num_epoch_per_round, None)
#     152     for layer_idx, sub_model_layer in enumerate(sub_model_t[1]):
#     153         sub_model_params[layer_idx].append(sub_model_layer.get_param_data())
#
# File ~\Desktop\COMP529\MLPLoRA.py:119, in train(train_data, test_data, model, loss_fn, optimizer, batch_size, num_epochs, measurement, verbose)
#     117 optimizer.zero_grad()
#     118 loss = loss_fn(model(batch_X.cuda()), batch_Y.cuda())
# --> 119 loss.backward()
#     120 optimizer.step()
#     121 if verbose:
#
# File C:\Python310\lib\site-packages\torch\_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File C:\Python310\lib\site-packages\torch\autograd\__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
def generate_target_func_multi(input_dim, hidden_dim, output_dim, rank_W1, rank_W2, num_funcs):
    fixed_W1 = 1e-6 * np.random.normal(size=(input_dim, hidden_dim)) / np.sqrt(input_dim + hidden_dim)
    fixed_W2 = 1e-6 * np.random.normal(size=(hidden_dim, output_dim)) / np.sqrt(output_dim + hidden_dim)

    print('Operator Norm of fixed W1: ', np.linalg.norm(fixed_W1, ord=2))
    print('Operator Norm of fixed W2: ', np.linalg.norm(fixed_W2, ord=2))
    
    target_funcs = []
    for _ in range(num_funcs):

        A1 = np.random.normal(size=(input_dim, rank_W1)) / np.sqrt(input_dim)
        B1 = np.random.normal(size=(rank_W1, hidden_dim)) / np.sqrt(hidden_dim)
        A2 = np.random.normal(size=(hidden_dim, rank_W2)) / np.sqrt(hidden_dim)
        B2 = np.random.normal(size=(rank_W2, output_dim)) / np.sqrt(output_dim)

        W1 = fixed_W1 + 6 * A1 @ B1
        W2 = fixed_W2 + 6 * A2 @ B2
        
        target_funcs.append(lambda X: relu(X @ W1) @ W2)
    
    return target_funcs, fixed_W1, fixed_W2

# %%
input_dim = 500
hidden_dim = 500
output_dim = 500
num_train_samples = 10000
num_test_samples = 2000
rank_W1 = 10
rank_W2 = 10
num_workers = 10

target_funcs, fixed_W1, fixed_W2 = generate_target_func_multi(input_dim, hidden_dim, output_dim, rank_W1, rank_W2, num_workers)
train_data_list = []
test_data_list = []
for t_func in target_funcs:
    cur_train, cur_test = generate_data(input_dim, int(num_train_samples / num_workers), int(num_test_samples / num_workers), t_func)
    train_data_list.append(cur_train)
    test_data_list.append(cur_test)
    
all_train_X = np.concatenate([x for x, _ in train_data_list], axis=0)
all_train_Y = np.concatenate([y for _, y in train_data_list], axis=0)
all_test_X = np.concatenate([x for x, _ in test_data_list], axis=0)
all_test_Y = np.concatenate([y for _, y in test_data_list], axis=0)

train_data = (all_train_X, all_train_Y)
test_data = (all_test_X, all_test_Y)
# Out:
# Operator Norm of fixed W1:  1.418432343326069e-06
# Operator Norm of fixed W2:  1.3963590336249437e-06

# %%
import measurements
lr = 50
batch_size = 200
phys_bs = 5000
num_epochs = 300


msrs = measurements.Measurement(verbose=True)
msrs.add_train_recorder('MSE', phys_bs, verbose=True)
msrs.add_test_recorder('MSE', phys_bs, verbose=True)

lora_t = MLPLoRA.get_mlp_lora([fixed_W1, fixed_W2], [20, ], 'relu')
lora_t = (lora_t[0].cuda(), lora_t[1])
loss_fn = torch.nn.MSELoss()
opt_constr = lambda params: torch.optim.SGD(params, lr=50)

num_com_rounds = 10
num_epoch_per_round = 60

train_data_tensor_list = [data_to_tensor(data_t) for data_t in train_data_list]

MLPLoRA.train_block_sub_lora_multi(train_data_tensor_list, data_to_tensor(train_data), data_to_tensor(test_data), lora_t, [[8, 8], [8, 8]], 'relu',
                             loss_fn, opt_constr, batch_size, num_com_rounds, num_epoch_per_round, msrs)
# Out:
# Epoch #60
#   Metrics on training data:
#     MSE: 0.2602985203266144.
#   Metrics on testing data:
#     MSE: 0.2631555497646332.
# Epoch #120
#   Metrics on training data:
#     MSE: 0.2566103935241699.
#   Metrics on testing data:
#     MSE: 0.2593747079372406.
# Epoch #180
#   Metrics on training data:
#     MSE: 0.2481585592031479.
#   Metrics on testing data:
#     MSE: 0.2506304979324341.
# Epoch #240
#   Metrics on training data:
#     MSE: 0.23727284371852875.
#   Metrics on testing data:
#     MSE: 0.23927879333496094.
# Epoch #300
#   Metrics on training data:
#     MSE: 0.22722892463207245.
#   Metrics on testing data:
#     MSE: 0.22865332663059235.
# Epoch #360
#   Metrics on training data:
#     MSE: 0.2257036566734314.
#   Metrics on testing data:
#     MSE: 0.2269832193851471.
# Epoch #420
#   Metrics on training data:
#     MSE: 0.22377130389213562.
#   Metrics on testing data:
#     MSE: 0.22496439516544342.
# Epoch #480
#   Metrics on training data:
#     MSE: 0.22128358483314514.
#   Metrics on testing data:
#     MSE: 0.22223785519599915.
# Epoch #540
#   Metrics on training data:
#     MSE: 0.22072289884090424.
#   Metrics on testing data:
#     MSE: 0.22167035937309265.
# Epoch #600
#   Metrics on training data:
#     MSE: 0.22002089023590088.
#   Metrics on testing data:
#     MSE: 0.2208627611398697.

# %%
msrs = measurements.Measurement(verbose=True)
msrs.add_train_recorder('MSE', phys_bs, verbose=True)
msrs.add_test_recorder('MSE', phys_bs, verbose=True)

lora, lora_layers = MLPLoRA.get_mlp_lora([fixed_W1, fixed_W2], [10, 10], 'relu')
lora = lora.cuda()
optimizer = torch.optim.SGD(lora.parameters(), lr=100)
loss_fn = torch.nn.MSELoss()

MLPLoRA.train(data_to_tensor(train_data), data_to_tensor(test_data), lora, loss_fn, optimizer, batch_size, num_epochs, msrs)
# Out:
# Epoch #0
#   Metrics on training data:
#     MSE: 0.11342192441225052.
#   Metrics on testing data:
#     MSE: 0.11741086095571518.
# Epoch #1
#   Metrics on training data:
#     MSE: 0.11328649520874023.
#   Metrics on testing data:
#     MSE: 0.11727248132228851.
# Epoch #2
#   Metrics on training data:
#     MSE: 0.11309223622083664.
#   Metrics on testing data:
#     MSE: 0.11707468330860138.
# Epoch #3
#   Metrics on training data:
#     MSE: 0.11276525259017944.
#   Metrics on testing data:
#     MSE: 0.11674168705940247.
# Epoch #4
#   Metrics on training data:
#     MSE: 0.11218676716089249.
#   Metrics on testing data:
#     MSE: 0.1161518320441246.
# Epoch #5
#   Metrics on training data:
#     MSE: 0.11115474253892899.
#   Metrics on testing data:
#     MSE: 0.11509814113378525.
# Epoch #6
#   Metrics on training data:
#     MSE: 0.10933151841163635.
#   Metrics on testing data:
#     MSE: 0.11323495209217072.
# Epoch #7
#   Metrics on training data:
#     MSE: 0.10619838535785675.
#   Metrics on testing data:
#     MSE: 0.11003153771162033.
# Epoch #8
#   Metrics on training data:
#     MSE: 0.10112671554088593.
#   Metrics on testing data:
#     MSE: 0.10484480112791061.
# Epoch #9
#   Metrics on training data:
#     MSE: 0.09387972205877304.
#   Metrics on testing data:
#     MSE: 0.09742863476276398.
# Epoch #10
#   Metrics on training data:
#     MSE: 0.0857248604297638.
#   Metrics on testing data:
#     MSE: 0.08906176686286926.
# Epoch #11
#   Metrics on training data:
#     MSE: 0.07937805354595184.
#   Metrics on testing data:
#     MSE: 0.08250772207975388.
# Epoch #12
#   Metrics on training data:
#     MSE: 0.0760076493024826.
#   Metrics on testing data:
#     MSE: 0.07900264114141464.
# Epoch #13
#   Metrics on training data:
#     MSE: 0.07452430576086044.
#   Metrics on testing data:
#     MSE: 0.07747890055179596.
# Epoch #14
#   Metrics on training data:
#     MSE: 0.07384058833122253.
#   Metrics on testing data:
#     MSE: 0.07681837677955627.
# Epoch #15
#   Metrics on training data:
#     MSE: 0.07347917556762695.
#   Metrics on testing data:
#     MSE: 0.07651129364967346.
# Epoch #16
#   Metrics on training data:
#     MSE: 0.07325741648674011.
#   Metrics on testing data:
#     MSE: 0.07635637372732162.
# Epoch #17
#   Metrics on training data:
#     MSE: 0.07309968024492264.
#   Metrics on testing data:
#     MSE: 0.07627028226852417.
# Epoch #18
#   Metrics on training data:
#     MSE: 0.07297259569168091.
#   Metrics on testing data:
#     MSE: 0.07621631026268005.
# Epoch #19
#   Metrics on training data:
#     MSE: 0.07286092638969421.
#   Metrics on testing data:
#     MSE: 0.07617776840925217.
# Epoch #20
#   Metrics on training data:
#     MSE: 0.07275762408971786.
#   Metrics on testing data:
#     MSE: 0.0761466845870018.
# Epoch #21
#   Metrics on training data:
#     MSE: 0.07265947014093399.
#   Metrics on testing data:
#     MSE: 0.07611937075853348.
# Epoch #22
#   Metrics on training data:
#     MSE: 0.07256467640399933.
#   Metrics on testing data:
#     MSE: 0.07609407603740692.
# Epoch #23
#   Metrics on training data:
#     MSE: 0.07247242331504822.
#   Metrics on testing data:
#     MSE: 0.07606987655162811.
# Epoch #24
#   Metrics on training data:
#     MSE: 0.07238218933343887.
#   Metrics on testing data:
#     MSE: 0.07604619115591049.
# Epoch #25
#   Metrics on training data:
#     MSE: 0.07229366153478622.
#   Metrics on testing data:
#     MSE: 0.07602269947528839.
# Epoch #26
#   Metrics on training data:
#     MSE: 0.07220672070980072.
#   Metrics on testing data:
#     MSE: 0.07599908858537674.
# Epoch #27
#   Metrics on training data:
#     MSE: 0.07212132215499878.
#   Metrics on testing data:
#     MSE: 0.07597525417804718.
# Epoch #28
#   Metrics on training data:
#     MSE: 0.07203726470470428.
#   Metrics on testing data:
#     MSE: 0.07595102488994598.
# Epoch #29
#   Metrics on training data:
#     MSE: 0.0719543844461441.
#   Metrics on testing data:
#     MSE: 0.07592621445655823.
# Epoch #30
#   Metrics on training data:
#     MSE: 0.07187274843454361.
#   Metrics on testing data:
#     MSE: 0.07590071856975555.
# Epoch #31
#   Metrics on training data:
#     MSE: 0.07179206609725952.
#   Metrics on testing data:
#     MSE: 0.0758742094039917.
# Epoch #32
#   Metrics on training data:
#     MSE: 0.07171227782964706.
#   Metrics on testing data:
#     MSE: 0.07584655284881592.
# Epoch #33
#   Metrics on training data:
#     MSE: 0.07163316756486893.
#   Metrics on testing data:
#     MSE: 0.07581770420074463.
# Epoch #34
#   Metrics on training data:
#     MSE: 0.0715547502040863.
#   Metrics on testing data:
#     MSE: 0.0757877379655838.
# Epoch #35
#   Metrics on training data:
#     MSE: 0.0714767798781395.
#   Metrics on testing data:
#     MSE: 0.07575657963752747.
# Epoch #36
#   Metrics on training data:
#     MSE: 0.07139919698238373.
#   Metrics on testing data:
#     MSE: 0.07572419941425323.
# Epoch #37
#   Metrics on training data:
#     MSE: 0.07132164388895035.
#   Metrics on testing data:
#     MSE: 0.07568992674350739.
# Epoch #38
#   Metrics on training data:
#     MSE: 0.07124414294958115.
#   Metrics on testing data:
#     MSE: 0.07565373927354813.
# Epoch #39
#   Metrics on training data:
#     MSE: 0.07116661220788956.
#   Metrics on testing data:
#     MSE: 0.07561570405960083.
# Epoch #40
#   Metrics on training data:
#     MSE: 0.07108896970748901.
#   Metrics on testing data:
#     MSE: 0.07557565718889236.
# Epoch #41
#   Metrics on training data:
#     MSE: 0.07101088762283325.
#   Metrics on testing data:
#     MSE: 0.07553311437368393.
# Epoch #42
#   Metrics on training data:
#     MSE: 0.07093221694231033.
#   Metrics on testing data:
#     MSE: 0.07548774778842926.
# Epoch #43
#   Metrics on training data:
#     MSE: 0.07085271924734116.
#   Metrics on testing data:
#     MSE: 0.07543937861919403.
# Epoch #44
#   Metrics on training data:
#     MSE: 0.07077190279960632.
#   Metrics on testing data:
#     MSE: 0.0753878802061081.
# Epoch #45
#   Metrics on training data:
#     MSE: 0.07068955153226852.
#   Metrics on testing data:
#     MSE: 0.07533293217420578.
# Epoch #46
#   Metrics on training data:
#     MSE: 0.07060515880584717.
#   Metrics on testing data:
#     MSE: 0.0752740129828453.
# Epoch #47
#   Metrics on training data:
#     MSE: 0.07051847130060196.
#   Metrics on testing data:
#     MSE: 0.07521083950996399.
# Epoch #48
#   Metrics on training data:
#     MSE: 0.07042890787124634.
#   Metrics on testing data:
#     MSE: 0.07514271885156631.
# Epoch #49
#   Metrics on training data:
#     MSE: 0.07033580541610718.
#   Metrics on testing data:
#     MSE: 0.07506915181875229.
# Epoch #50
#   Metrics on training data:
#     MSE: 0.07023842632770538.
#   Metrics on testing data:
#     MSE: 0.07498922199010849.
# Epoch #51
#   Metrics on training data:
#     MSE: 0.0701359212398529.
#   Metrics on testing data:
#     MSE: 0.07490209490060806.
# Epoch #52
#   Metrics on training data:
#     MSE: 0.07002740353345871.
#   Metrics on testing data:
#     MSE: 0.07480698078870773.
# Epoch #53
#   Metrics on training data:
#     MSE: 0.06991157680749893.
#   Metrics on testing data:
#     MSE: 0.07470232248306274.
# Epoch #54
#   Metrics on training data:
#     MSE: 0.06978679448366165.
#   Metrics on testing data:
#     MSE: 0.07458613067865372.
# Epoch #55
#   Metrics on training data:
#     MSE: 0.06965099275112152.
#   Metrics on testing data:
#     MSE: 0.07445641607046127.
# Epoch #56
#   Metrics on training data:
#     MSE: 0.06950142979621887.
#   Metrics on testing data:
#     MSE: 0.07431066036224365.
# Epoch #57
#   Metrics on training data:
#     MSE: 0.06933493912220001.
#   Metrics on testing data:
#     MSE: 0.07414563745260239.
# Epoch #58
#   Metrics on training data:
#     MSE: 0.06914744526147842.
#   Metrics on testing data:
#     MSE: 0.0739571750164032.
# Epoch #59
#   Metrics on training data:
#     MSE: 0.06893359124660492.
#   Metrics on testing data:
#     MSE: 0.07374001294374466.
# Epoch #60
#   Metrics on training data:
#     MSE: 0.06868649274110794.
#   Metrics on testing data:
#     MSE: 0.07348750531673431.
# Epoch #61
#   Metrics on training data:
#     MSE: 0.06839688867330551.
#   Metrics on testing data:
#     MSE: 0.07319089025259018.
# Epoch #62
#   Metrics on training data:
#     MSE: 0.06805393099784851.
#   Metrics on testing data:
#     MSE: 0.07283919304609299.
# Epoch #63
#   Metrics on training data:
#     MSE: 0.06764263659715652.
#   Metrics on testing data:
#     MSE: 0.0724179595708847.
# Epoch #64
#   Metrics on training data:
#     MSE: 0.06714533269405365.
#   Metrics on testing data:
#     MSE: 0.07190926373004913.
# Epoch #65
#   Metrics on training data:
#     MSE: 0.06654000282287598.
#   Metrics on testing data:
#     MSE: 0.0712921991944313.
# Epoch #66
#   Metrics on training data:
#     MSE: 0.0658017098903656.
#   Metrics on testing data:
#     MSE: 0.07054239511489868.
# Epoch #67
#   Metrics on training data:
#     MSE: 0.06490674614906311.
#   Metrics on testing data:
#     MSE: 0.06963704526424408.
# Epoch #68
#   Metrics on training data:
#     MSE: 0.06383872032165527.
#   Metrics on testing data:
#     MSE: 0.06856056302785873.
# Epoch #69
#   Metrics on training data:
#     MSE: 0.06260247528553009.
#   Metrics on testing data:
#     MSE: 0.06731867045164108.
# Epoch #70
#   Metrics on training data:
#     MSE: 0.06123872101306915.
#   Metrics on testing data:
#     MSE: 0.06595244258642197.
# Epoch #71
#   Metrics on training data:
#     MSE: 0.05982641875743866.
#   Metrics on testing data:
#     MSE: 0.0645405501127243.
# Epoch #72
#   Metrics on training data:
#     MSE: 0.058469224721193314.
#   Metrics on testing data:
#     MSE: 0.06318625807762146.
# Epoch #73
#   Metrics on training data:
#     MSE: 0.05725983902812004.
#   Metrics on testing data:
#     MSE: 0.061982281506061554.
# Epoch #74
#   Metrics on training data:
#     MSE: 0.056244250386953354.
#   Metrics on testing data:
#     MSE: 0.06097826361656189.
# Epoch #75
#   Metrics on training data:
#     MSE: 0.05542515590786934.
#   Metrics on testing data:
#     MSE: 0.060177262872457504.
# Epoch #76
#   Metrics on training data:
#     MSE: 0.05477740988135338.
#   Metrics on testing data:
#     MSE: 0.05955353006720543.
# Epoch #77
#   Metrics on training data:
#     MSE: 0.0542653426527977.
#   Metrics on testing data:
#     MSE: 0.05907035619020462.
# Epoch #78
#   Metrics on training data:
#     MSE: 0.053853537887334824.
#   Metrics on testing data:
#     MSE: 0.05868995562195778.
# Epoch #79
#   Metrics on training data:
#     MSE: 0.05351214483380318.
#   Metrics on testing data:
#     MSE: 0.058379556983709335.
# Epoch #80
#   Metrics on training data:
#     MSE: 0.05321795493364334.
#   Metrics on testing data:
#     MSE: 0.05811360478401184.
# Epoch #81
#   Metrics on training data:
#     MSE: 0.052952397614717484.
#   Metrics on testing data:
#     MSE: 0.05787236988544464.
# Epoch #82
#   Metrics on training data:
#     MSE: 0.052700694650411606.
#   Metrics on testing data:
#     MSE: 0.05764077976346016.
# Epoch #83
#   Metrics on training data:
#     MSE: 0.05245162174105644.
#   Metrics on testing data:
#     MSE: 0.05740658938884735.
# Epoch #84
#   Metrics on training data:
#     MSE: 0.052195098251104355.
#   Metrics on testing data:
#     MSE: 0.057158540934324265.
# Epoch #85
#   Metrics on training data:
#     MSE: 0.05192220211029053.
#   Metrics on testing data:
#     MSE: 0.05688690021634102.
# Epoch #86
#   Metrics on training data:
#     MSE: 0.05162427946925163.
#   Metrics on testing data:
#     MSE: 0.05658237636089325.
# Epoch #87
#   Metrics on training data:
#     MSE: 0.05129321292042732.
#   Metrics on testing data:
#     MSE: 0.0562354139983654.
# Epoch #88
#   Metrics on training data:
#     MSE: 0.05092006176710129.
#   Metrics on testing data:
#     MSE: 0.05583713948726654.
# Epoch #89
#   Metrics on training data:
#     MSE: 0.05049620941281319.
#   Metrics on testing data:
#     MSE: 0.055377665907144547.
# Epoch #90
#   Metrics on training data:
#     MSE: 0.05001353472471237.
#   Metrics on testing data:
#     MSE: 0.05484922230243683.
# Epoch #91
#   Metrics on training data:
#     MSE: 0.049465518444776535.
#   Metrics on testing data:
#     MSE: 0.05424520745873451.
# Epoch #92
#   Metrics on training data:
#     MSE: 0.048849839717149734.
#   Metrics on testing data:
#     MSE: 0.05356297641992569.
# Epoch #93
#   Metrics on training data:
#     MSE: 0.048168882727622986.
#   Metrics on testing data:
#     MSE: 0.05280643329024315.
# Epoch #94
#   Metrics on training data:
#     MSE: 0.04743319749832153.
#   Metrics on testing data:
#     MSE: 0.05198852717876434.
# Epoch #95
#   Metrics on training data:
#     MSE: 0.04666242003440857.
#   Metrics on testing data:
#     MSE: 0.05113188549876213.
# Epoch #96
#   Metrics on training data:
#     MSE: 0.04588410630822182.
#   Metrics on testing data:
#     MSE: 0.05026908218860626.
# Epoch #97
#   Metrics on training data:
#     MSE: 0.04512903839349747.
#   Metrics on testing data:
#     MSE: 0.049434009939432144.
# Epoch #98
#   Metrics on training data:
#     MSE: 0.04442581534385681.
#   Metrics on testing data:
#     MSE: 0.048659518361091614.
# Epoch #99
#   Metrics on training data:
#     MSE: 0.04379476234316826.
#   Metrics on testing data:
#     MSE: 0.04796723648905754.
# Epoch #100
#   Metrics on training data:
#     MSE: 0.04324590787291527.
#   Metrics on testing data:
#     MSE: 0.047367800027132034.
# Epoch #101
#   Metrics on training data:
#     MSE: 0.04277839884161949.
#   Metrics on testing data:
#     MSE: 0.04686078429222107.
# Epoch #102
#   Metrics on training data:
#     MSE: 0.042386315762996674.
#   Metrics on testing data:
#     MSE: 0.04643862321972847.
# Epoch #103
#   Metrics on training data:
#     MSE: 0.04205996170639992.
#   Metrics on testing data:
#     MSE: 0.04609019681811333.
# Epoch #104
#   Metrics on training data:
#     MSE: 0.041788943111896515.
#   Metrics on testing data:
#     MSE: 0.04580345377326012.
# Epoch #105
#   Metrics on training data:
#     MSE: 0.041562896221876144.
#   Metrics on testing data:
#     MSE: 0.0455663688480854.
# Epoch #106
#   Metrics on training data:
#     MSE: 0.04137295484542847.
#   Metrics on testing data:
#     MSE: 0.04536931961774826.
# Epoch #107
#   Metrics on training data:
#     MSE: 0.04121164605021477.
#   Metrics on testing data:
#     MSE: 0.04520373046398163.
# Epoch #108
#   Metrics on training data:
#     MSE: 0.04107300192117691.
#   Metrics on testing data:
#     MSE: 0.04506292939186096.
# Epoch #109
#   Metrics on training data:
#     MSE: 0.04095219820737839.
#   Metrics on testing data:
#     MSE: 0.04494141787290573.
# Epoch #110
#   Metrics on training data:
#     MSE: 0.04084540158510208.
#   Metrics on testing data:
#     MSE: 0.04483512416481972.
# Epoch #111
#   Metrics on training data:
#     MSE: 0.040749549865722656.
#   Metrics on testing data:
#     MSE: 0.044740114361047745.
# Epoch #112
#   Metrics on training data:
#     MSE: 0.04066229611635208.
#   Metrics on testing data:
#     MSE: 0.04465394839644432.
# Epoch #113
#   Metrics on training data:
#     MSE: 0.04058162122964859.
#   Metrics on testing data:
#     MSE: 0.04457448795437813.
# Epoch #114
#   Metrics on training data:
#     MSE: 0.040506280958652496.
#   Metrics on testing data:
#     MSE: 0.04450022801756859.
# Epoch #115
#   Metrics on training data:
#     MSE: 0.040435124188661575.
#   Metrics on testing data:
#     MSE: 0.044429805129766464.
# Epoch #116
#   Metrics on training data:
#     MSE: 0.04036714509129524.
#   Metrics on testing data:
#     MSE: 0.04436207190155983.
# Epoch #117
#   Metrics on training data:
#     MSE: 0.040301550179719925.
#   Metrics on testing data:
#     MSE: 0.04429628327488899.
# Epoch #118
#   Metrics on training data:
#     MSE: 0.04023788496851921.
#   Metrics on testing data:
#     MSE: 0.04423189163208008.
# Epoch #119
#   Metrics on training data:
#     MSE: 0.0401756688952446.
#   Metrics on testing data:
#     MSE: 0.04416852071881294.
# Epoch #120
#   Metrics on training data:
#     MSE: 0.04011446610093117.
#   Metrics on testing data:
#     MSE: 0.04410549998283386.
# Epoch #121
#   Metrics on training data:
#     MSE: 0.04005391523241997.
#   Metrics on testing data:
#     MSE: 0.04404233396053314.
# Epoch #122
#   Metrics on training data:
#     MSE: 0.039993662387132645.
#   Metrics on testing data:
#     MSE: 0.04397876188158989.
# Epoch #123
#   Metrics on training data:
#     MSE: 0.0399334579706192.
#   Metrics on testing data:
#     MSE: 0.043914537876844406.
# Epoch #124
#   Metrics on training data:
#     MSE: 0.039872944355010986.
#   Metrics on testing data:
#     MSE: 0.04384927451610565.
# Epoch #125
#   Metrics on training data:
#     MSE: 0.03981209918856621.
#   Metrics on testing data:
#     MSE: 0.04378288611769676.
# Epoch #126
#   Metrics on training data:
#     MSE: 0.03975066542625427.
#   Metrics on testing data:
#     MSE: 0.04371529445052147.
# Epoch #127
#   Metrics on training data:
#     MSE: 0.03968843072652817.
#   Metrics on testing data:
#     MSE: 0.04364626854658127.
# Epoch #128
#   Metrics on training data:
#     MSE: 0.03962515667080879.
#   Metrics on testing data:
#     MSE: 0.04357560724020004.
# Epoch #129
#   Metrics on training data:
#     MSE: 0.03956058248877525.
#   Metrics on testing data:
#     MSE: 0.04350288584828377.
# Epoch #130
#   Metrics on training data:
#     MSE: 0.039494503289461136.
#   Metrics on testing data:
#     MSE: 0.043427806347608566.
# Epoch #131
#   Metrics on training data:
#     MSE: 0.03942672163248062.
#   Metrics on testing data:
#     MSE: 0.04335026070475578.
# Epoch #132
#   Metrics on training data:
#     MSE: 0.039356913417577744.
#   Metrics on testing data:
#     MSE: 0.04326987266540527.
# Epoch #133
#   Metrics on training data:
#     MSE: 0.03928486257791519.
#   Metrics on testing data:
#     MSE: 0.04318656027317047.
# Epoch #134
#   Metrics on training data:
#     MSE: 0.03921029716730118.
#   Metrics on testing data:
#     MSE: 0.043100230395793915.
# Epoch #135
#   Metrics on training data:
#     MSE: 0.03913300111889839.
#   Metrics on testing data:
#     MSE: 0.043010469526052475.
# Epoch #136
#   Metrics on training data:
#     MSE: 0.039052631705999374.
#   Metrics on testing data:
#     MSE: 0.04291699454188347.
# Epoch #137
#   Metrics on training data:
#     MSE: 0.038968902081251144.
#   Metrics on testing data:
#     MSE: 0.04281936585903168.
# Epoch #138
#   Metrics on training data:
#     MSE: 0.03888150677084923.
#   Metrics on testing data:
#     MSE: 0.04271724820137024.
# Epoch #139
#   Metrics on training data:
#     MSE: 0.03879005089402199.
#   Metrics on testing data:
#     MSE: 0.0426102876663208.
# Epoch #140
#   Metrics on training data:
#     MSE: 0.038694098591804504.
#   Metrics on testing data:
#     MSE: 0.04249805957078934.
# Epoch #141
#   Metrics on training data:
#     MSE: 0.03859315812587738.
#   Metrics on testing data:
#     MSE: 0.04238015040755272.
# Epoch #142
#   Metrics on training data:
#     MSE: 0.03848674148321152.
#   Metrics on testing data:
#     MSE: 0.042256083339452744.
# Epoch #143
#   Metrics on training data:
#     MSE: 0.03837437182664871.
#   Metrics on testing data:
#     MSE: 0.04212554916739464.
# Epoch #144
#   Metrics on training data:
#     MSE: 0.03825558349490166.
#   Metrics on testing data:
#     MSE: 0.041988108307123184.
# Epoch #145
#   Metrics on training data:
#     MSE: 0.03812979534268379.
#   Metrics on testing data:
#     MSE: 0.04184294119477272.
# Epoch #146
#   Metrics on training data:
#     MSE: 0.037996262311935425.
#   Metrics on testing data:
#     MSE: 0.04168950393795967.
# Epoch #147
#   Metrics on training data:
#     MSE: 0.03785419836640358.
#   Metrics on testing data:
#     MSE: 0.041527025401592255.
# Epoch #148
#   Metrics on training data:
#     MSE: 0.037702929228544235.
#   Metrics on testing data:
#     MSE: 0.041354864835739136.
# Epoch #149
#   Metrics on training data:
#     MSE: 0.037541698664426804.
#   Metrics on testing data:
#     MSE: 0.041172582656145096.
# Epoch #150
#   Metrics on training data:
#     MSE: 0.0373694971203804.
#   Metrics on testing data:
#     MSE: 0.04097890481352806.
# Epoch #151
#   Metrics on training data:
#     MSE: 0.0371854193508625.
#   Metrics on testing data:
#     MSE: 0.040772903710603714.
# Epoch #152
#   Metrics on training data:
#     MSE: 0.03698849678039551.
#   Metrics on testing data:
#     MSE: 0.04055371135473251.
# Epoch #153
#   Metrics on training data:
#     MSE: 0.036777663975954056.
#   Metrics on testing data:
#     MSE: 0.040320415049791336.
# Epoch #154
#   Metrics on training data:
#     MSE: 0.036552056670188904.
#   Metrics on testing data:
#     MSE: 0.04007194563746452.
# Epoch #155
#   Metrics on training data:
#     MSE: 0.036310553550720215.
#   Metrics on testing data:
#     MSE: 0.03980761766433716.
# Epoch #156
#   Metrics on training data:
#     MSE: 0.03605228289961815.
#   Metrics on testing data:
#     MSE: 0.03952622041106224.
# Epoch #157
#   Metrics on training data:
#     MSE: 0.03577641770243645.
#   Metrics on testing data:
#     MSE: 0.03922699764370918.
# Epoch #158
#   Metrics on training data:
#     MSE: 0.03548262268304825.
#   Metrics on testing data:
#     MSE: 0.038909777998924255.
# Epoch #159
#   Metrics on training data:
#     MSE: 0.03517047315835953.
#   Metrics on testing data:
#     MSE: 0.038573987782001495.
# Epoch #160
#   Metrics on training data:
#     MSE: 0.03483986854553223.
#   Metrics on testing data:
#     MSE: 0.03822033107280731.
# Epoch #161
#   Metrics on training data:
#     MSE: 0.034491170197725296.
#   Metrics on testing data:
#     MSE: 0.03784884139895439.
# Epoch #162
#   Metrics on training data:
#     MSE: 0.034124936908483505.
#   Metrics on testing data:
#     MSE: 0.03746025264263153.
# Epoch #163
#   Metrics on training data:
#     MSE: 0.03374285623431206.
#   Metrics on testing data:
#     MSE: 0.037056125700473785.
# Epoch #164
#   Metrics on training data:
#     MSE: 0.033346910029649734.
#   Metrics on testing data:
#     MSE: 0.03663872927427292.
# Epoch #165
#   Metrics on training data:
#     MSE: 0.032939694821834564.
#   Metrics on testing data:
#     MSE: 0.036211047321558.
# Epoch #166
#   Metrics on training data:
#     MSE: 0.03252513334155083.
#   Metrics on testing data:
#     MSE: 0.03577670827507973.
# Epoch #167
#   Metrics on training data:
#     MSE: 0.032107163220644.
#   Metrics on testing data:
#     MSE: 0.035339485853910446.
# Epoch #168
#   Metrics on training data:
#     MSE: 0.031689781695604324.
#   Metrics on testing data:
#     MSE: 0.03490350395441055.
# Epoch #169
#   Metrics on training data:
#     MSE: 0.03127691149711609.
#   Metrics on testing data:
#     MSE: 0.03447309508919716.
# Epoch #170
#   Metrics on training data:
#     MSE: 0.030872251838445663.
#   Metrics on testing data:
#     MSE: 0.03405190259218216.
# Epoch #171
#   Metrics on training data:
#     MSE: 0.030478782951831818.
#   Metrics on testing data:
#     MSE: 0.033643562346696854.
# Epoch #172
#   Metrics on training data:
#     MSE: 0.030099397525191307.
#   Metrics on testing data:
#     MSE: 0.03325050696730614.
# Epoch #173
#   Metrics on training data:
#     MSE: 0.029735852032899857.
#   Metrics on testing data:
#     MSE: 0.03287480026483536.
# Epoch #174
#   Metrics on training data:
#     MSE: 0.029389141127467155.
#   Metrics on testing data:
#     MSE: 0.03251681476831436.
# Epoch #175
#   Metrics on training data:
#     MSE: 0.029060350731015205.
#   Metrics on testing data:
#     MSE: 0.0321776419878006.
# Epoch #176
#   Metrics on training data:
#     MSE: 0.02874908037483692.
#   Metrics on testing data:
#     MSE: 0.031857267022132874.
# Epoch #177
#   Metrics on training data:
#     MSE: 0.028455065563321114.
#   Metrics on testing data:
#     MSE: 0.03155428171157837.
# Epoch #178
#   Metrics on training data:
#     MSE: 0.028177276253700256.
#   Metrics on testing data:
#     MSE: 0.0312679149210453.
# Epoch #179
#   Metrics on training data:
#     MSE: 0.027914637699723244.
#   Metrics on testing data:
#     MSE: 0.030997121706604958.
# Epoch #180
#   Metrics on training data:
#     MSE: 0.027666350826621056.
#   Metrics on testing data:
#     MSE: 0.03074054978787899.
# Epoch #181
#   Metrics on training data:
#     MSE: 0.02743111550807953.
#   Metrics on testing data:
#     MSE: 0.03049641102552414.
# Epoch #182
#   Metrics on training data:
#     MSE: 0.02720768377184868.
#   Metrics on testing data:
#     MSE: 0.030263734981417656.
# Epoch #183
#   Metrics on training data:
#     MSE: 0.026994939893484116.
#   Metrics on testing data:
#     MSE: 0.030041448771953583.
# Epoch #184
#   Metrics on training data:
#     MSE: 0.026791570708155632.
#   Metrics on testing data:
#     MSE: 0.02982858009636402.
# Epoch #185
#   Metrics on training data:
#     MSE: 0.026596542447805405.
#   Metrics on testing data:
#     MSE: 0.02962394803762436.
# Epoch #186
#   Metrics on training data:
#     MSE: 0.026408782228827477.
#   Metrics on testing data:
#     MSE: 0.029426254332065582.
# Epoch #187
#   Metrics on training data:
#     MSE: 0.026227392256259918.
#   Metrics on testing data:
#     MSE: 0.029234429821372032.
# Epoch #188
#   Metrics on training data:
#     MSE: 0.02605137787759304.
#   Metrics on testing data:
#     MSE: 0.029047692194581032.
# Epoch #189
#   Metrics on training data:
#     MSE: 0.025880077853798866.
#   Metrics on testing data:
#     MSE: 0.028865354135632515.
# Epoch #190
#   Metrics on training data:
#     MSE: 0.025712816044688225.
#   Metrics on testing data:
#     MSE: 0.028686750680208206.
# Epoch #191
#   Metrics on training data:
#     MSE: 0.025549083948135376.
#   Metrics on testing data:
#     MSE: 0.028511570766568184.
# Epoch #192
#   Metrics on training data:
#     MSE: 0.025388222187757492.
#   Metrics on testing data:
#     MSE: 0.02833842672407627.
# Epoch #193
#   Metrics on training data:
#     MSE: 0.0252296831458807.
#   Metrics on testing data:
#     MSE: 0.028167065232992172.
# Epoch #194
#   Metrics on training data:
#     MSE: 0.025072939693927765.
#   Metrics on testing data:
#     MSE: 0.027997178956866264.
# Epoch #195
#   Metrics on training data:
#     MSE: 0.024917632341384888.
#   Metrics on testing data:
#     MSE: 0.027828168123960495.
# Epoch #196
#   Metrics on training data:
#     MSE: 0.024763094261288643.
#   Metrics on testing data:
#     MSE: 0.0276593379676342.
# Epoch #197
#   Metrics on training data:
#     MSE: 0.02460913546383381.
#   Metrics on testing data:
#     MSE: 0.027490811422467232.
# Epoch #198
#   Metrics on training data:
#     MSE: 0.024455349892377853.
#   Metrics on testing data:
#     MSE: 0.02732185274362564.
# Epoch #199
#   Metrics on training data:
#     MSE: 0.02430114708840847.
#   Metrics on testing data:
#     MSE: 0.02715199440717697.
# Epoch #200
#   Metrics on training data:
#     MSE: 0.02414620853960514.
#   Metrics on testing data:
#     MSE: 0.026981204748153687.
# Epoch #201
#   Metrics on training data:
#     MSE: 0.023990068584680557.
#   Metrics on testing data:
#     MSE: 0.02680891938507557.
# Epoch #202
#   Metrics on training data:
#     MSE: 0.023832498118281364.
#   Metrics on testing data:
#     MSE: 0.026634691283106804.
# Epoch #203
#   Metrics on training data:
#     MSE: 0.02367330528795719.
#   Metrics on testing data:
#     MSE: 0.026458144187927246.
# Epoch #204
#   Metrics on training data:
#     MSE: 0.023512130603194237.
#   Metrics on testing data:
#     MSE: 0.02627907693386078.
# Epoch #205
#   Metrics on training data:
#     MSE: 0.023348428308963776.
#   Metrics on testing data:
#     MSE: 0.026097269728779793.
# Epoch #206
#   Metrics on training data:
#     MSE: 0.023181775584816933.
#   Metrics on testing data:
#     MSE: 0.02591228298842907.
# Epoch #207
#   Metrics on training data:
#     MSE: 0.02301201783120632.
#   Metrics on testing data:
#     MSE: 0.025723880156874657.
# Epoch #208
#   Metrics on training data:
#     MSE: 0.022838789969682693.
#   Metrics on testing data:
#     MSE: 0.02553151734173298.
# Epoch #209
#   Metrics on training data:
#     MSE: 0.022661855444312096.
#   Metrics on testing data:
#     MSE: 0.025335220620036125.
# Epoch #210
#   Metrics on training data:
#     MSE: 0.02248106338083744.
#   Metrics on testing data:
#     MSE: 0.025134500116109848.
# Epoch #211
#   Metrics on training data:
#     MSE: 0.022296147421002388.
#   Metrics on testing data:
#     MSE: 0.024929145351052284.
# Epoch #212
#   Metrics on training data:
#     MSE: 0.022106990218162537.
#   Metrics on testing data:
#     MSE: 0.024719301611185074.
# Epoch #213
#   Metrics on training data:
#     MSE: 0.02191346138715744.
#   Metrics on testing data:
#     MSE: 0.024504348635673523.
# Epoch #214
#   Metrics on training data:
#     MSE: 0.02171553485095501.
#   Metrics on testing data:
#     MSE: 0.024284493178129196.
# Epoch #215
#   Metrics on training data:
#     MSE: 0.021513106301426888.
#   Metrics on testing data:
#     MSE: 0.02405981719493866.
# Epoch #216
#   Metrics on training data:
#     MSE: 0.021306203678250313.
#   Metrics on testing data:
#     MSE: 0.023830363526940346.
# Epoch #217
#   Metrics on training data:
#     MSE: 0.02109508216381073.
#   Metrics on testing data:
#     MSE: 0.023596514016389847.
# Epoch #218
#   Metrics on training data:
#     MSE: 0.020879730582237244.
#   Metrics on testing data:
#     MSE: 0.023357952013611794.
# Epoch #219
#   Metrics on training data:
#     MSE: 0.020660540089011192.
#   Metrics on testing data:
#     MSE: 0.023115182295441628.
# Epoch #220
#   Metrics on training data:
#     MSE: 0.020437978208065033.
#   Metrics on testing data:
#     MSE: 0.022868497297167778.
# Epoch #221
#   Metrics on training data:
#     MSE: 0.020212456583976746.
#   Metrics on testing data:
#     MSE: 0.022618547081947327.
# Epoch #222
#   Metrics on training data:
#     MSE: 0.01998436078429222.
#   Metrics on testing data:
#     MSE: 0.022365881130099297.
# Epoch #223
#   Metrics on training data:
#     MSE: 0.019754329696297646.
#   Metrics on testing data:
#     MSE: 0.02211109735071659.
# Epoch #224
#   Metrics on training data:
#     MSE: 0.019522972404956818.
#   Metrics on testing data:
#     MSE: 0.021854788064956665.
# Epoch #225
#   Metrics on training data:
#     MSE: 0.019290778785943985.
#   Metrics on testing data:
#     MSE: 0.021597573533654213.
# Epoch #226
#   Metrics on training data:
#     MSE: 0.019058339297771454.
#   Metrics on testing data:
#     MSE: 0.02134007401764393.
# Epoch #227
#   Metrics on training data:
#     MSE: 0.01882622018456459.
#   Metrics on testing data:
#     MSE: 0.021082688122987747.
# Epoch #228
#   Metrics on training data:
#     MSE: 0.01859494298696518.
#   Metrics on testing data:
#     MSE: 0.020825859159231186.
# Epoch #229
#   Metrics on training data:
#     MSE: 0.01836496591567993.
#   Metrics on testing data:
#     MSE: 0.020570069551467896.
# Epoch #230
#   Metrics on training data:
#     MSE: 0.01813657209277153.
#   Metrics on testing data:
#     MSE: 0.020315686240792274.
# Epoch #231
#   Metrics on training data:
#     MSE: 0.017910286784172058.
#   Metrics on testing data:
#     MSE: 0.02006336860358715.
# Epoch #232
#   Metrics on training data:
#     MSE: 0.017686419188976288.
#   Metrics on testing data:
#     MSE: 0.019813301041722298.
# Epoch #233
#   Metrics on training data:
#     MSE: 0.017465434968471527.
#   Metrics on testing data:
#     MSE: 0.019565921276807785.
# Epoch #234
#   Metrics on training data:
#     MSE: 0.017247309908270836.
#   Metrics on testing data:
#     MSE: 0.019321614876389503.
# Epoch #235
#   Metrics on training data:
#     MSE: 0.01703215017914772.
#   Metrics on testing data:
#     MSE: 0.019080406054854393.
# Epoch #236
#   Metrics on training data:
#     MSE: 0.016820065677165985.
#   Metrics on testing data:
#     MSE: 0.018842440098524094.
# Epoch #237
#   Metrics on training data:
#     MSE: 0.016611116006970406.
#   Metrics on testing data:
#     MSE: 0.01860760897397995.
# Epoch #238
#   Metrics on training data:
#     MSE: 0.01640533283352852.
#   Metrics on testing data:
#     MSE: 0.018376072868704796.
# Epoch #239
#   Metrics on training data:
#     MSE: 0.01620251126587391.
#   Metrics on testing data:
#     MSE: 0.018147878348827362.
# Epoch #240
#   Metrics on training data:
#     MSE: 0.01600274257361889.
#   Metrics on testing data:
#     MSE: 0.017923012375831604.
# Epoch #241
#   Metrics on training data:
#     MSE: 0.015805941075086594.
#   Metrics on testing data:
#     MSE: 0.01770142838358879.
# Epoch #242
#   Metrics on training data:
#     MSE: 0.015612197108566761.
#   Metrics on testing data:
#     MSE: 0.017483117058873177.
# Epoch #243
#   Metrics on training data:
#     MSE: 0.015421293675899506.
#   Metrics on testing data:
#     MSE: 0.017267830669879913.
# Epoch #244
#   Metrics on training data:
#     MSE: 0.015233074314892292.
#   Metrics on testing data:
#     MSE: 0.017055653035640717.
# Epoch #245
#   Metrics on training data:
#     MSE: 0.015047549270093441.
#   Metrics on testing data:
#     MSE: 0.01684650033712387.
# Epoch #246
#   Metrics on training data:
#     MSE: 0.01486468780785799.
#   Metrics on testing data:
#     MSE: 0.01664046198129654.
# Epoch #247
#   Metrics on training data:
#     MSE: 0.01468436885625124.
#   Metrics on testing data:
#     MSE: 0.016437318176031113.
# Epoch #248
#   Metrics on training data:
#     MSE: 0.014506426639854908.
#   Metrics on testing data:
#     MSE: 0.01623707264661789.
# Epoch #249
#   Metrics on training data:
#     MSE: 0.014330988749861717.
#   Metrics on testing data:
#     MSE: 0.016039500012993813.
# Epoch #250
#   Metrics on training data:
#     MSE: 0.014157873578369617.
#   Metrics on testing data:
#     MSE: 0.015844570472836494.
# Epoch #251
#   Metrics on training data:
#     MSE: 0.013987090438604355.
#   Metrics on testing data:
#     MSE: 0.01565241813659668.
# Epoch #252
#   Metrics on training data:
#     MSE: 0.013818581588566303.
#   Metrics on testing data:
#     MSE: 0.015462702140212059.
# Epoch #253
#   Metrics on training data:
#     MSE: 0.013652149587869644.
#   Metrics on testing data:
#     MSE: 0.015275441110134125.
# Epoch #254
#   Metrics on training data:
#     MSE: 0.013487711548805237.
#   Metrics on testing data:
#     MSE: 0.015090558677911758.
# Epoch #255
#   Metrics on training data:
#     MSE: 0.013325197622179985.
#   Metrics on testing data:
#     MSE: 0.014908216893672943.
# Epoch #256
#   Metrics on training data:
#     MSE: 0.013164520263671875.
#   Metrics on testing data:
#     MSE: 0.014727962203323841.
# Epoch #257
#   Metrics on training data:
#     MSE: 0.013005654327571392.
#   Metrics on testing data:
#     MSE: 0.01454982627183199.
# Epoch #258
#   Metrics on training data:
#     MSE: 0.012848515063524246.
#   Metrics on testing data:
#     MSE: 0.014373819343745708.
# Epoch #259
#   Metrics on training data:
#     MSE: 0.012693051248788834.
#   Metrics on testing data:
#     MSE: 0.014199969358742237.
# Epoch #260
#   Metrics on training data:
#     MSE: 0.0125391511246562.
#   Metrics on testing data:
#     MSE: 0.01402804534882307.
# Epoch #261
#   Metrics on training data:
#     MSE: 0.012386860325932503.
#   Metrics on testing data:
#     MSE: 0.0138581283390522.
# Epoch #262
#   Metrics on training data:
#     MSE: 0.012236207723617554.
#   Metrics on testing data:
#     MSE: 0.013690252788364887.
# Epoch #263
#   Metrics on training data:
#     MSE: 0.012087155133485794.
#   Metrics on testing data:
#     MSE: 0.013524353504180908.
# Epoch #264
#   Metrics on training data:
#     MSE: 0.011939611285924911.
#   Metrics on testing data:
#     MSE: 0.013360369019210339.
# Epoch #265
#   Metrics on training data:
#     MSE: 0.011793659999966621.
#   Metrics on testing data:
#     MSE: 0.013198398053646088.
# Epoch #266
#   Metrics on training data:
#     MSE: 0.011649259366095066.
#   Metrics on testing data:
#     MSE: 0.013038341887295246.
# Epoch #267
#   Metrics on training data:
#     MSE: 0.01150631345808506.
#   Metrics on testing data:
#     MSE: 0.012880058959126472.
# Epoch #268
#   Metrics on training data:
#     MSE: 0.011364806443452835.
#   Metrics on testing data:
#     MSE: 0.012723589316010475.
# Epoch #269
#   Metrics on training data:
#     MSE: 0.011224761605262756.
#   Metrics on testing data:
#     MSE: 0.012568806298077106.
# Epoch #270
#   Metrics on training data:
#     MSE: 0.011086056008934975.
#   Metrics on testing data:
#     MSE: 0.012415486387908459.
# Epoch #271
#   Metrics on training data:
#     MSE: 0.010948739014565945.
#   Metrics on testing data:
#     MSE: 0.012263961136341095.
# Epoch #272
#   Metrics on training data:
#     MSE: 0.010812926106154919.
#   Metrics on testing data:
#     MSE: 0.01211429201066494.
# Epoch #273
#   Metrics on training data:
#     MSE: 0.010678568854928017.
#   Metrics on testing data:
#     MSE: 0.011966301128268242.
# Epoch #274
#   Metrics on training data:
#     MSE: 0.0105457017198205.
#   Metrics on testing data:
#     MSE: 0.011820144020020962.
# Epoch #275
#   Metrics on training data:
#     MSE: 0.010414257645606995.
#   Metrics on testing data:
#     MSE: 0.011675595305860043.
# Epoch #276
#   Metrics on training data:
#     MSE: 0.010284354910254478.
#   Metrics on testing data:
#     MSE: 0.011532641015946865.
# Epoch #277
#   Metrics on training data:
#     MSE: 0.010155955329537392.
#   Metrics on testing data:
#     MSE: 0.011391486041247845.
# Epoch #278
#   Metrics on training data:
#     MSE: 0.010029193013906479.
#   Metrics on testing data:
#     MSE: 0.011252271942794323.
# Epoch #279
#   Metrics on training data:
#     MSE: 0.009903967380523682.
#   Metrics on testing data:
#     MSE: 0.011114867404103279.
# Epoch #280
#   Metrics on training data:
#     MSE: 0.009780368767678738.
#   Metrics on testing data:
#     MSE: 0.010979236103594303.
# Epoch #281
#   Metrics on training data:
#     MSE: 0.009658361785113811.
#   Metrics on testing data:
#     MSE: 0.010845494456589222.
# Epoch #282
#   Metrics on training data:
#     MSE: 0.009538012556731701.
#   Metrics on testing data:
#     MSE: 0.01071364339441061.
# Epoch #283
#   Metrics on training data:
#     MSE: 0.00941935833543539.
#   Metrics on testing data:
#     MSE: 0.010583633556962013.
# Epoch #284
#   Metrics on training data:
#     MSE: 0.009302440099418163.
#   Metrics on testing data:
#     MSE: 0.010455569252371788.
# Epoch #285
#   Metrics on training data:
#     MSE: 0.009187220595777035.
#   Metrics on testing data:
#     MSE: 0.010329271666705608.
# Epoch #286
#   Metrics on training data:
#     MSE: 0.009073744527995586.
#   Metrics on testing data:
#     MSE: 0.010204925201833248.
# Epoch #287
#   Metrics on training data:
#     MSE: 0.008962063118815422.
#   Metrics on testing data:
#     MSE: 0.010082564316689968.
# Epoch #288
#   Metrics on training data:
#     MSE: 0.008852113969624043.
#   Metrics on testing data:
#     MSE: 0.009961964562535286.
# Epoch #289
#   Metrics on training data:
#     MSE: 0.008744018152356148.
#   Metrics on testing data:
#     MSE: 0.009843280538916588.
# Epoch #290
#   Metrics on training data:
#     MSE: 0.008637838996946812.
#   Metrics on testing data:
#     MSE: 0.009726633317768574.
# Epoch #291
#   Metrics on training data:
#     MSE: 0.00853355135768652.
#   Metrics on testing data:
#     MSE: 0.009611949324607849.
# Epoch #292
#   Metrics on training data:
#     MSE: 0.008431114256381989.
#   Metrics on testing data:
#     MSE: 0.00949926394969225.
# Epoch #293
#   Metrics on training data:
#     MSE: 0.008330544456839561.
#   Metrics on testing data:
#     MSE: 0.009388609789311886.
# Epoch #294
#   Metrics on training data:
#     MSE: 0.008231856860220432.
#   Metrics on testing data:
#     MSE: 0.009280026890337467.
# Epoch #295
#   Metrics on training data:
#     MSE: 0.008134976960718632.
#   Metrics on testing data:
#     MSE: 0.009173477999866009.
# Epoch #296
#   Metrics on training data:
#     MSE: 0.008039935491979122.
#   Metrics on testing data:
#     MSE: 0.009068872779607773.
# Epoch #297
#   Metrics on training data:
#     MSE: 0.007946743629872799.
#   Metrics on testing data:
#     MSE: 0.008966266177594662.
# Epoch #298
#   Metrics on training data:
#     MSE: 0.007855317555367947.
#   Metrics on testing data:
#     MSE: 0.008865616284310818.
# Epoch #299
#   Metrics on training data:
#     MSE: 0.007765649352222681.
#   Metrics on testing data:
#     MSE: 0.008766932412981987.

# %%
msrs = measurements.Measurement(verbose=True)
msrs.add_train_recorder('MSE', phys_bs, verbose=True)
msrs.add_test_recorder('MSE', phys_bs, verbose=True)

mlp = MLPLoRA.fully_connected_net(input_dim, output_dim, [hidden_dim], 'relu').cuda()
optimizer = torch.optim.SGD(mlp.parameters(), lr=lr)
loss_fn = torch.nn.MSELoss()

MLPLoRA.train(data_to_tensor(train_data), data_to_tensor(test_data), mlp, loss_fn, optimizer, batch_size, num_epochs, msrs)
# Out:
# Epoch #0
#   Metrics on training data:
#     MSE: 0.2620835304260254.
#   Metrics on testing data:
#     MSE: 0.26590004563331604.
# Epoch #1
#   Metrics on training data:
#     MSE: 0.2573451101779938.
#   Metrics on testing data:
#     MSE: 0.2612677812576294.
# Epoch #2
#   Metrics on training data:
#     MSE: 0.254048615694046.
#   Metrics on testing data:
#     MSE: 0.25804969668388367.
# Epoch #3
#   Metrics on training data:
#     MSE: 0.25159478187561035.
#   Metrics on testing data:
#     MSE: 0.2556613087654114.
# Epoch #4
#   Metrics on training data:
#     MSE: 0.24962179362773895.
#   Metrics on testing data:
#     MSE: 0.2537543475627899.
# Epoch #5
#   Metrics on training data:
#     MSE: 0.24794022738933563.
#   Metrics on testing data:
#     MSE: 0.2521304786205292.
# Epoch #6
#   Metrics on training data:
#     MSE: 0.24641546607017517.
#   Metrics on testing data:
#     MSE: 0.2506639361381531.
# Epoch #7
#   Metrics on training data:
#     MSE: 0.24496327340602875.
#   Metrics on testing data:
#     MSE: 0.24927657842636108.
# Epoch #8
#   Metrics on training data:
#     MSE: 0.24351812899112701.
#   Metrics on testing data:
#     MSE: 0.24789640307426453.
# Epoch #9
#   Metrics on training data:
#     MSE: 0.24202777445316315.
#   Metrics on testing data:
#     MSE: 0.24647139012813568.
# Epoch #10
#   Metrics on training data:
#     MSE: 0.24045565724372864.
#   Metrics on testing data:
#     MSE: 0.2449653446674347.
# Epoch #11
#   Metrics on training data:
#     MSE: 0.23877103626728058.
#   Metrics on testing data:
#     MSE: 0.24334795773029327.
# Epoch #12
#   Metrics on training data:
#     MSE: 0.23694740235805511.
#   Metrics on testing data:
#     MSE: 0.24159091711044312.
# Epoch #13
#   Metrics on training data:
#     MSE: 0.23495981097221375.
#   Metrics on testing data:
#     MSE: 0.23966722190380096.
# Epoch #14
#   Metrics on training data:
#     MSE: 0.23278281092643738.
#   Metrics on testing data:
#     MSE: 0.23755237460136414.
# Epoch #15
#   Metrics on training data:
#     MSE: 0.23039674758911133.
#   Metrics on testing data:
#     MSE: 0.23522871732711792.
# Epoch #16
#   Metrics on training data:
#     MSE: 0.22778092324733734.
#   Metrics on testing data:
#     MSE: 0.23267634212970734.
# Epoch #17
#   Metrics on training data:
#     MSE: 0.2249227911233902.
#   Metrics on testing data:
#     MSE: 0.2298792600631714.
# Epoch #18
#   Metrics on training data:
#     MSE: 0.2218126356601715.
#   Metrics on testing data:
#     MSE: 0.22682307660579681.
# Epoch #19
#   Metrics on training data:
#     MSE: 0.21844428777694702.
#   Metrics on testing data:
#     MSE: 0.22350363433361053.
# Epoch #20
#   Metrics on training data:
#     MSE: 0.21481554210186005.
#   Metrics on testing data:
#     MSE: 0.21992087364196777.
# Epoch #21
#   Metrics on training data:
#     MSE: 0.21093808114528656.
#   Metrics on testing data:
#     MSE: 0.21608097851276398.
# Epoch #22
#   Metrics on training data:
#     MSE: 0.20682772994041443.
#   Metrics on testing data:
#     MSE: 0.21199682354927063.
# Epoch #23
#   Metrics on training data:
#     MSE: 0.20250265300273895.
#   Metrics on testing data:
#     MSE: 0.20769165456295013.
# Epoch #24
#   Metrics on training data:
#     MSE: 0.19799555838108063.
#   Metrics on testing data:
#     MSE: 0.20319724082946777.
# Epoch #25
#   Metrics on training data:
#     MSE: 0.19334213435649872.
#   Metrics on testing data:
#     MSE: 0.198545902967453.
# Epoch #26
#   Metrics on training data:
#     MSE: 0.18859454989433289.
#   Metrics on testing data:
#     MSE: 0.19379179179668427.
# Epoch #27
#   Metrics on training data:
#     MSE: 0.18379978835582733.
#   Metrics on testing data:
#     MSE: 0.18898263573646545.
# Epoch #28
#   Metrics on training data:
#     MSE: 0.17901842296123505.
#   Metrics on testing data:
#     MSE: 0.1841791570186615.
# Epoch #29
#   Metrics on training data:
#     MSE: 0.17429867386817932.
#   Metrics on testing data:
#     MSE: 0.17943346500396729.
# Epoch #30
#   Metrics on training data:
#     MSE: 0.16968612372875214.
#   Metrics on testing data:
#     MSE: 0.17479342222213745.
# Epoch #31
#   Metrics on training data:
#     MSE: 0.16522547602653503.
#   Metrics on testing data:
#     MSE: 0.17030277848243713.
# Epoch #32
#   Metrics on training data:
#     MSE: 0.1609499454498291.
#   Metrics on testing data:
#     MSE: 0.1659969538450241.
# Epoch #33
#   Metrics on training data:
#     MSE: 0.15688154101371765.
#   Metrics on testing data:
#     MSE: 0.16189979016780853.
# Epoch #34
#   Metrics on training data:
#     MSE: 0.1530330628156662.
#   Metrics on testing data:
#     MSE: 0.15802434086799622.
# Epoch #35
#   Metrics on training data:
#     MSE: 0.14941854774951935.
#   Metrics on testing data:
#     MSE: 0.15438474714756012.
# Epoch #36
#   Metrics on training data:
#     MSE: 0.14603641629219055.
#   Metrics on testing data:
#     MSE: 0.15097962319850922.
# Epoch #37
#   Metrics on training data:
#     MSE: 0.14288318157196045.
#   Metrics on testing data:
#     MSE: 0.1478051394224167.
# Epoch #38
#   Metrics on training data:
#     MSE: 0.13994991779327393.
#   Metrics on testing data:
#     MSE: 0.14485234022140503.
# Epoch #39
#   Metrics on training data:
#     MSE: 0.13722413778305054.
#   Metrics on testing data:
#     MSE: 0.14211010932922363.
# Epoch #40
#   Metrics on training data:
#     MSE: 0.13469743728637695.
#   Metrics on testing data:
#     MSE: 0.1395680010318756.
# Epoch #41
#   Metrics on training data:
#     MSE: 0.1323549598455429.
#   Metrics on testing data:
#     MSE: 0.13721127808094025.
# Epoch #42
#   Metrics on training data:
#     MSE: 0.13018280267715454.
#   Metrics on testing data:
#     MSE: 0.13502751290798187.
# Epoch #43
#   Metrics on training data:
#     MSE: 0.12816818058490753.
#   Metrics on testing data:
#     MSE: 0.13300250470638275.
# Epoch #44
#   Metrics on training data:
#     MSE: 0.12629538774490356.
#   Metrics on testing data:
#     MSE: 0.13112075626850128.
# Epoch #45
#   Metrics on training data:
#     MSE: 0.124551922082901.
#   Metrics on testing data:
#     MSE: 0.12937012314796448.
# Epoch #46
#   Metrics on training data:
#     MSE: 0.12292817234992981.
#   Metrics on testing data:
#     MSE: 0.1277405023574829.
# Epoch #47
#   Metrics on training data:
#     MSE: 0.1214120090007782.
#   Metrics on testing data:
#     MSE: 0.12621957063674927.
# Epoch #48
#   Metrics on training data:
#     MSE: 0.11999265104532242.
#   Metrics on testing data:
#     MSE: 0.1247970312833786.
# Epoch #49
#   Metrics on training data:
#     MSE: 0.11866261810064316.
#   Metrics on testing data:
#     MSE: 0.12346488237380981.
# Epoch #50
#   Metrics on training data:
#     MSE: 0.11741281300783157.
#   Metrics on testing data:
#     MSE: 0.12221494317054749.
# Epoch #51
#   Metrics on training data:
#     MSE: 0.11623746901750565.
#   Metrics on testing data:
#     MSE: 0.12104131281375885.
# Epoch #52
#   Metrics on training data:
#     MSE: 0.11512770503759384.
#   Metrics on testing data:
#     MSE: 0.11993474513292313.
# Epoch #53
#   Metrics on training data:
#     MSE: 0.11408102512359619.
#   Metrics on testing data:
#     MSE: 0.11889279633760452.
# Epoch #54
#   Metrics on training data:
#     MSE: 0.11308871954679489.
#   Metrics on testing data:
#     MSE: 0.11790656298398972.
# Epoch #55
#   Metrics on training data:
#     MSE: 0.11214777827262878.
#   Metrics on testing data:
#     MSE: 0.11697359383106232.
# Epoch #56
#   Metrics on training data:
#     MSE: 0.11125463247299194.
#   Metrics on testing data:
#     MSE: 0.11608988046646118.
# Epoch #57
#   Metrics on training data:
#     MSE: 0.11040566116571426.
#   Metrics on testing data:
#     MSE: 0.11525194346904755.
# Epoch #58
#   Metrics on training data:
#     MSE: 0.10959814488887787.
#   Metrics on testing data:
#     MSE: 0.11445671319961548.
# Epoch #59
#   Metrics on training data:
#     MSE: 0.10882924497127533.
#   Metrics on testing data:
#     MSE: 0.11370126903057098.
# Epoch #60
#   Metrics on training data:
#     MSE: 0.10809584707021713.
#   Metrics on testing data:
#     MSE: 0.11298258602619171.
# Epoch #61
#   Metrics on training data:
#     MSE: 0.10739587247371674.
#   Metrics on testing data:
#     MSE: 0.1122984066605568.
# Epoch #62
#   Metrics on training data:
#     MSE: 0.10672613233327866.
#   Metrics on testing data:
#     MSE: 0.11164513975381851.
# Epoch #63
#   Metrics on training data:
#     MSE: 0.10608585923910141.
#   Metrics on testing data:
#     MSE: 0.1110217496752739.
# Epoch #64
#   Metrics on training data:
#     MSE: 0.10547330975532532.
#   Metrics on testing data:
#     MSE: 0.1104266494512558.
# Epoch #65
#   Metrics on training data:
#     MSE: 0.10488668829202652.
#   Metrics on testing data:
#     MSE: 0.10985849052667618.
# Epoch #66
#   Metrics on training data:
#     MSE: 0.10432411730289459.
#   Metrics on testing data:
#     MSE: 0.1093147024512291.
# Epoch #67
#   Metrics on training data:
#     MSE: 0.10378407686948776.
#   Metrics on testing data:
#     MSE: 0.10879385471343994.
# Epoch #68
#   Metrics on training data:
#     MSE: 0.10326500982046127.
#   Metrics on testing data:
#     MSE: 0.10829459130764008.
# Epoch #69
#   Metrics on training data:
#     MSE: 0.10276620835065842.
#   Metrics on testing data:
#     MSE: 0.10781523585319519.
# Epoch #70
#   Metrics on training data:
#     MSE: 0.1022857204079628.
#   Metrics on testing data:
#     MSE: 0.10735505819320679.
# Epoch #71
#   Metrics on training data:
#     MSE: 0.10182318091392517.
#   Metrics on testing data:
#     MSE: 0.10691263526678085.
# Epoch #72
#   Metrics on training data:
#     MSE: 0.10137735307216644.
#   Metrics on testing data:
#     MSE: 0.10648726671934128.
# Epoch #73
#   Metrics on training data:
#     MSE: 0.10094769299030304.
#   Metrics on testing data:
#     MSE: 0.1060781329870224.
# Epoch #74
#   Metrics on training data:
#     MSE: 0.10053259879350662.
#   Metrics on testing data:
#     MSE: 0.10568344593048096.
# Epoch #75
#   Metrics on training data:
#     MSE: 0.10013164579868317.
#   Metrics on testing data:
#     MSE: 0.10530286282300949.
# Epoch #76
#   Metrics on training data:
#     MSE: 0.0997438058257103.
#   Metrics on testing data:
#     MSE: 0.10493570566177368.
# Epoch #77
#   Metrics on training data:
#     MSE: 0.09936930984258652.
#   Metrics on testing data:
#     MSE: 0.10458129644393921.
# Epoch #78
#   Metrics on training data:
#     MSE: 0.09900661557912827.
#   Metrics on testing data:
#     MSE: 0.10423872619867325.
# Epoch #79
#   Metrics on training data:
#     MSE: 0.09865636378526688.
#   Metrics on testing data:
#     MSE: 0.1039084643125534.
# Epoch #80
#   Metrics on training data:
#     MSE: 0.09831462055444717.
#   Metrics on testing data:
#     MSE: 0.10358712077140808.
# Epoch #81
#   Metrics on training data:
#     MSE: 0.0979861170053482.
#   Metrics on testing data:
#     MSE: 0.10327828675508499.
# Epoch #82
#   Metrics on training data:
#     MSE: 0.09766564518213272.
#   Metrics on testing data:
#     MSE: 0.10297773033380508.
# Epoch #83
#   Metrics on training data:
#     MSE: 0.09735506027936935.
#   Metrics on testing data:
#     MSE: 0.10268658399581909.
# Epoch #84
#   Metrics on training data:
#     MSE: 0.0970534086227417.
#   Metrics on testing data:
#     MSE: 0.10240426659584045.
# Epoch #85
#   Metrics on training data:
#     MSE: 0.09676045924425125.
#   Metrics on testing data:
#     MSE: 0.10213017463684082.
# Epoch #86
#   Metrics on training data:
#     MSE: 0.0964764803647995.
#   Metrics on testing data:
#     MSE: 0.10186456888914108.
# Epoch #87
#   Metrics on training data:
#     MSE: 0.09620001912117004.
#   Metrics on testing data:
#     MSE: 0.10160648077726364.
# Epoch #88
#   Metrics on training data:
#     MSE: 0.09593072533607483.
#   Metrics on testing data:
#     MSE: 0.10135556757450104.
# Epoch #89
#   Metrics on training data:
#     MSE: 0.0956692099571228.
#   Metrics on testing data:
#     MSE: 0.10111186653375626.
# Epoch #90
#   Metrics on training data:
#     MSE: 0.09541405737400055.
#   Metrics on testing data:
#     MSE: 0.1008746549487114.
# Epoch #91
#   Metrics on training data:
#     MSE: 0.09516683965921402.
#   Metrics on testing data:
#     MSE: 0.10064494609832764.
# Epoch #92
#   Metrics on training data:
#     MSE: 0.09492594748735428.
#   Metrics on testing data:
#     MSE: 0.10042137652635574.
# Epoch #93
#   Metrics on training data:
#     MSE: 0.09469206631183624.
#   Metrics on testing data:
#     MSE: 0.10020472854375839.
# Epoch #94
#   Metrics on training data:
#     MSE: 0.0944637656211853.
#   Metrics on testing data:
#     MSE: 0.09999337047338486.
# Epoch #95
#   Metrics on training data:
#     MSE: 0.09424145519733429.
#   Metrics on testing data:
#     MSE: 0.09978777170181274.
# Epoch #96
#   Metrics on training data:
#     MSE: 0.09402567148208618.
#   Metrics on testing data:
#     MSE: 0.09958820044994354.
# Epoch #97
#   Metrics on training data:
#     MSE: 0.09381364285945892.
#   Metrics on testing data:
#     MSE: 0.09939230978488922.
# Epoch #98
#   Metrics on training data:
#     MSE: 0.09360994398593903.
#   Metrics on testing data:
#     MSE: 0.09920446574687958.
# Epoch #99
#   Metrics on training data:
#     MSE: 0.09340956062078476.
#   Metrics on testing data:
#     MSE: 0.09901965409517288.
# Epoch #100
#   Metrics on training data:
#     MSE: 0.09321482479572296.
#   Metrics on testing data:
#     MSE: 0.09884030371904373.
# Epoch #101
#   Metrics on training data:
#     MSE: 0.09302257746458054.
#   Metrics on testing data:
#     MSE: 0.09866342693567276.
# Epoch #102
#   Metrics on training data:
#     MSE: 0.0928388312458992.
#   Metrics on testing data:
#     MSE: 0.09849463403224945.
# Epoch #103
#   Metrics on training data:
#     MSE: 0.09265423566102982.
#   Metrics on testing data:
#     MSE: 0.09832530468702316.
# Epoch #104
#   Metrics on training data:
#     MSE: 0.09247756749391556.
#   Metrics on testing data:
#     MSE: 0.09816312789916992.
# Epoch #105
#   Metrics on training data:
#     MSE: 0.09230416268110275.
#   Metrics on testing data:
#     MSE: 0.0980047658085823.
# Epoch #106
#   Metrics on training data:
#     MSE: 0.0921352356672287.
#   Metrics on testing data:
#     MSE: 0.0978507548570633.
# Epoch #107
#   Metrics on training data:
#     MSE: 0.0919695496559143.
#   Metrics on testing data:
#     MSE: 0.09769977629184723.
# Epoch #108
#   Metrics on training data:
#     MSE: 0.09180809557437897.
#   Metrics on testing data:
#     MSE: 0.0975528210401535.
# Epoch #109
#   Metrics on training data:
#     MSE: 0.09164997190237045.
#   Metrics on testing data:
#     MSE: 0.09740898758172989.
# Epoch #110
#   Metrics on training data:
#     MSE: 0.09149527549743652.
#   Metrics on testing data:
#     MSE: 0.0972684845328331.
# Epoch #111
#   Metrics on training data:
#     MSE: 0.09134267270565033.
#   Metrics on testing data:
#     MSE: 0.09712937474250793.
# Epoch #112
#   Metrics on training data:
#     MSE: 0.09119638800621033.
#   Metrics on testing data:
#     MSE: 0.09699675440788269.
# Epoch #113
#   Metrics on training data:
#     MSE: 0.0910518616437912.
#   Metrics on testing data:
#     MSE: 0.09686574339866638.
# Epoch #114
#   Metrics on training data:
#     MSE: 0.09090817719697952.
#   Metrics on testing data:
#     MSE: 0.09673536568880081.
# Epoch #115
#   Metrics on training data:
#     MSE: 0.09077022224664688.
#   Metrics on testing data:
#     MSE: 0.0966109186410904.
# Epoch #116
#   Metrics on training data:
#     MSE: 0.09063687920570374.
#   Metrics on testing data:
#     MSE: 0.09649015963077545.
# Epoch #117
#   Metrics on training data:
#     MSE: 0.09050013870000839.
#   Metrics on testing data:
#     MSE: 0.09636659920215607.
# Epoch #118
#   Metrics on training data:
#     MSE: 0.0903715267777443.
#   Metrics on testing data:
#     MSE: 0.09625110030174255.
# Epoch #119
#   Metrics on training data:
#     MSE: 0.09024319797754288.
#   Metrics on testing data:
#     MSE: 0.09613583236932755.
# Epoch #120
#   Metrics on training data:
#     MSE: 0.09011628478765488.
#   Metrics on testing data:
#     MSE: 0.09602189809083939.
# Epoch #121
#   Metrics on training data:
#     MSE: 0.0899956077337265.
#   Metrics on testing data:
#     MSE: 0.09591341763734818.
# Epoch #122
#   Metrics on training data:
#     MSE: 0.08987465500831604.
#   Metrics on testing data:
#     MSE: 0.0958050936460495.
# Epoch #123
#   Metrics on training data:
#     MSE: 0.08975452929735184.
#   Metrics on testing data:
#     MSE: 0.09569693356752396.
# Epoch #124
#   Metrics on training data:
#     MSE: 0.0896402969956398.
#   Metrics on testing data:
#     MSE: 0.09559456259012222.
# Epoch #125
#   Metrics on training data:
#     MSE: 0.0895237922668457.
#   Metrics on testing data:
#     MSE: 0.0954899787902832.
# Epoch #126
#   Metrics on training data:
#     MSE: 0.08941306173801422.
#   Metrics on testing data:
#     MSE: 0.09539095312356949.
# Epoch #127
#   Metrics on training data:
#     MSE: 0.08930080384016037.
#   Metrics on testing data:
#     MSE: 0.09529054164886475.
# Epoch #128
#   Metrics on training data:
#     MSE: 0.0891919657588005.
#   Metrics on testing data:
#     MSE: 0.09519347548484802.
# Epoch #129
#   Metrics on training data:
#     MSE: 0.08908789604902267.
#   Metrics on testing data:
#     MSE: 0.09510071575641632.
# Epoch #130
#   Metrics on training data:
#     MSE: 0.08897922188043594.
#   Metrics on testing data:
#     MSE: 0.09500394761562347.
# Epoch #131
#   Metrics on training data:
#     MSE: 0.08887562155723572.
#   Metrics on testing data:
#     MSE: 0.09491176158189774.
# Epoch #132
#   Metrics on training data:
#     MSE: 0.08877541124820709.
#   Metrics on testing data:
#     MSE: 0.09482289850711823.
# Epoch #133
#   Metrics on training data:
#     MSE: 0.08867335319519043.
#   Metrics on testing data:
#     MSE: 0.09473215043544769.
# Epoch #134
#   Metrics on training data:
#     MSE: 0.08857457339763641.
#   Metrics on testing data:
#     MSE: 0.09464482218027115.
# Epoch #135
#   Metrics on training data:
#     MSE: 0.08848083019256592.
#   Metrics on testing data:
#     MSE: 0.09456223249435425.
# Epoch #136
#   Metrics on training data:
#     MSE: 0.0883832722902298.
#   Metrics on testing data:
#     MSE: 0.09447570145130157.
# Epoch #137
#   Metrics on training data:
#     MSE: 0.08828867226839066.
#   Metrics on testing data:
#     MSE: 0.09439250826835632.
# Epoch #138
#   Metrics on training data:
#     MSE: 0.08819665014743805.
#   Metrics on testing data:
#     MSE: 0.09431156516075134.
# Epoch #139
#   Metrics on training data:
#     MSE: 0.0881032720208168.
#   Metrics on testing data:
#     MSE: 0.0942293107509613.
# Epoch #140
#   Metrics on training data:
#     MSE: 0.08801336586475372.
#   Metrics on testing data:
#     MSE: 0.09415014833211899.
# Epoch #141
#   Metrics on training data:
#     MSE: 0.08792410790920258.
#   Metrics on testing data:
#     MSE: 0.09407199174165726.
# Epoch #142
#   Metrics on training data:
#     MSE: 0.08783537149429321.
#   Metrics on testing data:
#     MSE: 0.09399444609880447.
# Epoch #143
#   Metrics on training data:
#     MSE: 0.08774850517511368.
#   Metrics on testing data:
#     MSE: 0.09391872584819794.
# Epoch #144
#   Metrics on training data:
#     MSE: 0.08766083419322968.
#   Metrics on testing data:
#     MSE: 0.0938422754406929.
# Epoch #145
#   Metrics on training data:
#     MSE: 0.08757522702217102.
#   Metrics on testing data:
#     MSE: 0.09376785159111023.
# Epoch #146
#   Metrics on training data:
#     MSE: 0.08748927712440491.
#   Metrics on testing data:
#     MSE: 0.09369311481714249.
# Epoch #147
#   Metrics on training data:
#     MSE: 0.08740582317113876.
#   Metrics on testing data:
#     MSE: 0.09362062066793442.
# Epoch #148
#   Metrics on training data:
#     MSE: 0.08732454478740692.
#   Metrics on testing data:
#     MSE: 0.09355001151561737.
# Epoch #149
#   Metrics on training data:
#     MSE: 0.08724083006381989.
#   Metrics on testing data:
#     MSE: 0.09347762167453766.
# Epoch #150
#   Metrics on training data:
#     MSE: 0.08716154843568802.
#   Metrics on testing data:
#     MSE: 0.09340915083885193.
# Epoch #151
#   Metrics on training data:
#     MSE: 0.08707910776138306.
#   Metrics on testing data:
#     MSE: 0.09333772212266922.
# Epoch #152
#   Metrics on training data:
#     MSE: 0.08700207620859146.
#   Metrics on testing data:
#     MSE: 0.09327097982168198.
# Epoch #153
#   Metrics on training data:
#     MSE: 0.08692120015621185.
#   Metrics on testing data:
#     MSE: 0.0932013988494873.
# Epoch #154
#   Metrics on training data:
#     MSE: 0.08684486895799637.
#   Metrics on testing data:
#     MSE: 0.09313540905714035.
# Epoch #155
#   Metrics on training data:
#     MSE: 0.08676834404468536.
#   Metrics on testing data:
#     MSE: 0.09306913614273071.
# Epoch #156
#   Metrics on training data:
#     MSE: 0.08669082075357437.
#   Metrics on testing data:
#     MSE: 0.09300220757722855.
# Epoch #157
#   Metrics on training data:
#     MSE: 0.08661426603794098.
#   Metrics on testing data:
#     MSE: 0.09293590486049652.
# Epoch #158
#   Metrics on training data:
#     MSE: 0.08654123544692993.
#   Metrics on testing data:
#     MSE: 0.09287277609109879.
# Epoch #159
#   Metrics on training data:
#     MSE: 0.08646595478057861.
#   Metrics on testing data:
#     MSE: 0.09280756115913391.
# Epoch #160
#   Metrics on training data:
#     MSE: 0.08639460057020187.
#   Metrics on testing data:
#     MSE: 0.09274683147668839.
# Epoch #161
#   Metrics on training data:
#     MSE: 0.08632343262434006.
#   Metrics on testing data:
#     MSE: 0.09268580377101898.
# Epoch #162
#   Metrics on training data:
#     MSE: 0.08625208586454391.
#   Metrics on testing data:
#     MSE: 0.09262444823980331.
# Epoch #163
#   Metrics on training data:
#     MSE: 0.08617863804101944.
#   Metrics on testing data:
#     MSE: 0.09256172180175781.
# Epoch #164
#   Metrics on training data:
#     MSE: 0.0861077830195427.
#   Metrics on testing data:
#     MSE: 0.09250106662511826.
# Epoch #165
#   Metrics on training data:
#     MSE: 0.08603733777999878.
#   Metrics on testing data:
#     MSE: 0.09244094043970108.
# Epoch #166
#   Metrics on training data:
#     MSE: 0.08596840500831604.
#   Metrics on testing data:
#     MSE: 0.09238199144601822.
# Epoch #167
#   Metrics on training data:
#     MSE: 0.08589807152748108.
#   Metrics on testing data:
#     MSE: 0.09232205897569656.
# Epoch #168
#   Metrics on training data:
#     MSE: 0.08582890778779984.
#   Metrics on testing data:
#     MSE: 0.09226294606924057.
# Epoch #169
#   Metrics on training data:
#     MSE: 0.08576187491416931.
#   Metrics on testing data:
#     MSE: 0.0922057256102562.
# Epoch #170
#   Metrics on training data:
#     MSE: 0.08569413423538208.
#   Metrics on testing data:
#     MSE: 0.09214825928211212.
# Epoch #171
#   Metrics on training data:
#     MSE: 0.08562517911195755.
#   Metrics on testing data:
#     MSE: 0.09208951145410538.
# Epoch #172
#   Metrics on training data:
#     MSE: 0.0855587050318718.
#   Metrics on testing data:
#     MSE: 0.0920327752828598.
# Epoch #173
#   Metrics on training data:
#     MSE: 0.085493303835392.
#   Metrics on testing data:
#     MSE: 0.0919773206114769.
# Epoch #174
#   Metrics on training data:
#     MSE: 0.08542731404304504.
#   Metrics on testing data:
#     MSE: 0.09192096441984177.
# Epoch #175
#   Metrics on training data:
#     MSE: 0.08536109328269958.
#   Metrics on testing data:
#     MSE: 0.09186461567878723.
# Epoch #176
#   Metrics on training data:
#     MSE: 0.08529556542634964.
#   Metrics on testing data:
#     MSE: 0.09180884063243866.
# Epoch #177
#   Metrics on training data:
#     MSE: 0.08523332327604294.
#   Metrics on testing data:
#     MSE: 0.09175589680671692.
# Epoch #178
#   Metrics on training data:
#     MSE: 0.08516846597194672.
#   Metrics on testing data:
#     MSE: 0.09170056879520416.
# Epoch #179
#   Metrics on training data:
#     MSE: 0.08510372042655945.
#   Metrics on testing data:
#     MSE: 0.09164528548717499.
# Epoch #180
#   Metrics on training data:
#     MSE: 0.08504021912813187.
#   Metrics on testing data:
#     MSE: 0.09159133583307266.
# Epoch #181
#   Metrics on training data:
#     MSE: 0.08497676253318787.
#   Metrics on testing data:
#     MSE: 0.09153735637664795.
# Epoch #182
#   Metrics on training data:
#     MSE: 0.08491522073745728.
#   Metrics on testing data:
#     MSE: 0.0914849117398262.
# Epoch #183
#   Metrics on training data:
#     MSE: 0.08485233038663864.
#   Metrics on testing data:
#     MSE: 0.09143226593732834.
# Epoch #184
#   Metrics on training data:
#     MSE: 0.0847918912768364.
#   Metrics on testing data:
#     MSE: 0.09138109534978867.
# Epoch #185
#   Metrics on training data:
#     MSE: 0.08472902327775955.
#   Metrics on testing data:
#     MSE: 0.0913279801607132.
# Epoch #186
#   Metrics on training data:
#     MSE: 0.08466844260692596.
#   Metrics on testing data:
#     MSE: 0.09127689152956009.
# Epoch #187
#   Metrics on training data:
#     MSE: 0.08460837602615356.
#   Metrics on testing data:
#     MSE: 0.09122603386640549.
# Epoch #188
#   Metrics on training data:
#     MSE: 0.0845470279455185.
#   Metrics on testing data:
#     MSE: 0.09117447584867477.
# Epoch #189
#   Metrics on training data:
#     MSE: 0.08448658883571625.
#   Metrics on testing data:
#     MSE: 0.09112351387739182.
# Epoch #190
#   Metrics on training data:
#     MSE: 0.0844273641705513.
#   Metrics on testing data:
#     MSE: 0.0910734310746193.
# Epoch #191
#   Metrics on training data:
#     MSE: 0.08436769992113113.
#   Metrics on testing data:
#     MSE: 0.09102310985326767.
# Epoch #192
#   Metrics on training data:
#     MSE: 0.08431003987789154.
#   Metrics on testing data:
#     MSE: 0.09097431600093842.
# Epoch #193
#   Metrics on training data:
#     MSE: 0.08425004780292511.
#   Metrics on testing data:
#     MSE: 0.0909237414598465.
# Epoch #194
#   Metrics on training data:
#     MSE: 0.0841916874051094.
#   Metrics on testing data:
#     MSE: 0.09087482839822769.
# Epoch #195
#   Metrics on training data:
#     MSE: 0.08413485437631607.
#   Metrics on testing data:
#     MSE: 0.09082714468240738.
# Epoch #196
#   Metrics on training data:
#     MSE: 0.08407548069953918.
#   Metrics on testing data:
#     MSE: 0.09077724069356918.
# Epoch #197
#   Metrics on training data:
#     MSE: 0.08401811122894287.
#   Metrics on testing data:
#     MSE: 0.0907287746667862.
# Epoch #198
#   Metrics on training data:
#     MSE: 0.08396229147911072.
#   Metrics on testing data:
#     MSE: 0.09068220853805542.
# Epoch #199
#   Metrics on training data:
#     MSE: 0.08390263468027115.
#   Metrics on testing data:
#     MSE: 0.09063203632831573.
# Epoch #200
#   Metrics on training data:
#     MSE: 0.08384565263986588.
#   Metrics on testing data:
#     MSE: 0.09058433771133423.
# Epoch #201
#   Metrics on training data:
#     MSE: 0.08378899097442627.
#   Metrics on testing data:
#     MSE: 0.09053674340248108.
# Epoch #202
#   Metrics on training data:
#     MSE: 0.08373244106769562.
#   Metrics on testing data:
#     MSE: 0.09048926085233688.
# Epoch #203
#   Metrics on training data:
#     MSE: 0.0836765244603157.
#   Metrics on testing data:
#     MSE: 0.09044252336025238.
# Epoch #204
#   Metrics on training data:
#     MSE: 0.08362238854169846.
#   Metrics on testing data:
#     MSE: 0.09039729088544846.
# Epoch #205
#   Metrics on training data:
#     MSE: 0.08356702327728271.
#   Metrics on testing data:
#     MSE: 0.09035121649503708.
# Epoch #206
#   Metrics on training data:
#     MSE: 0.08351138979196548.
#   Metrics on testing data:
#     MSE: 0.09030510485172272.
# Epoch #207
#   Metrics on training data:
#     MSE: 0.08345808833837509.
#   Metrics on testing data:
#     MSE: 0.09026042371988297.
# Epoch #208
#   Metrics on training data:
#     MSE: 0.08340266346931458.
#   Metrics on testing data:
#     MSE: 0.09021435678005219.
# Epoch #209
#   Metrics on training data:
#     MSE: 0.08334919810295105.
#   Metrics on testing data:
#     MSE: 0.09017004072666168.
# Epoch #210
#   Metrics on training data:
#     MSE: 0.08329471200704575.
#   Metrics on testing data:
#     MSE: 0.0901249423623085.
# Epoch #211
#   Metrics on training data:
#     MSE: 0.0832398310303688.
#   Metrics on testing data:
#     MSE: 0.0900791808962822.
# Epoch #212
#   Metrics on training data:
#     MSE: 0.08318775147199631.
#   Metrics on testing data:
#     MSE: 0.09003569930791855.
# Epoch #213
#   Metrics on training data:
#     MSE: 0.08313346654176712.
#   Metrics on testing data:
#     MSE: 0.08999055624008179.
# Epoch #214
#   Metrics on training data:
#     MSE: 0.08307994157075882.
#   Metrics on testing data:
#     MSE: 0.08994631469249725.
# Epoch #215
#   Metrics on training data:
#     MSE: 0.08302689343690872.
#   Metrics on testing data:
#     MSE: 0.08990231156349182.
# Epoch #216
#   Metrics on training data:
#     MSE: 0.08297588676214218.
#   Metrics on testing data:
#     MSE: 0.0898599773645401.
# Epoch #217
#   Metrics on training data:
#     MSE: 0.08292238414287567.
#   Metrics on testing data:
#     MSE: 0.08981598168611526.
# Epoch #218
#   Metrics on training data:
#     MSE: 0.08287002891302109.
#   Metrics on testing data:
#     MSE: 0.08977282792329788.
# Epoch #219
#   Metrics on training data:
#     MSE: 0.08281800150871277.
#   Metrics on testing data:
#     MSE: 0.08972974121570587.
# Epoch #220
#   Metrics on training data:
#     MSE: 0.08276684582233429.
#   Metrics on testing data:
#     MSE: 0.08968747407197952.
# Epoch #221
#   Metrics on training data:
#     MSE: 0.08271543681621552.
#   Metrics on testing data:
#     MSE: 0.08964498341083527.
# Epoch #222
#   Metrics on training data:
#     MSE: 0.08266548067331314.
#   Metrics on testing data:
#     MSE: 0.08960393071174622.
# Epoch #223
#   Metrics on training data:
#     MSE: 0.08261337131261826.
#   Metrics on testing data:
#     MSE: 0.08956137299537659.
# Epoch #224
#   Metrics on training data:
#     MSE: 0.08256269246339798.
#   Metrics on testing data:
#     MSE: 0.08951977640390396.
# Epoch #225
#   Metrics on training data:
#     MSE: 0.08251205831766129.
#   Metrics on testing data:
#     MSE: 0.08947794139385223.
# Epoch #226
#   Metrics on training data:
#     MSE: 0.08246133476495743.
#   Metrics on testing data:
#     MSE: 0.08943640440702438.
# Epoch #227
#   Metrics on training data:
#     MSE: 0.08241119235754013.
#   Metrics on testing data:
#     MSE: 0.08939535170793533.
# Epoch #228
#   Metrics on training data:
#     MSE: 0.08236142247915268.
#   Metrics on testing data:
#     MSE: 0.08935466408729553.
# Epoch #229
#   Metrics on training data:
#     MSE: 0.08231191337108612.
#   Metrics on testing data:
#     MSE: 0.08931427448987961.
# Epoch #230
#   Metrics on training data:
#     MSE: 0.08226175606250763.
#   Metrics on testing data:
#     MSE: 0.08927353471517563.
# Epoch #231
#   Metrics on training data:
#     MSE: 0.08221215754747391.
#   Metrics on testing data:
#     MSE: 0.08923278003931046.
# Epoch #232
#   Metrics on training data:
#     MSE: 0.08216298371553421.
#   Metrics on testing data:
#     MSE: 0.08919233828783035.
# Epoch #233
#   Metrics on training data:
#     MSE: 0.08211518824100494.
#   Metrics on testing data:
#     MSE: 0.08915368467569351.
# Epoch #234
#   Metrics on training data:
#     MSE: 0.08206649869680405.
#   Metrics on testing data:
#     MSE: 0.08911394327878952.
# Epoch #235
#   Metrics on training data:
#     MSE: 0.08201653510332108.
#   Metrics on testing data:
#     MSE: 0.08907356858253479.
# Epoch #236
#   Metrics on training data:
#     MSE: 0.08196792006492615.
#   Metrics on testing data:
#     MSE: 0.08903447538614273.
# Epoch #237
#   Metrics on training data:
#     MSE: 0.08191948384046555.
#   Metrics on testing data:
#     MSE: 0.08899498730897903.
# Epoch #238
#   Metrics on training data:
#     MSE: 0.08187185972929001.
#   Metrics on testing data:
#     MSE: 0.0889558419585228.
# Epoch #239
#   Metrics on training data:
#     MSE: 0.08182429522275925.
#   Metrics on testing data:
#     MSE: 0.08891724050045013.
# Epoch #240
#   Metrics on training data:
#     MSE: 0.08177715539932251.
#   Metrics on testing data:
#     MSE: 0.08887900412082672.
# Epoch #241
#   Metrics on training data:
#     MSE: 0.08172893524169922.
#   Metrics on testing data:
#     MSE: 0.08883995562791824.
# Epoch #242
#   Metrics on training data:
#     MSE: 0.08168324083089828.
#   Metrics on testing data:
#     MSE: 0.08880269527435303.
# Epoch #243
#   Metrics on training data:
#     MSE: 0.08163560926914215.
#   Metrics on testing data:
#     MSE: 0.08876364678144455.
# Epoch #244
#   Metrics on training data:
#     MSE: 0.08158985525369644.
#   Metrics on testing data:
#     MSE: 0.08872675150632858.
# Epoch #245
#   Metrics on training data:
#     MSE: 0.08154173195362091.
#   Metrics on testing data:
#     MSE: 0.08868785202503204.
# Epoch #246
#   Metrics on training data:
#     MSE: 0.08149538189172745.
#   Metrics on testing data:
#     MSE: 0.08865034580230713.
# Epoch #247
#   Metrics on training data:
#     MSE: 0.08144962042570114.
#   Metrics on testing data:
#     MSE: 0.08861343562602997.
# Epoch #248
#   Metrics on training data:
#     MSE: 0.08140445500612259.
#   Metrics on testing data:
#     MSE: 0.08857722580432892.
# Epoch #249
#   Metrics on training data:
#     MSE: 0.08135782927274704.
#   Metrics on testing data:
#     MSE: 0.08853920549154282.
# Epoch #250
#   Metrics on training data:
#     MSE: 0.08131147176027298.
#   Metrics on testing data:
#     MSE: 0.08850207924842834.
# Epoch #251
#   Metrics on training data:
#     MSE: 0.08126778155565262.
#   Metrics on testing data:
#     MSE: 0.0884668156504631.
# Epoch #252
#   Metrics on training data:
#     MSE: 0.08122124522924423.
#   Metrics on testing data:
#     MSE: 0.0884300023317337.
# Epoch #253
#   Metrics on training data:
#     MSE: 0.08117614686489105.
#   Metrics on testing data:
#     MSE: 0.08839353173971176.
# Epoch #254
#   Metrics on training data:
#     MSE: 0.08112970739603043.
#   Metrics on testing data:
#     MSE: 0.08835619688034058.
# Epoch #255
#   Metrics on training data:
#     MSE: 0.08108486980199814.
#   Metrics on testing data:
#     MSE: 0.08832022547721863.
# Epoch #256
#   Metrics on training data:
#     MSE: 0.08104042708873749.
#   Metrics on testing data:
#     MSE: 0.08828448504209518.
# Epoch #257
#   Metrics on training data:
#     MSE: 0.08099715411663055.
#   Metrics on testing data:
#     MSE: 0.08824960887432098.
# Epoch #258
#   Metrics on training data:
#     MSE: 0.08095185458660126.
#   Metrics on testing data:
#     MSE: 0.08821306377649307.
# Epoch #259
#   Metrics on training data:
#     MSE: 0.08090738207101822.
#   Metrics on testing data:
#     MSE: 0.08817765861749649.
# Epoch #260
#   Metrics on training data:
#     MSE: 0.08086512237787247.
#   Metrics on testing data:
#     MSE: 0.08814354240894318.
# Epoch #261
#   Metrics on training data:
#     MSE: 0.0808195248246193.
#   Metrics on testing data:
#     MSE: 0.08810678869485855.
# Epoch #262
#   Metrics on training data:
#     MSE: 0.08077633380889893.
#   Metrics on testing data:
#     MSE: 0.08807206898927689.
# Epoch #263
#   Metrics on training data:
#     MSE: 0.08073268830776215.
#   Metrics on testing data:
#     MSE: 0.08803726732730865.
# Epoch #264
#   Metrics on training data:
#     MSE: 0.08069077879190445.
#   Metrics on testing data:
#     MSE: 0.08800368010997772.
# Epoch #265
#   Metrics on training data:
#     MSE: 0.08064665645360947.
#   Metrics on testing data:
#     MSE: 0.08796828240156174.
# Epoch #266
#   Metrics on training data:
#     MSE: 0.08060359954833984.
#   Metrics on testing data:
#     MSE: 0.08793386071920395.
# Epoch #267
#   Metrics on training data:
#     MSE: 0.08055933564901352.
#   Metrics on testing data:
#     MSE: 0.08789873123168945.
# Epoch #268
#   Metrics on training data:
#     MSE: 0.08051757514476776.
#   Metrics on testing data:
#     MSE: 0.08786534518003464.
# Epoch #269
#   Metrics on training data:
#     MSE: 0.08047526329755783.
#   Metrics on testing data:
#     MSE: 0.08783227205276489.
# Epoch #270
#   Metrics on training data:
#     MSE: 0.0804310068488121.
#   Metrics on testing data:
#     MSE: 0.08779694139957428.
# Epoch #271
#   Metrics on training data:
#     MSE: 0.08039099723100662.
#   Metrics on testing data:
#     MSE: 0.08776562660932541.
# Epoch #272
#   Metrics on training data:
#     MSE: 0.08034685999155045.
#   Metrics on testing data:
#     MSE: 0.08773041516542435.
# Epoch #273
#   Metrics on training data:
#     MSE: 0.08030465245246887.
#   Metrics on testing data:
#     MSE: 0.0876968652009964.
# Epoch #274
#   Metrics on training data:
#     MSE: 0.08026278764009476.
#   Metrics on testing data:
#     MSE: 0.08766406774520874.
# Epoch #275
#   Metrics on training data:
#     MSE: 0.08022008091211319.
#   Metrics on testing data:
#     MSE: 0.08762966841459274.
# Epoch #276
#   Metrics on training data:
#     MSE: 0.08017876744270325.
#   Metrics on testing data:
#     MSE: 0.08759710192680359.
# Epoch #277
#   Metrics on training data:
#     MSE: 0.08013834804296494.
#   Metrics on testing data:
#     MSE: 0.08756528794765472.
# Epoch #278
#   Metrics on training data:
#     MSE: 0.08009643852710724.
#   Metrics on testing data:
#     MSE: 0.08753208070993423.
# Epoch #279
#   Metrics on training data:
#     MSE: 0.08005483448505402.
#   Metrics on testing data:
#     MSE: 0.08749958127737045.
# Epoch #280
#   Metrics on training data:
#     MSE: 0.08001405745744705.
#   Metrics on testing data:
#     MSE: 0.08746720105409622.
# Epoch #281
#   Metrics on training data:
#     MSE: 0.07997272908687592.
#   Metrics on testing data:
#     MSE: 0.08743462711572647.
# Epoch #282
#   Metrics on training data:
#     MSE: 0.0799342691898346.
#   Metrics on testing data:
#     MSE: 0.08740439265966415.
# Epoch #283
#   Metrics on training data:
#     MSE: 0.07989104837179184.
#   Metrics on testing data:
#     MSE: 0.08737014979124069.
# Epoch #284
#   Metrics on training data:
#     MSE: 0.07985246181488037.
#   Metrics on testing data:
#     MSE: 0.0873400941491127.
# Epoch #285
#   Metrics on training data:
#     MSE: 0.0798112004995346.
#   Metrics on testing data:
#     MSE: 0.08730734884738922.
# Epoch #286
#   Metrics on training data:
#     MSE: 0.0797729343175888.
#   Metrics on testing data:
#     MSE: 0.0872776061296463.
# Epoch #287
#   Metrics on training data:
#     MSE: 0.07973067462444305.
#   Metrics on testing data:
#     MSE: 0.08724384009838104.
# Epoch #288
#   Metrics on training data:
#     MSE: 0.07969000190496445.
#   Metrics on testing data:
#     MSE: 0.08721193671226501.
# Epoch #289
#   Metrics on training data:
#     MSE: 0.07965199649333954.
#   Metrics on testing data:
#     MSE: 0.08718202263116837.
# Epoch #290
#   Metrics on training data:
#     MSE: 0.07961000502109528.
#   Metrics on testing data:
#     MSE: 0.087148517370224.
# Epoch #291
#   Metrics on training data:
#     MSE: 0.07957110553979874.
#   Metrics on testing data:
#     MSE: 0.08711796998977661.
# Epoch #292
#   Metrics on training data:
#     MSE: 0.07953043282032013.
#   Metrics on testing data:
#     MSE: 0.08708583563566208.
# Epoch #293
#   Metrics on training data:
#     MSE: 0.07949221134185791.
#   Metrics on testing data:
#     MSE: 0.08705583959817886.
# Epoch #294
#   Metrics on training data:
#     MSE: 0.07945381850004196.
#   Metrics on testing data:
#     MSE: 0.08702588081359863.
# Epoch #295
#   Metrics on training data:
#     MSE: 0.07941234111785889.
#   Metrics on testing data:
#     MSE: 0.08699300140142441.
# Epoch #296
#   Metrics on training data:
#     MSE: 0.07937471568584442.
#   Metrics on testing data:
#     MSE: 0.08696375042200089.
# Epoch #297
#   Metrics on training data:
#     MSE: 0.07933750003576279.
#   Metrics on testing data:
#     MSE: 0.08693414181470871.
# Epoch #298
#   Metrics on training data:
#     MSE: 0.07929914444684982.
#   Metrics on testing data:
#     MSE: 0.0869046226143837.
# Epoch #299
#   Metrics on training data:
#     MSE: 0.07925771176815033.
#   Metrics on testing data:
#     MSE: 0.08687164634466171.
